# %%
# === SETUP: Run this first! ===
import os
import sys

# Change to project root and add to Python path
notebook_dir = os.getcwd()
project_root = os.path.dirname(notebook_dir)  # Goes up one level from 'notebooks/'
os.chdir(project_root)
sys.path.insert(0, project_root)

print(f"Project root: {project_root}")
print(f"tsnn module path: {os.path.join(project_root, 'tsnn')}")
# Out:
# Project root: /Users/cyrilgarcia/notebooks/tsnn
# tsnn module path: /Users/cyrilgarcia/notebooks/tsnn/tsnn

# %%
# %load_ext autoreload
# %autoreload 2

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.linear_model import LassoCV, RidgeCV, LinearRegression
import torch
from torch.utils.data import Dataset, random_split
from torch.utils.data import DataLoader
import importlib
import sys
#sys.path.append('/Users/cyrilgarcia/notebooks/tsnn/')

import tsnn

from tsnn.generators import generators
from tsnn.benchmarks import benchmark_comparison, ml_benchmarks, torch_benchmarks
from tsnn import utils
import torch.nn.functional as F
import math
from typing import Optional
from tsnn.tstorch import transformers



plt.style.use('ggplot')

# %%
from dataclasses import dataclass
from torch import nn
device = 'mps'

# %%
# This notebook will be used to compare different models.

# %% [markdown]
# # Basic comparison of models

# %% [markdown]
# ## Time series data

# %%
@dataclass
class Config:
    T: int = 3000
    n_ts: int = 10
    n_f: int = 40
    #T: int = 2000
    #n_ts: int = 5
    #n_f: int = 10
    pct_zero_corr: float = 0.5
    split_conditional: float = 0.25
    split_shift: float = 0.25
    split_seasonal: float = 0.
    split_cs: float = 0.25
    split_cs_shift: float = 0.25
    low_corr: float = 0.04
    high_corr: float = 0.05

# @dataclass
# class Config:
#     T: int = 3000
#     n_ts: int = 20
#     n_f: int = 10
#     pct_zero_corr: float = 0.5
#     split_conditional: float = 1.0
#     split_shift: float = 0.
#     split_seasonal: float = 0.
#     split_cs: float = 0.
#     split_cs_shift: float = 0.
#     low_corr: float = 0.1
#     high_corr: float = 0.2

# %%
z = generators.Generator(Config.T, Config.n_ts, Config.n_f)

# %%
# %%time
z.generate_dataset(pct_zero_corr = Config.pct_zero_corr,
                  split_conditional = Config.split_conditional,
                  split_shift = Config.split_shift,
                  split_seasonal = Config.split_seasonal,
                  split_cs=Config.split_cs,
                  split_cs_shift=Config.split_cs_shift,
                  low_corr=Config.low_corr, 
                  high_corr=Config.high_corr)
# Out:
# CPU times: user 20.2 ms, sys: 8.56 ms, total: 28.7 ms
# Wall time: 56.1 ms

# %%
z.get_dataloader(n_rolling=10, batch_size=128)

# %% [markdown]
# ## NN and Transformer models

# %%
# First a basic fully connect MLP:

class GlobalMLP(nn.Module):
    def __init__(
        self,
        n_ts,          # N
        n_f,           # F
        n_rolling,     # T
        hidden_dim=512,
        num_layers=4,
        dropout=0.1,
    ):
        super().__init__()
        
        input_dim = n_rolling * n_ts * n_f
        
        layers = []
        dim = input_dim
        for i in range(num_layers):
            layers.append(nn.Linear(dim, hidden_dim))
            layers.append(nn.GELU())
            layers.append(nn.Dropout(dropout))
            dim = hidden_dim
        
        # Final projection to N targets
        layers.append(nn.Linear(hidden_dim, n_ts))
        
        self.network = nn.Sequential(*layers)

    def forward(self, x):
        """
        x: (B, T, N, F)
        """
        B = x.shape[0]
        x = x.reshape(B, -1)          # (B, T*N*F)
        out = self.network(x)         # (B, N)
        return out

# %%
# Next a per series than global MLP

class PerSeriesThenGlobalMLP(nn.Module):
    def __init__(
        self,
        n_ts,          # N
        n_f,           # F
        n_rolling,     # T
        d_model=256,   # hidden size after per-series processing
        hidden_global=512,
        num_layers_local=3,
        num_layers_global=3,
        dropout=0.1,
    ):
        super().__init__()
        
        self.n_ts = n_ts
        self.d_model = d_model
        
        # --------------------------------------------------------------
        # 1. Local MLP: applied independently to each series
        #    Input per series: T × F  →  collapses to d_model
        # --------------------------------------------------------------
        local_layers = []
        dim = n_rolling * n_f
        for i in range(num_layers_local):
            local_layers.extend([
                nn.Linear(dim, d_model),
                nn.GELU(),
                nn.Dropout(dropout),
                nn.LayerNorm(d_model)
            ])
            dim = d_model
        # Final local projection
        local_layers.append(nn.Linear(dim, d_model))
        self.local_mlp = nn.Sequential(*local_layers)
        
        # --------------------------------------------------------------
        # 2. Global MLP: mixes information across the N series
        #    Input: N × d_model  →  N
        # --------------------------------------------------------------
        global_layers = []
        dim = n_ts * d_model
        for i in range(num_layers_global):
            global_layers.extend([
                nn.Linear(dim, hidden_global),
                nn.GELU(),
                nn.Dropout(dropout),
                nn.LayerNorm(hidden_global)
            ])
            dim = hidden_global
        global_layers.append(nn.Linear(hidden_global, n_ts))
        self.global_mlp = nn.Sequential(*global_layers)

    def forward(self, x):
        """
        x: (B, T, N, F)
        """
        B, T, N, F = x.shape
        
        # Reshape so each series becomes a separate "sample"
        x = x.permute(0, 2, 1, 3).reshape(B * N, T * F)   # (B*N, T*F)
        
        # Local processing: each series gets its own embedding
        local_emb = self.local_mlp(x)                     # (B*N, d_model)
        
        # Reshape back to have the series dimension explicit
        x_global = local_emb.view(B, N * self.d_model)    # (B, N*d_model)
        
        # Global mixing across series
        out = self.global_mlp(x_global)                   # (B, N)
        
        return out

# %%
# Basic transformer model with TS attention.

class TransformerEncoderModel(nn.Module):
    def __init__(self, n_ts, n_f, n_rolling, d_model=128, nhead=8, num_layers=2, dropout=0.8):
        super().__init__()
        self.input_dim = n_ts * n_f
        self.d_model = d_model

        # Linear projection of (n_ts*n_f) features
        self.input_proj = nn.Linear(self.input_dim, d_model)

        # Positional encoding (learned or sinusoidal)
        self.pos_embedding = nn.Parameter(torch.randn(1, n_rolling, d_model))

        # Transformer encoder
        encoder_layer = nn.TransformerEncoderLayer(
            d_model=d_model,
            nhead=nhead,
            dim_feedforward=4 * d_model,
            dropout=dropout,
            batch_first=True
        )
        self.encoder = nn.TransformerEncoder(encoder_layer, num_layers=num_layers)

        # prediction
        self.decoder = nn.Sequential(
            nn.LayerNorm(d_model),
            nn.Linear(d_model, n_ts)
        )

    def forward(self, x, mask=None):
        # x: (batch, n_rolling, n_ts, n_f)
        B, n_rolling, n_ts, n_f = x.shape

        # Flatten dimensions that are not lookback
        x = x.reshape(B, n_rolling, n_ts*n_f)
        x = self.input_proj(x) + self.pos_embedding[:, :n_rolling, :]

        # pass through Transformer encoder
        causal_mask = torch.triu(torch.ones(n_rolling, n_rolling, device=x.device), diagonal=1).bool()
        encoded = self.encoder(x, mask=causal_mask)  

        # last time step’s embedding for prediction
        out = self.decoder(encoded[:, -1, :])  # (B, N)
        return out

# %%
# Transformer model with both TS then CS attention.

class DualAttentionTransformer(nn.Module):
    def __init__(
        self,
        n_ts,          # number of time series (N)
        n_f,           # number of input features per timestamp
        n_rolling,     # lookback window length (T)
        d_model=128,
        nhead_time=8,      # heads for temporal attention (stage 1)
        nhead_series=8,    # heads for cross-series attention (stage 2)
        num_layers_time=1,
        num_layers_series=1,
        dim_feedforward=512,
        dropout=0.8,
    ):
        super().__init__()
        
        self.n_ts = n_ts
        self.n_rolling = n_rolling
        self.d_model = d_model

        # ------------------------------------------------------------------
        # 1. Input projection: (n_f) → d_model  (shared across all series & timesteps)
        # ------------------------------------------------------------------
        self.input_proj = nn.Linear(n_f, d_model)

        # Positional encoding for the temporal dimension (stage 1)
        self.pos_emb_time = nn.Parameter(torch.randn(1, n_rolling, d_model))
        # self.pos_emb_time = torch.arange(1, n_rolling)

        # ------------------------------------------------------------------
        # Stage 1: Temporal Transformer (attention over time, independent per series)
        # ------------------------------------------------------------------
        temporal_layer = nn.TransformerEncoderLayer(
            d_model=d_model,
            nhead=nhead_time,
            dim_feedforward=dim_feedforward,
            dropout=dropout,
            batch_first=True,
            activation="gelu",
        )
        self.temporal_transformer = nn.TransformerEncoder(
            temporal_layer, num_layers=num_layers_time
        )

        # Causal mask for temporal attention (autoregressive within the window)
        self.register_buffer(
            "causal_mask_time",
            torch.triu(torch.ones(n_rolling, n_rolling), diagonal=1).bool()
        )

        # ------------------------------------------------------------------
        # Stage 2: Cross-Series Transformer (attention over the N series)
        # ------------------------------------------------------------------
        series_layer = nn.TransformerEncoderLayer(
            d_model=d_model,
            nhead=nhead_series,
            dim_feedforward=dim_feedforward,
            dropout=dropout,
            batch_first=True,
            activation="gelu",
        )
        self.series_transformer = nn.TransformerEncoder(
            series_layer, num_layers=num_layers_series
        )

        # Optional positional encoding for the series dimension
        # (can be learned or fixed; here learned)
        
        self.pos_emb_series = nn.Parameter(torch.randn(1, n_ts, d_model))
        # self.pos_emb_series = torch.arange(1, n_ts)

        # ------------------------------------------------------------------
        # Final prediction head: d_model → 1 (forecast scalar per series)
        # ------------------------------------------------------------------
        self.output_head = nn.Sequential(
            nn.LayerNorm(d_model),
            nn.ReLU(),
            nn.Dropout(dropout),
            nn.Linear(d_model, 1)
        )

    def forward(self, x):
        """
        x : (B, n_rolling, n_ts, n_f)   float tensor
        Returns: (B, n_ts)               predicted scalar for each series
        """
        B, T, N, F = x.shape  # T = n_rolling, N = n_ts, F = n_f

        # ------------------------------------------------------------------
        # 1. Project features → d_model
        # ------------------------------------------------------------------
        # (B, T, N, F) → (B, T, N, d_model)
        x = self.input_proj(x)

        # ------------------------------------------------------------------
        # 2. Reshape so that batch × series becomes the new "batch"
        #    → (B*N, T, d_model)
        # ------------------------------------------------------------------
        x = x.permute(0, 2, 1, 3).reshape(B * N, T, self.d_model)  # (B*N, T, d_model)

        # Add temporal positional encoding
        x = x + self.pos_emb_time[:, :T, :]

        # ------------------------------------------------------------------
        # 3. Temporal Transformer (causal attention over time)
        # ------------------------------------------------------------------
        x = self.temporal_transformer(x, mask=self.causal_mask_time)  # (B*N, T, d_model)

        # Take the last timestep representation
        x_last = x[:, -1, :]  # (B*N, d_model)

        # ------------------------------------------------------------------
        # 4. Reshape back to have series dimension explicit
        #    → (B, N, d_model)
        # ------------------------------------------------------------------
        x_series = x_last.view(B, N, self.d_model)

        # Add series positional encoding
        x_series = x_series + self.pos_emb_series

        # ------------------------------------------------------------------
        # 5. Cross-Series Transformer (full attention over the N series)
        # ------------------------------------------------------------------
        # No mask needed here → full bidirectional attention across series
        x_series = self.series_transformer(x_series)  # (B, N, d_model)

        # ------------------------------------------------------------------
        # 6. Final prediction
        # ------------------------------------------------------------------
        out = self.output_head(x_series)      # (B, N, 1)
        out = out.squeeze(-1)                 # (B, N) = (B, n_ts)

        return out

# %%
# MLP in the TS dimension, then transformer in CS dimension.

class MLPSpatioTransformer(nn.Module):
    """
    Architecture:
    1. Treat each series independently → collapse (T, F) → d_model via shared MLP
    2. Reshape to (B, N, d_model)
    3. Apply Transformer with attention over the N series (cross-series communication)
    4. Predict one scalar per series from the final d_model representations
    """
    def __init__(
        self,
        n_ts,              # N: number of time series
        n_f,               # F: number of input features
        n_rolling,         # T: lookback length
        d_model=256,
        nhead=8,
        num_layers=2,
        dim_feedforward=512,
        dropout=0.8,
        mlp_layers=3,      # depth of the per-series MLP
    ):
        super().__init__()
        
        self.n_ts = n_ts
        self.n_rolling = n_rolling
        self.d_model = d_model

        # --------------------------------------------------------------
        # 1. Per-series MLP: processes each (T, F) window independently
        #    Input size per series: T * F
        # --------------------------------------------------------------
        input_dim = n_rolling * n_f
        mlp = []
        dim = input_dim
        
        for i in range(mlp_layers):
            mlp.extend([
                nn.Linear(dim, d_model),
                nn.GELU(),
                nn.LayerNorm(d_model),
                nn.Dropout(dropout)
            ])
            dim = d_model
            
        # Final projection to exact d_model (in case of residual connections or skip)
        mlp.append(nn.Linear(dim, d_model))
        self.per_series_mlp = nn.Sequential(*mlp)

        # --------------------------------------------------------------
        # 2. Positional encoding for the series dimension (N)
        #    (learned, because series usually don't have natural ordering)
        # --------------------------------------------------------------
        self.pos_embedding = nn.Parameter(torch.randn(1, n_ts, d_model))

        # --------------------------------------------------------------
        # 3. Cross-series Transformer (attention over the N dimension)
        # --------------------------------------------------------------
        encoder_layer = nn.TransformerEncoderLayer(
            d_model=d_model,
            nhead=nhead,
            dim_feedforward=dim_feedforward,
            dropout=dropout,
            activation='gelu',
            batch_first=True,
            norm_first=True
        )
        self.transformer = nn.TransformerEncoder(
            encoder_layer,
            num_layers=num_layers
        )

        # --------------------------------------------------------------
        # 4. Final prediction head: d_model → 1
        # --------------------------------------------------------------
        self.output_head = nn.Sequential(
            nn.LayerNorm(d_model),
            nn.GELU(),
            nn.Dropout(dropout),
            nn.Linear(d_model, 1)
        )

    def forward(self, x):
        """
        x : (B, T, N, F)
        Returns: (B, N)
        """
        B, T, N, F = x.shape

        # --------------------------------------------------------------
        # 1. Reshape so each series is a separate sample
        #    (B, T, N, F) → (B*N, T*F)
        # --------------------------------------------------------------
        x = x.permute(0, 2, 1, 3).reshape(B * N, T * F)   # (B*N, T*F)

        # --------------------------------------------------------------
        # 2. Per-series MLP encoding
        # --------------------------------------------------------------
        h = self.per_series_mlp(x)                        # (B*N, d_model)

        # --------------------------------------------------------------
        # 3. Reshape back to explicit series dimension
        #    (B*N, d_model) → (B, N, d_model)
        # --------------------------------------------------------------
        h = h.view(B, N, self.d_model)

        # Add learned positional encoding for the series axis
        h = h + self.pos_embedding

        # --------------------------------------------------------------
        # 4. Cross-series Transformer (full bidirectional attention over N)
        # --------------------------------------------------------------
        h = self.transformer(h)                           # (B, N, d_model)

        # --------------------------------------------------------------
        # 5. Final prediction
        # --------------------------------------------------------------
        out = self.output_head(h)                         # (B, N, 1)
        out = out.squeeze(-1)                             # (B, N)

        return out

# %%
# Lets add one more model, alternating TS and CS transformers.
class AlternatingDualAttentionTransformer(nn.Module):
    def __init__(
        self,
        n_ts,
        n_f,
        n_rolling,
        d_model=128,
        nhead=8,
        num_layers=2,
        dim_feedforward=512,
        dropout=0.1,
    ):
        super().__init__()
        self.d_model = d_model
        self.n_rolling = n_rolling
        self.n_ts = n_ts

        self.input_proj = nn.Linear(n_f, d_model)

        # ←←← THIS IS THE FIX ←←←
        self.pos_emb_time   = nn.Parameter(torch.randn(1, 1, d_model))   # broadcasts over T
        self.pos_emb_series = nn.Parameter(torch.randn(1, 1, d_model))   # broadcasts over N

        self.dropout = nn.Dropout(dropout)

        self.blocks = nn.ModuleList()
        for _ in range(num_layers):
            temp = nn.TransformerEncoder(
                nn.TransformerEncoderLayer(d_model, nhead, dim_feedforward, dropout,
                                          activation="gelu", batch_first=True),
                num_layers=1
            )
            series = nn.TransformerEncoder(
                nn.TransformerEncoderLayer(d_model, nhead, dim_feedforward, dropout,
                                          activation="gelu", batch_first=True),
                num_layers=1
            )
            self.blocks.append(nn.ModuleDict({
                'temporal': temp,
                'series': series,
                'norm1': nn.LayerNorm(d_model),
                'norm2': nn.LayerNorm(d_model),
            }))

        self.register_buffer("causal_mask",
                             torch.triu(torch.ones(n_rolling, n_rolling), diagonal=1).bool())

        self.output_head = nn.Sequential(
            nn.LayerNorm(d_model),
            nn.GELU(),
            nn.Dropout(dropout),
            nn.Linear(d_model, 1)
        )

    def forward(self, x):
        B, T, N, _ = x.shape

        x = self.input_proj(x)                                  # (B,T,N,d_model)

        # ←←← NOW SAFE ←←←
        x = x + self.pos_emb_time + self.pos_emb_series

        for block in self.blocks:
            # Temporal
            res = x
            x = x.permute(0, 2, 1, 3).reshape(B*N, T, self.d_model)
            x = block['temporal'](x, mask=self.causal_mask)
            x = x.reshape(B, N, T, self.d_model).permute(0, 2, 1, 3)
            x = block['norm1'](res + self.dropout(x))

            # Cross-series
            res = x
            x = x.reshape(B*T, N, self.d_model)
            x = block['series'](x)
            x = x.reshape(B, T, N, self.d_model)
            x = block['norm2'](res + self.dropout(x))

        # Take last timestep
        x = x[:, -1, :, :]                                      # (B, N, d_model)
        return self.output_head(x).squeeze(-1)

# %%
class AlternatingDualAttentionTransformer2(nn.Module):
    def __init__(
        self,
        n_ts,
        n_f,
        n_rolling,
        mask,
        d_model=128,
        nhead=8,
        num_layers=2,
        dim_feedforward=512,
        dropout=0.1,
        sparsify=None
    ):
        super().__init__()
        self.d_model = d_model
        self.n_rolling = n_rolling
        self.n_ts = n_ts
        self.mask = mask
        self.sparsify = sparsify

        self.input_proj = nn.Linear(n_f, d_model)

        # Broadcasted positional embeddings
        self.pos_emb_time   = nn.Parameter(torch.randn(1, 1, d_model))
        self.pos_emb_series = nn.Parameter(torch.randn(1, 1, d_model))

        self.dropout = nn.Dropout(dropout)

        self.blocks = nn.ModuleList()
        for _ in range(num_layers):
            temp = transformers.TransformerEncoder(
                transformers.TransformerEncoderLayer(d_model, nhead, dim_feedforward, dropout),
                num_layers=1
            )
            # we only use the self_attn module from this one — series attention is custom
            series = transformers.TransformerEncoderLayer(d_model, nhead, dim_feedforward, dropout)
            self.blocks.append(nn.ModuleDict({
                'temporal': temp,
                'series': series,
                'norm1': nn.LayerNorm(d_model),
                'norm2': nn.LayerNorm(d_model),
            }))

        self.output_head = nn.Sequential(
            nn.LayerNorm(d_model),
            nn.GELU(),
            nn.Dropout(dropout),
            nn.Linear(d_model, 1)
        )

    def series_attention(self, x, attn_layer):
        """
        x: (B, T, N, d)
        Applies attention independently for each (B, T) window over the N dimension.
        """
        B, T, N, D = x.shape

        x_flat = x.view(B*T, N, D)

        out = attn_layer.self_attn(x_flat, x_flat, x_flat,)

        out = out.view(B, T, N, D)
        return out
    
    def temporal_attention(self, x, attn_encoder):
        """
        x: (B, T, N, D)
        Applies temporal attention independently for each series (N dimension)
        using the stored TransformerEncoder.
        """
        B, T, N, D = x.shape
        x_flat = x.transpose(1, 2).contiguous().view(B*N, T, D)

        out = attn_encoder(x_flat, mask=self.mask, sparsify=self.sparsify)

        out = out.view(B, N, T, D).transpose(1, 2)
        return out

    def forward(self, x):
        B, T, N, _ = x.shape

        x = self.input_proj(x)

        # broadcast positional embeddings
        x = x + self.pos_emb_time + self.pos_emb_series

        for block in self.blocks:
            # temporal
            res = x
            x_t = self.temporal_attention(x, block['temporal'])
            x = block['norm1']((res + self.dropout(x_t)).contiguous())

            # series
            res = x
            x_s = self.series_attention(x, block['series'])
            x = block['norm2']((res + self.dropout(x_s)).contiguous())

        # final timestep → (B, N, d)
        x = x[:, -1, :, :]

        return self.output_head(x).squeeze(-1)

# %% [markdown]
# ## Running the models

# %%
# Let's now run the five models above (or a subset of them) on the generated data.

# %%
m = GlobalMLP(Config.n_ts, Config.n_f, 10, dropout=0.2).to(device)
optimizer = torch.optim.Adam(m.parameters(), lr=0.001)
#optimizer = torch.optim.SGD(m.parameters(), lr=1e-3)

model_nn1 = torch_benchmarks.TorchWrapper(m, optimizer=optimizer)
model_nn1.fit(z.train, test=z.test, epochs=100)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:23<00:00,  4.22it/s]

# %%
m = PerSeriesThenGlobalMLP(Config.n_ts, Config.n_f, 10, dropout=0.2).to(device)
optimizer = torch.optim.AdamW(m.parameters(), lr=0.001)
#optimizer = torch.optim.SGD(m.parameters(), lr=1e-3)

model_nn2 = torch_benchmarks.TorchWrapper(m, optimizer=optimizer)
model_nn2.fit(z.train, test=z.test, epochs=100)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:29<00:00,  3.37it/s]

# %%
m = TransformerEncoderModel(Config.n_ts, Config.n_f, 10).to(device)
optimizer = torch.optim.AdamW(m.parameters(), lr=0.001)
#optimizer = torch.optim.SGD(m.parameters(), lr=1e-3)


model_torch = torch_benchmarks.TorchWrapper(m, optimizer=optimizer)
model_torch.fit(z.train, test=z.test, epochs=80)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████| 80/80 [00:27<00:00,  2.94it/s]

# %%
m = DualAttentionTransformer(Config.n_ts, Config.n_f, 10, d_model=32, dim_feedforward=512, dropout=0.5, num_layers_series=2, num_layers_time=2).to(device)
optimizer = torch.optim.AdamW(m.parameters(), lr=0.001)
#optimizer = torch.optim.SGD(m.parameters(), lr=1e-3)


model_torch2 = torch_benchmarks.TorchWrapper(m, optimizer=optimizer)
model_torch2.fit(z.train, test=z.test, epochs=40)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████| 40/40 [00:51<00:00,  1.29s/it]

# %%
m = MLPSpatioTransformer(Config.n_ts, Config.n_f, 10, d_model=128, dim_feedforward=512, dropout=0.5, num_layers=2, mlp_layers=2).to(device)
optimizer = torch.optim.AdamW(m.parameters(), lr=0.001)
# optimizer = torch.optim.SGD(m.parameters(), lr=1e-3)


model_torch3 = torch_benchmarks.TorchWrapper(m, optimizer=optimizer)
model_torch3.fit(z.train, test=z.test, epochs=60)
# Out:
# /Users/cyrilgarcia/miniconda3/envs/cyril10/lib/python3.10/site-packages/torch/nn/modules/transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   warnings.warn(
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████| 60/60 [00:27<00:00,  2.16it/s]

# %% [raw]
# m = AlternatingDualAttentionTransformer(Config.n_ts, Config.n_f, 10, d_model=128, dim_feedforward=512, dropout=0.5, num_layers=2).to(device)
# optimizer = torch.optim.AdamW(m.parameters(), lr=0.001)
# # optimizer = torch.optim.SGD(m.parameters(), lr=1e-3)
#
#
# model_torch4 = torch_benchmarks.TorchWrapper(m, optimizer=optimizer)
# model_torch4.fit(z.train, test=z.test, epochs=60)

# %%
def causal_mask(b, h, q_idx, kv_idx):
    return q_idx >= kv_idx

def build_attention_mask(mask_fn, seq_len, device="cpu"):
    q_idx = torch.arange(seq_len, device=device)
    kv_idx = torch.arange(seq_len, device=device)
    b = torch.zeros(1, device=device)
    h = torch.zeros(1, device=device)
    mask_bool = mask_fn(b, h, q_idx[:, None], kv_idx[None, :])  # (seq_len, seq_len)
    return mask_bool

mask = causal_mask
mask = build_attention_mask(mask, 10, device=device)
def custom_mask_mod(b, h, q_idx, kv_idx):
    return mask[q_idx, kv_idx]

# %%
device='mps'
m = AlternatingDualAttentionTransformer2(Config.n_ts, Config.n_f, 10, mask=mask, d_model=128, dim_feedforward=512, dropout=0.5, num_layers=2).to(device)
optimizer = torch.optim.AdamW(m.parameters(), lr=0.001)
# optimizer = torch.optim.SGD(m.parameters(), lr=1e-3)
m = torch.compile(m, backend="eager")

model_torch5 = torch_benchmarks.TorchWrapper(m, optimizer=optimizer, device=device)
model_torch5.fit(z.train, test=z.test, epochs=60)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████| 60/60 [02:17<00:00,  2.29s/it]

# %% [markdown]
# ## Comparison

# %%
comp = benchmark_comparison.Comparator(models=[model_nn1, model_nn2, model_torch, model_torch2, model_torch3, model_torch5],
                                        model_names=['NN1', 'NN2', 'transformer', 'transformer2', 'transformer3', 'transformer5'])

# comp = benchmark_comparison.Comparator(models=[model_nn1, model_nn2, model_torch],
#                                         model_names=['NN1', 'NN2', 'transformer'])

# %%
comp.correl(z, mode='train')
# Out:
# python(32875) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(32876) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(32877) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(32878) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(32880) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(32881) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(32882) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(32883) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(32887) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(32888) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(32889) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(32890) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(32896) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(32897) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(32898) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(32899) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(32908) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(32909) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(32910) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(32911) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(32922) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(32923) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(32924) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(32925) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# <style type="text/css">
# #T_61287_row0_col0, #T_61287_row5_col1, #T_61287_row6_col1, #T_61287_row7_col1, #T_61287_row8_col8, #T_61287_row9_col9 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_61287_row0_col1, #T_61287_row0_col2, #T_61287_row0_col3, #T_61287_row0_col4, #T_61287_row0_col5, #T_61287_row0_col6, #T_61287_row0_col7, #T_61287_row0_col8, #T_61287_row0_col9, #T_61287_row0_col10, #T_61287_row1_col2, #T_61287_row1_col3, #T_61287_row1_col4, #T_61287_row1_col5, #T_61287_row1_col6, #T_61287_row1_col7, #T_61287_row1_col8, #T_61287_row1_col9, #T_61287_row1_col10, #T_61287_row2_col3, #T_61287_row2_col4, #T_61287_row2_col5, #T_61287_row2_col6, #T_61287_row2_col7, #T_61287_row2_col8, #T_61287_row2_col9, #T_61287_row2_col10, #T_61287_row3_col4, #T_61287_row3_col5, #T_61287_row3_col6, #T_61287_row3_col7, #T_61287_row3_col8, #T_61287_row3_col9, #T_61287_row3_col10, #T_61287_row4_col5, #T_61287_row4_col6, #T_61287_row4_col7, #T_61287_row4_col8, #T_61287_row4_col9, #T_61287_row4_col10, #T_61287_row5_col6, #T_61287_row5_col7, #T_61287_row5_col8, #T_61287_row5_col9, #T_61287_row5_col10, #T_61287_row6_col7, #T_61287_row6_col8, #T_61287_row6_col9, #T_61287_row6_col10, #T_61287_row7_col8, #T_61287_row7_col9, #T_61287_row7_col10, #T_61287_row8_col9, #T_61287_row8_col10, #T_61287_row9_col10 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_61287_row1_col0, #T_61287_row5_col2, #T_61287_row6_col2, #T_61287_row8_col6, #T_61287_row8_col7, #T_61287_row9_col2 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_61287_row1_col1 {
#   background-color: #f4987a;
#   color: #000000;
# }
# #T_61287_row2_col0, #T_61287_row5_col3, #T_61287_row6_col3, #T_61287_row8_col0 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_61287_row2_col1, #T_61287_row3_col1 {
#   background-color: #f39778;
#   color: #000000;
# }
# #T_61287_row2_col2, #T_61287_row3_col2, #T_61287_row4_col3, #T_61287_row8_col5, #T_61287_row10_col5 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_61287_row3_col0, #T_61287_row4_col0, #T_61287_row5_col4, #T_61287_row6_col4, #T_61287_row9_col4 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_61287_row3_col3, #T_61287_row8_col2, #T_61287_row8_col3 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_61287_row4_col1 {
#   background-color: #f49a7b;
#   color: #000000;
# }
# #T_61287_row4_col2, #T_61287_row4_col4 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_61287_row5_col0, #T_61287_row6_col0 {
#   background-color: #b50927;
#   color: #f1f1f1;
# }
# #T_61287_row5_col5, #T_61287_row6_col5, #T_61287_row9_col5 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_61287_row6_col6 {
#   background-color: #b70d28;
#   color: #f1f1f1;
# }
# #T_61287_row7_col0, #T_61287_row7_col6, #T_61287_row7_col7 {
#   background-color: #e8765c;
#   color: #f1f1f1;
# }
# #T_61287_row7_col2 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_61287_row7_col3, #T_61287_row10_col1 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_61287_row7_col4 {
#   background-color: #f0cdbb;
#   color: #000000;
# }
# #T_61287_row7_col5, #T_61287_row10_col2 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_61287_row8_col1, #T_61287_row10_col4 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_61287_row8_col4, #T_61287_row10_col3 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_61287_row9_col0 {
#   background-color: #cc403a;
#   color: #f1f1f1;
# }
# #T_61287_row9_col1 {
#   background-color: #f3c8b2;
#   color: #000000;
# }
# #T_61287_row9_col3 {
#   background-color: #f1ccb8;
#   color: #000000;
# }
# #T_61287_row9_col6, #T_61287_row9_col7 {
#   background-color: #cd423b;
#   color: #f1f1f1;
# }
# #T_61287_row9_col8 {
#   background-color: #ee8669;
#   color: #f1f1f1;
# }
# #T_61287_row10_col0, #T_61287_row10_col6, #T_61287_row10_col7, #T_61287_row10_col8 {
#   background-color: #f5c4ac;
#   color: #000000;
# }
# #T_61287_row10_col9 {
#   background-color: #f7b396;
#   color: #000000;
# }
# #T_61287_row10_col10 {
#   background-color: #f6bfa6;
#   color: #000000;
# }
# </style>
# <table id="T_61287">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_61287_level0_col0" class="col_heading level0 col0" >true</th>
#       <th id="T_61287_level0_col1" class="col_heading level0 col1" >optimal</th>
#       <th id="T_61287_level0_col2" class="col_heading level0 col2" >conditional</th>
#       <th id="T_61287_level0_col3" class="col_heading level0 col3" >shift</th>
#       <th id="T_61287_level0_col4" class="col_heading level0 col4" >cs</th>
#       <th id="T_61287_level0_col5" class="col_heading level0 col5" >cs_shift</th>
#       <th id="T_61287_level0_col6" class="col_heading level0 col6" >NN1</th>
#       <th id="T_61287_level0_col7" class="col_heading level0 col7" >NN2</th>
#       <th id="T_61287_level0_col8" class="col_heading level0 col8" >transformer</th>
#       <th id="T_61287_level0_col9" class="col_heading level0 col9" >transformer2</th>
#       <th id="T_61287_level0_col10" class="col_heading level0 col10" >transformer3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_61287_level0_row0" class="row_heading level0 row0" >optimal</th>
#       <td id="T_61287_row0_col0" class="data row0 col0" >0.187</td>
#       <td id="T_61287_row0_col1" class="data row0 col1" >nan</td>
#       <td id="T_61287_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_61287_row0_col3" class="data row0 col3" >nan</td>
#       <td id="T_61287_row0_col4" class="data row0 col4" >nan</td>
#       <td id="T_61287_row0_col5" class="data row0 col5" >nan</td>
#       <td id="T_61287_row0_col6" class="data row0 col6" >nan</td>
#       <td id="T_61287_row0_col7" class="data row0 col7" >nan</td>
#       <td id="T_61287_row0_col8" class="data row0 col8" >nan</td>
#       <td id="T_61287_row0_col9" class="data row0 col9" >nan</td>
#       <td id="T_61287_row0_col10" class="data row0 col10" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_61287_level0_row1" class="row_heading level0 row1" >conditional</th>
#       <td id="T_61287_row1_col0" class="data row1 col0" >0.100</td>
#       <td id="T_61287_row1_col1" class="data row1 col1" >0.507</td>
#       <td id="T_61287_row1_col2" class="data row1 col2" >nan</td>
#       <td id="T_61287_row1_col3" class="data row1 col3" >nan</td>
#       <td id="T_61287_row1_col4" class="data row1 col4" >nan</td>
#       <td id="T_61287_row1_col5" class="data row1 col5" >nan</td>
#       <td id="T_61287_row1_col6" class="data row1 col6" >nan</td>
#       <td id="T_61287_row1_col7" class="data row1 col7" >nan</td>
#       <td id="T_61287_row1_col8" class="data row1 col8" >nan</td>
#       <td id="T_61287_row1_col9" class="data row1 col9" >nan</td>
#       <td id="T_61287_row1_col10" class="data row1 col10" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_61287_level0_row2" class="row_heading level0 row2" >shift</th>
#       <td id="T_61287_row2_col0" class="data row2 col0" >0.105</td>
#       <td id="T_61287_row2_col1" class="data row2 col1" >0.513</td>
#       <td id="T_61287_row2_col2" class="data row2 col2" >0.011</td>
#       <td id="T_61287_row2_col3" class="data row2 col3" >nan</td>
#       <td id="T_61287_row2_col4" class="data row2 col4" >nan</td>
#       <td id="T_61287_row2_col5" class="data row2 col5" >nan</td>
#       <td id="T_61287_row2_col6" class="data row2 col6" >nan</td>
#       <td id="T_61287_row2_col7" class="data row2 col7" >nan</td>
#       <td id="T_61287_row2_col8" class="data row2 col8" >nan</td>
#       <td id="T_61287_row2_col9" class="data row2 col9" >nan</td>
#       <td id="T_61287_row2_col10" class="data row2 col10" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_61287_level0_row3" class="row_heading level0 row3" >cs</th>
#       <td id="T_61287_row3_col0" class="data row3 col0" >0.089</td>
#       <td id="T_61287_row3_col1" class="data row3 col1" >0.515</td>
#       <td id="T_61287_row3_col2" class="data row3 col2" >0.010</td>
#       <td id="T_61287_row3_col3" class="data row3 col3" >0.023</td>
#       <td id="T_61287_row3_col4" class="data row3 col4" >nan</td>
#       <td id="T_61287_row3_col5" class="data row3 col5" >nan</td>
#       <td id="T_61287_row3_col6" class="data row3 col6" >nan</td>
#       <td id=

# %%
comp.correl(z, mode='test')
# Out:
# python(32968) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(32969) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(32970) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(32971) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(32972) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(32973) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(32974) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(32975) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(32976) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(32977) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(32978) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(32979) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(32981) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(32982) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(32983) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(32984) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(32990) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(32991) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(32992) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(32993) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(32996) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(32997) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(32998) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(32999) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# <style type="text/css">
# #T_a29f2_row0_col0 {
#   background-color: #f1ccb8;
#   color: #000000;
# }
# #T_a29f2_row0_col1, #T_a29f2_row0_col2, #T_a29f2_row0_col3, #T_a29f2_row0_col4, #T_a29f2_row0_col5, #T_a29f2_row0_col6, #T_a29f2_row0_col7, #T_a29f2_row0_col8, #T_a29f2_row0_col9, #T_a29f2_row0_col10, #T_a29f2_row1_col2, #T_a29f2_row1_col3, #T_a29f2_row1_col4, #T_a29f2_row1_col5, #T_a29f2_row1_col6, #T_a29f2_row1_col7, #T_a29f2_row1_col8, #T_a29f2_row1_col9, #T_a29f2_row1_col10, #T_a29f2_row2_col3, #T_a29f2_row2_col4, #T_a29f2_row2_col5, #T_a29f2_row2_col6, #T_a29f2_row2_col7, #T_a29f2_row2_col8, #T_a29f2_row2_col9, #T_a29f2_row2_col10, #T_a29f2_row3_col4, #T_a29f2_row3_col5, #T_a29f2_row3_col6, #T_a29f2_row3_col7, #T_a29f2_row3_col8, #T_a29f2_row3_col9, #T_a29f2_row3_col10, #T_a29f2_row4_col5, #T_a29f2_row4_col6, #T_a29f2_row4_col7, #T_a29f2_row4_col8, #T_a29f2_row4_col9, #T_a29f2_row4_col10, #T_a29f2_row5_col6, #T_a29f2_row5_col7, #T_a29f2_row5_col8, #T_a29f2_row5_col9, #T_a29f2_row5_col10, #T_a29f2_row6_col7, #T_a29f2_row6_col8, #T_a29f2_row6_col9, #T_a29f2_row6_col10, #T_a29f2_row7_col8, #T_a29f2_row7_col9, #T_a29f2_row7_col10, #T_a29f2_row8_col9, #T_a29f2_row8_col10, #T_a29f2_row9_col10 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_a29f2_row1_col0, #T_a29f2_row4_col0 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_a29f2_row1_col1 {
#   background-color: #f39778;
#   color: #000000;
# }
# #T_a29f2_row2_col0, #T_a29f2_row7_col1 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_a29f2_row2_col1, #T_a29f2_row4_col1 {
#   background-color: #f4987a;
#   color: #000000;
# }
# #T_a29f2_row2_col2, #T_a29f2_row5_col0, #T_a29f2_row6_col0, #T_a29f2_row8_col1, #T_a29f2_row9_col2, #T_a29f2_row9_col4, #T_a29f2_row9_col5, #T_a29f2_row10_col3 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_a29f2_row3_col0 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_a29f2_row3_col1 {
#   background-color: #f39577;
#   color: #000000;
# }
# #T_a29f2_row3_col2, #T_a29f2_row10_col1, #T_a29f2_row10_col4 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_a29f2_row3_col3, #T_a29f2_row4_col4, #T_a29f2_row6_col2, #T_a29f2_row7_col3, #T_a29f2_row7_col5, #T_a29f2_row8_col3, #T_a29f2_row8_col4, #T_a29f2_row10_col2 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_a29f2_row4_col2, #T_a29f2_row4_col3, #T_a29f2_row8_col2, #T_a29f2_row8_col5, #T_a29f2_row10_col5 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_a29f2_row5_col1, #T_a29f2_row8_col6 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_a29f2_row5_col2, #T_a29f2_row7_col2 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_a29f2_row5_col3, #T_a29f2_row5_col5, #T_a29f2_row6_col5, #T_a29f2_row7_col0, #T_a29f2_row9_col6, #T_a29f2_row10_col0 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_a29f2_row5_col4, #T_a29f2_row6_col3, #T_a29f2_row6_col4, #T_a29f2_row10_col7 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_a29f2_row6_col1, #T_a29f2_row8_col0 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_a29f2_row6_col6 {
#   background-color: #f3c7b1;
#   color: #000000;
# }
# #T_a29f2_row7_col4 {
#   background-color: #efcebd;
#   color: #000000;
# }
# #T_a29f2_row7_col6, #T_a29f2_row9_col9 {
#   background-color: #f4c6af;
#   color: #000000;
# }
# #T_a29f2_row7_col7 {
#   background-color: #ecd3c5;
#   color: #000000;
# }
# #T_a29f2_row8_col7, #T_a29f2_row9_col0, #T_a29f2_row10_col6 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_a29f2_row8_col8 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_a29f2_row9_col1 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_a29f2_row9_col3 {
#   background-color: #f5c4ac;
#   color: #000000;
# }
# #T_a29f2_row9_col7 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_a29f2_row9_col8 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_a29f2_row10_col8 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_a29f2_row10_col9 {
#   background-color: #f7b497;
#   color: #000000;
# }
# #T_a29f2_row10_col10 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# </style>
# <table id="T_a29f2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a29f2_level0_col0" class="col_heading level0 col0" >true</th>
#       <th id="T_a29f2_level0_col1" class="col_heading level0 col1" >optimal</th>
#       <th id="T_a29f2_level0_col2" class="col_heading level0 col2" >conditional</th>
#       <th id="T_a29f2_level0_col3" class="col_heading level0 col3" >shift</th>
#       <th id="T_a29f2_level0_col4" class="col_heading level0 col4" >cs</th>
#       <th id="T_a29f2_level0_col5" class="col_heading level0 col5" >cs_shift</th>
#       <th id="T_a29f2_level0_col6" class="col_heading level0 col6" >NN1</th>
#       <th id="T_a29f2_level0_col7" class="col_heading level0 col7" >NN2</th>
#       <th id="T_a29f2_level0_col8" class="col_heading level0 col8" >transformer</th>
#       <th id="T_a29f2_level0_col9" class="col_heading level0 col9" >transformer2</th>
#       <th id="T_a29f2_level0_col10" class="col_heading level0 col10" >transformer3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a29f2_level0_row0" class="row_heading level0 row0" >optimal</th>
#       <td id="T_a29f2_row0_col0" class="data row0 col0" >0.190</td>
#       <td id="T_a29f2_row0_col1" class="data row0 col1" >nan</td>
#       <td id="T_a29f2_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_a29f2_row0_col3" class="data row0 col3" >nan</td>
#       <td id="T_a29f2_row0_col4" class="data row0 col4" >nan</td>
#       <td id="T_a29f2_row0_col5" class="data row0 col5" >nan</td>
#       <td id="T_a29f2_row0_col6" class="data row0 col6" >nan</td>
#       <td id="T_a29f2_row0_col7" class="data row0 col7" >nan</td>
#       <td id="T_a29f2_row0_col8" class="data row0 col8" >nan</td>
#       <td id="T_a29f2_row0_col9" class="data row0 col9" >nan</td>
#       <td id="T_a29f2_row0_col10" class="data row0 col10" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_a29f2_level0_row1" class="row_heading level0 row1" >conditional</th>
#       <td id="T_a29f2_row1_col0" class="data row1 col0" >0.097</td>
#       <td id="T_a29f2_row1_col1" class="data row1 col1" >0.515</td>
#       <td id="T_a29f2_row1_col2" class="data row1 col2" >nan</td>
#       <td id="T_a29f2_row1_col3" class="data row1 col3" >nan</td>
#       <td id="T_a29f2_row1_col4" class="data row1 col4" >nan</td>
#       <td id="T_a29f2_row1_col5" class="data row1 col5" >nan</td>
#       <td id="T_a29f2_row1_col6" class="data row1 col6" >nan</td>
#       <td id="T_a29f2_row1_col7" class="data row1 col7" >nan</td>
#       <td id="T_a29f2_row1_col8" class="data row1 col8" >nan</td>
#       <td id="T_a29f2_row1_col9" class="data row1 col9" >nan</td>
#       <td id="T_a29f2_row1_col10" class="data row1 col10" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_a29f2_level0_row2" class="row_heading level0 row2" >shift</th>
#       <td id="T_a29f2_row2_col0" class="data row2 col0" >0.092</td>
#       <td id="T_a29f2_row2_col1" class="data row2 col1" >0.502</td>
#       <td id="T_a29f2_row2_col2" class="data row2 col2" >0.017</td>
#       <td id="T_a29f2_row2_col3" class="data row2 col3" >nan</td>
#       <td id="T_a29f2_row2_col4" class="data row2 col4" >nan</td>
#       <td id="T_a29f2_row2_col5" class="data row2 col5" >nan</td>
#       <td id="T_a29f2_row2_col6" class="data row2 col6" >nan</td>
#       <td id="T_a29f2_row2_col7" class="data row2 col7" >nan</td>
#       <td id="T_a29f2_row2_col8" class="data row2 col8" >nan</td>
#       <td id="T_a29f2_row2_col9" class="data row2 col9" >nan</td>
#       <td id="T_a29f2_row2_col10" class="data row2 col10" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_a29f2_level0_row3" class="row_heading level0 row3" >cs</th>
#       <td id="T_a29f2_row3_col0" class="data row3 col0" >0.102</td>
#       <td id="T_a29f2_row3_col1" class="data row3 col1" >0.518</td>
#       <td id="T_a29f2_row3_col2" class="data row3 col2" >0.027</td>
#       <td id="T_a29f2_row3_col3" class="data row3 col3" >0.014</td>
#       <td id="T_a29f2_row3_col4" class="data row3 col4" >nan</td>
#       <td id="T_a29f2_row3_col5" class="data row3 col5" >nan</td>
#       <td id="T_a29f2_row3_co

# %% [markdown]
# # Same as above with just one effect

# %% [markdown]
# ## cs_shift effect

# %%
# @dataclass
# class Config:
#     T: int = 3000
#     n_ts: int = 50
#     n_f: int = 10
#     pct_zero_corr: float = 0.5
#     split_conditional: float = 0.25
#     split_shift: float = 0.25
#     split_seasonal: float = 0.
#     split_cs: float = 0.25
#     split_cs_shift: float = 0.25
#     low_corr: float = 0.1
#     high_corr: float = 0.2

@dataclass
class Config:
    T: int = 3000
    n_ts: int = 10
    n_f: int = 10
    pct_zero_corr: float = 0.5
    split_conditional: float = 0.
    split_shift: float = 0.
    split_seasonal: float = 0.
    split_cs: float = 0.
    split_cs_shift: float = 1.0
    low_corr: float = 0.1
    high_corr: float = 0.2

# %%
z = generators.Generator(Config.T, Config.n_ts, Config.n_f)

# %%
# %%time
z.generate_dataset(pct_zero_corr = Config.pct_zero_corr,
                  split_conditional = Config.split_conditional,
                  split_shift = Config.split_shift,
                  split_seasonal = Config.split_seasonal,
                  split_cs=Config.split_cs,
                  split_cs_shift=Config.split_cs_shift,
                  low_corr=Config.low_corr, 
                  high_corr=Config.high_corr)
# Out:
# CPU times: user 8.46 ms, sys: 2.15 ms, total: 10.6 ms
# Wall time: 9.5 ms

# %%
z.get_dataloader(n_rolling=10)

# %%
m = GlobalMLP(Config.n_ts, Config.n_f, 10, dropout=0.2).to(device)
optimizer = torch.optim.Adam(m.parameters(), lr=0.001)
#optimizer = torch.optim.SGD(m.parameters(), lr=1e-3)

model_nn1 = torch_benchmarks.TorchWrapper(m, optimizer=optimizer)
model_nn1.fit(z.train, test=z.test, epochs=100)
# Out:
# 100%|██████████| 100/100 [00:10<00:00,  9.54it/s]

# %%
m = PerSeriesThenGlobalMLP(Config.n_ts, Config.n_f, 10, dropout=0.2).to(device)
optimizer = torch.optim.AdamW(m.parameters(), lr=0.001)
#optimizer = torch.optim.SGD(m.parameters(), lr=1e-3)

model_nn2 = torch_benchmarks.TorchWrapper(m, optimizer=optimizer)
model_nn2.fit(z.train, test=z.test, epochs=100)
# Out:
# 100%|██████████| 100/100 [00:15<00:00,  6.39it/s]

# %%
m = TransformerEncoderModel(Config.n_ts, Config.n_f, 10).to(device)
optimizer = torch.optim.AdamW(m.parameters(), lr=0.001)
#optimizer = torch.optim.SGD(m.parameters(), lr=1e-3)


model_torch = torch_benchmarks.TorchWrapper(m, optimizer=optimizer)
model_torch.fit(z.train, test=z.test, epochs=80)
# Out:
# 100%|██████████| 80/80 [00:16<00:00,  4.94it/s]

# %%
m = DualAttentionTransformer(Config.n_ts, Config.n_f, 10, d_model=128, dim_feedforward=512, dropout=0.2, num_layers_series=2, num_layers_time=2).to(device)
optimizer = torch.optim.AdamW(m.parameters(), lr=0.001)
#optimizer = torch.optim.SGD(m.parameters(), lr=1e-3)


model_torch2 = torch_benchmarks.TorchWrapper(m, optimizer=optimizer)
model_torch2.fit(z.train, test=z.test, epochs=60)
# Out:
# 100%|██████████| 60/60 [01:02<00:00,  1.03s/it]

# %%
m = MLPSpatioTransformer(Config.n_ts, Config.n_f, 10, d_model=128, dim_feedforward=512, dropout=0.5, num_layers=2, mlp_layers=2).to(device)
optimizer = torch.optim.AdamW(m.parameters(), lr=0.001)
# optimizer = torch.optim.SGD(m.parameters(), lr=1e-3)


model_torch3 = torch_benchmarks.TorchWrapper(m, optimizer=optimizer)
model_torch3.fit(z.train, test=z.test, epochs=60)
# Out:
# /Users/gremy/Code/TSNN-1/tsnn-env/lib/python3.11/site-packages/torch/nn/modules/transformer.py:392: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   warnings.warn(
# 100%|██████████| 60/60 [00:12<00:00,  4.93it/s]

# %%
m = AlternatingDualAttentionTransformer(Config.n_ts, Config.n_f, 10, d_model=128, dim_feedforward=512, dropout=0.2, num_layers=2).to(device)
optimizer = torch.optim.AdamW(m.parameters(), lr=0.001)
# optimizer = torch.optim.SGD(m.parameters(), lr=1e-3)


model_torch4 = torch_benchmarks.TorchWrapper(m, optimizer=optimizer)
model_torch4.fit(z.train, test=z.test, epochs=60)
# Out:
# 100%|██████████| 60/60 [01:54<00:00,  1.91s/it]

# %%
comp = benchmark_comparison.Comparator(models=[model_nn1, model_nn2, model_torch, model_torch2, model_torch3, model_torch4],
                                        model_names=['NN1', 'NN2', 'transformer', 'transformer2', 'transformer3', 'transformer4'])

# %%
comp.correl(z, mode='train')
# Out:
# /Users/gremy/Code/TSNN-1/tsnn-env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# <style type="text/css">
# #T_f799b_row0_col0, #T_f799b_row1_col0, #T_f799b_row2_col1, #T_f799b_row2_col2 {
#   background-color: #f7ba9f;
#   color: #000000;
# }
# #T_f799b_row0_col1, #T_f799b_row0_col2, #T_f799b_row0_col3, #T_f799b_row0_col4, #T_f799b_row0_col5, #T_f799b_row0_col6, #T_f799b_row0_col7, #T_f799b_row1_col2, #T_f799b_row1_col3, #T_f799b_row1_col4, #T_f799b_row1_col5, #T_f799b_row1_col6, #T_f799b_row1_col7, #T_f799b_row2_col3, #T_f799b_row2_col4, #T_f799b_row2_col5, #T_f799b_row2_col6, #T_f799b_row2_col7, #T_f799b_row3_col4, #T_f799b_row3_col5, #T_f799b_row3_col6, #T_f799b_row3_col7, #T_f799b_row4_col5, #T_f799b_row4_col6, #T_f799b_row4_col7, #T_f799b_row5_col6, #T_f799b_row5_col7, #T_f799b_row6_col7 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_f799b_row1_col1, #T_f799b_row2_col0 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_f799b_row3_col0 {
#   background-color: #b50927;
#   color: #f1f1f1;
# }
# #T_f799b_row3_col1, #T_f799b_row3_col2, #T_f799b_row7_col3, #T_f799b_row7_col4, #T_f799b_row7_col6 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# #T_f799b_row3_col3 {
#   background-color: #b70d28;
#   color: #f1f1f1;
# }
# #T_f799b_row4_col0, #T_f799b_row4_col3 {
#   background-color: #f6a385;
#   color: #000000;
# }
# #T_f799b_row4_col1, #T_f799b_row4_col2, #T_f799b_row7_col0 {
#   background-color: #f7bca1;
#   color: #000000;
# }
# #T_f799b_row4_col4 {
#   background-color: #f6a586;
#   color: #000000;
# }
# #T_f799b_row5_col0 {
#   background-color: #e0654f;
#   color: #f1f1f1;
# }
# #T_f799b_row5_col1, #T_f799b_row5_col2 {
#   background-color: #f29274;
#   color: #f1f1f1;
# }
# #T_f799b_row5_col3 {
#   background-color: #e16751;
#   color: #f1f1f1;
# }
# #T_f799b_row5_col4 {
#   background-color: #e26952;
#   color: #f1f1f1;
# }
# #T_f799b_row5_col5 {
#   background-color: #eb7d62;
#   color: #f1f1f1;
# }
# #T_f799b_row6_col0, #T_f799b_row6_col3 {
#   background-color: #f4987a;
#   color: #000000;
# }
# #T_f799b_row6_col1, #T_f799b_row6_col2 {
#   background-color: #e46e56;
#   color: #f1f1f1;
# }
# #T_f799b_row6_col4 {
#   background-color: #f59c7d;
#   color: #000000;
# }
# #T_f799b_row6_col5 {
#   background-color: #e36b54;
#   color: #f1f1f1;
# }
# #T_f799b_row6_col6 {
#   background-color: #dd5f4b;
#   color: #f1f1f1;
# }
# #T_f799b_row7_col1, #T_f799b_row7_col2 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_f799b_row7_col5 {
#   background-color: #f5c2aa;
#   color: #000000;
# }
# #T_f799b_row7_col7 {
#   background-color: #f5c4ac;
#   color: #000000;
# }
# </style>
# <table id="T_f799b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f799b_level0_col0" class="col_heading level0 col0" >true</th>
#       <th id="T_f799b_level0_col1" class="col_heading level0 col1" >optimal</th>
#       <th id="T_f799b_level0_col2" class="col_heading level0 col2" >cs_shift</th>
#       <th id="T_f799b_level0_col3" class="col_heading level0 col3" >NN1</th>
#       <th id="T_f799b_level0_col4" class="col_heading level0 col4" >NN2</th>
#       <th id="T_f799b_level0_col5" class="col_heading level0 col5" >transformer</th>
#       <th id="T_f799b_level0_col6" class="col_heading level0 col6" >transformer2</th>
#       <th id="T_f799b_level0_col7" class="col_heading level0 col7" >transformer3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f799b_level0_row0" class="row_heading level0 row0" >optimal</th>
#       <td id="T_f799b_row0_col0" class="data row0 col0" >0.313</td>
#       <td id="T_f799b_row0_col1" class="data row0 col1" >nan</td>
#       <td id="T_f799b_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_f799b_row0_col3" class="data row0 col3" >nan</td>
#       <td id="T_f799b_row0_col4" class="data row0 col4" >nan</td>
#       <td id="T_f799b_row0_col5" class="data row0 col5" >nan</td>
#       <td id="T_f799b_row0_col6" class="data row0 col6" >nan</td>
#       <td id="T_f799b_row0_col7" class="data row0 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_f799b_level0_row1" class="row_heading level0 row1" >cs_shift</th>
#       <td id="T_f799b_row1_col0" class="data row1 col0" >0.313</td>
#       <td id="T_f799b_row1_col1" class="data row1 col1" >1.000</td>
#       <td id="T_f799b_row1_col2" class="data row1 col2" >nan</td>
#       <td id="T_f799b_row1_col3" class="data row1 col3" >nan</td>
#       <td id="T_f799b_row1_col4" class="data row1 col4" >nan</td>
#       <td id="T_f799b_row1_col5" class="data row1 col5" >nan</td>
#       <td id="T_f799b_row1_col6" class="data row1 col6" >nan</td>
#       <td id="T_f799b_row1_col7" class="data row1 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_f799b_level0_row2" class="row_heading level0 row2" >NN1</th>
#       <td id="T_f799b_row2_col0" class="data row2 col0" >0.993</td>
#       <td id="T_f799b_row2_col1" class="data row2 col1" >0.313</td>
#       <td id="T_f799b_row2_col2" class="data row2 col2" >0.313</td>
#       <td id="T_f799b_row2_col3" class="data row2 col3" >nan</td>
#       <td id="T_f799b_row2_col4" class="data row2 col4" >nan</td>
#       <td id="T_f799b_row2_col5" class="data row2 col5" >nan</td>
#       <td id="T_f799b_row2_col6" class="data row2 col6" >nan</td>
#       <td id="T_f799b_row2_col7" class="data row2 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_f799b_level0_row3" class="row_heading level0 row3" >NN2</th>
#       <td id="T_f799b_row3_col0" class="data row3 col0" >0.991</td>
#       <td id="T_f799b_row3_col1" class="data row3 col1" >0.301</td>
#       <td id="T_f799b_row3_col2" class="data row3 col2" >0.301</td>
#       <td id="T_f799b_row3_col3" class="data row3 col3" >0.984</td>
#       <td id="T_f799b_row3_col4" class="data row3 col4" >nan</td>
#       <td id="T_f799b_row3_col5" class="data row3 col5" >nan</td>
#       <td id="T_f799b_row3_col6" class="data row3 col6" >nan</td>
#       <td id="T_f799b_row3_col7" class="data row3 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_f799b_level0_row4" class="row_heading level0 row4" >transformer</th>
#       <td id="T_f799b_row4_col0" class="data row4 col0" >0.452</td>
#       <td id="T_f799b_row4_col1" class="data row4 col1" >0.311</td>
#       <td id="T_f799b_row4_col2" class="data row4 col2" >0.311</td>
#       <td id="T_f799b_row4_col3" class="data row4 col3" >0.452</td>
#       <td id="T_f799b_row4_col4" class="data row4 col4" >0.440</td>
#       <td id="T_f799b_row4_col5" class="data row4 col5" >nan</td>
#       <td id="T_f799b_row4_col6" class="data row4 col6" >nan</td>
#       <td id="T_f799b_row4_col7" class="data row4 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_f799b_level0_row5" class="row_heading level0 row5" >transformer2</th>
#       <td id="T_f799b_row5_col0" class="data row5 col0" >0.729</td>
#       <td id="T_f799b_row5_col1" class="data row5 col1" >0.539</td>
#       <td id="T_f799b_row5_col2" class="data row5 col2" >0.539</td>
#       <td id="T_f799b_row5_col3" class="data row5 col3" >0.726</td>
#       <td id="T_f799b_row5_col4" class="data row5 col4" >0.717</td>
#       <td id="T_f799b_row5_col5" class="data row5 col5" >0.629</td>
#       <td id="T_f799b_row5_col6" class="data row5 col6" >nan</td>
#       <td id="T_f799b_row5_col7" class="data row5 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_f799b_level0_row6" class="row_heading level0 row6" >transformer3</th>
#       <td id="T_f799b_row6_col0" class="data row6 col0" >0.502</td>
#       <td id="T_f799b_row6_col1" class="data row6 col1" >0.693</td>
#       <td id="T_f799b_row6_col2" class="data row6 col2" >0.693</td>
#       <td id="T_f799b_row6_col3" class="data row6 col3" >0.501</td>
#       <td id="T_f799b_row6_col4" class="data row6 col4" >0.487</td>
#       <td id="T_f799b_row6_col5" class="data row6 col5" >0.710</td>
#       <td id="T_f799b_row6_col6" class="data row6 col6" >0.754</td>
#       <td id="T_f799b_row6_col7" class="data row6 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_f799b_level0_row7" class="row_heading level0 row7" >transformer4</th>
#       <td id="T_f799b_row7_col0" class="data row7 col0" >0.309</td>
#       <td id="T_f799b_row7_col1" class="data row7 col1" >0.114</td>
#       <td id="T_f799b_row7_col2" class="data row7 col2" >0.114</td>
#       <td id="T_f799b_row7_col3" class="data row7 col3" >0.304

# %%
comp.correl(z, mode='test')
# Out:
# /Users/gremy/Code/TSNN-1/tsnn-env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# <style type="text/css">
# #T_a4771_row0_col0, #T_a4771_row1_col0 {
#   background-color: #f7bca1;
#   color: #000000;
# }
# #T_a4771_row0_col1, #T_a4771_row0_col2, #T_a4771_row0_col3, #T_a4771_row0_col4, #T_a4771_row0_col5, #T_a4771_row0_col6, #T_a4771_row0_col7, #T_a4771_row1_col2, #T_a4771_row1_col3, #T_a4771_row1_col4, #T_a4771_row1_col5, #T_a4771_row1_col6, #T_a4771_row1_col7, #T_a4771_row2_col3, #T_a4771_row2_col4, #T_a4771_row2_col5, #T_a4771_row2_col6, #T_a4771_row2_col7, #T_a4771_row3_col4, #T_a4771_row3_col5, #T_a4771_row3_col6, #T_a4771_row3_col7, #T_a4771_row4_col5, #T_a4771_row4_col6, #T_a4771_row4_col7, #T_a4771_row5_col6, #T_a4771_row5_col7, #T_a4771_row6_col7 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_a4771_row1_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_a4771_row2_col0 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# #T_a4771_row2_col1, #T_a4771_row2_col2 {
#   background-color: #f7b194;
#   color: #000000;
# }
# #T_a4771_row3_col0 {
#   background-color: #f4c6af;
#   color: #000000;
# }
# #T_a4771_row3_col1, #T_a4771_row3_col2 {
#   background-color: #f6a586;
#   color: #000000;
# }
# #T_a4771_row3_col3 {
#   background-color: #f4987a;
#   color: #000000;
# }
# #T_a4771_row4_col0 {
#   background-color: #f6bfa6;
#   color: #000000;
# }
# #T_a4771_row4_col1, #T_a4771_row4_col2 {
#   background-color: #f5c1a9;
#   color: #000000;
# }
# #T_a4771_row4_col3 {
#   background-color: #f49a7b;
#   color: #000000;
# }
# #T_a4771_row4_col4, #T_a4771_row6_col3 {
#   background-color: #f59d7e;
#   color: #000000;
# }
# #T_a4771_row5_col0 {
#   background-color: #f7ba9f;
#   color: #000000;
# }
# #T_a4771_row5_col1, #T_a4771_row5_col2 {
#   background-color: #f08a6c;
#   color: #f1f1f1;
# }
# #T_a4771_row5_col3 {
#   background-color: #f7a98b;
#   color: #000000;
# }
# #T_a4771_row5_col4 {
#   background-color: #f59c7d;
#   color: #000000;
# }
# #T_a4771_row5_col5, #T_a4771_row6_col4 {
#   background-color: #ee8669;
#   color: #f1f1f1;
# }
# #T_a4771_row6_col0 {
#   background-color: #f7af91;
#   color: #000000;
# }
# #T_a4771_row6_col1, #T_a4771_row6_col2 {
#   background-color: #e46e56;
#   color: #f1f1f1;
# }
# #T_a4771_row6_col5 {
#   background-color: #e7745b;
#   color: #f1f1f1;
# }
# #T_a4771_row6_col6 {
#   background-color: #dc5d4a;
#   color: #f1f1f1;
# }
# #T_a4771_row7_col0 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_a4771_row7_col1, #T_a4771_row7_col2 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_a4771_row7_col3 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_a4771_row7_col4 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_a4771_row7_col5 {
#   background-color: #efcebd;
#   color: #000000;
# }
# #T_a4771_row7_col6, #T_a4771_row7_col7 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# </style>
# <table id="T_a4771">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a4771_level0_col0" class="col_heading level0 col0" >true</th>
#       <th id="T_a4771_level0_col1" class="col_heading level0 col1" >optimal</th>
#       <th id="T_a4771_level0_col2" class="col_heading level0 col2" >cs_shift</th>
#       <th id="T_a4771_level0_col3" class="col_heading level0 col3" >NN1</th>
#       <th id="T_a4771_level0_col4" class="col_heading level0 col4" >NN2</th>
#       <th id="T_a4771_level0_col5" class="col_heading level0 col5" >transformer</th>
#       <th id="T_a4771_level0_col6" class="col_heading level0 col6" >transformer2</th>
#       <th id="T_a4771_level0_col7" class="col_heading level0 col7" >transformer3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a4771_level0_row0" class="row_heading level0 row0" >optimal</th>
#       <td id="T_a4771_row0_col0" class="data row0 col0" >0.308</td>
#       <td id="T_a4771_row0_col1" class="data row0 col1" >nan</td>
#       <td id="T_a4771_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_a4771_row0_col3" class="data row0 col3" >nan</td>
#       <td id="T_a4771_row0_col4" class="data row0 col4" >nan</td>
#       <td id="T_a4771_row0_col5" class="data row0 col5" >nan</td>
#       <td id="T_a4771_row0_col6" class="data row0 col6" >nan</td>
#       <td id="T_a4771_row0_col7" class="data row0 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_a4771_level0_row1" class="row_heading level0 row1" >cs_shift</th>
#       <td id="T_a4771_row1_col0" class="data row1 col0" >0.308</td>
#       <td id="T_a4771_row1_col1" class="data row1 col1" >1.000</td>
#       <td id="T_a4771_row1_col2" class="data row1 col2" >nan</td>
#       <td id="T_a4771_row1_col3" class="data row1 col3" >nan</td>
#       <td id="T_a4771_row1_col4" class="data row1 col4" >nan</td>
#       <td id="T_a4771_row1_col5" class="data row1 col5" >nan</td>
#       <td id="T_a4771_row1_col6" class="data row1 col6" >nan</td>
#       <td id="T_a4771_row1_col7" class="data row1 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_a4771_level0_row2" class="row_heading level0 row2" >NN1</th>
#       <td id="T_a4771_row2_col0" class="data row2 col0" >0.208</td>
#       <td id="T_a4771_row2_col1" class="data row2 col1" >0.369</td>
#       <td id="T_a4771_row2_col2" class="data row2 col2" >0.369</td>
#       <td id="T_a4771_row2_col3" class="data row2 col3" >nan</td>
#       <td id="T_a4771_row2_col4" class="data row2 col4" >nan</td>
#       <td id="T_a4771_row2_col5" class="data row2 col5" >nan</td>
#       <td id="T_a4771_row2_col6" class="data row2 col6" >nan</td>
#       <td id="T_a4771_row2_col7" class="data row2 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_a4771_level0_row3" class="row_heading level0 row3" >NN2</th>
#       <td id="T_a4771_row3_col0" class="data row3 col0" >0.237</td>
#       <td id="T_a4771_row3_col1" class="data row3 col1" >0.440</td>
#       <td id="T_a4771_row3_col2" class="data row3 col2" >0.440</td>
#       <td id="T_a4771_row3_col3" class="data row3 col3" >0.508</td>
#       <td id="T_a4771_row3_col4" class="data row3 col4" >nan</td>
#       <td id="T_a4771_row3_col5" class="data row3 col5" >nan</td>
#       <td id="T_a4771_row3_col6" class="data row3 col6" >nan</td>
#       <td id="T_a4771_row3_col7" class="data row3 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_a4771_level0_row4" class="row_heading level0 row4" >transformer</th>
#       <td id="T_a4771_row4_col0" class="data row4 col0" >0.285</td>
#       <td id="T_a4771_row4_col1" class="data row4 col1" >0.268</td>
#       <td id="T_a4771_row4_col2" class="data row4 col2" >0.268</td>
#       <td id="T_a4771_row4_col3" class="data row4 col3" >0.494</td>
#       <td id="T_a4771_row4_col4" class="data row4 col4" >0.483</td>
#       <td id="T_a4771_row4_col5" class="data row4 col5" >nan</td>
#       <td id="T_a4771_row4_col6" class="data row4 col6" >nan</td>
#       <td id="T_a4771_row4_col7" class="data row4 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_a4771_level0_row5" class="row_heading level0 row5" >transformer2</th>
#       <td id="T_a4771_row5_col0" class="data row5 col0" >0.318</td>
#       <td id="T_a4771_row5_col1" class="data row5 col1" >0.572</td>
#       <td id="T_a4771_row5_col2" class="data row5 col2" >0.572</td>
#       <td id="T_a4771_row5_col3" class="data row5 col3" >0.414</td>
#       <td id="T_a4771_row5_col4" class="data row5 col4" >0.486</td>
#       <td id="T_a4771_row5_col5" class="data row5 col5" >0.593</td>
#       <td id="T_a4771_row5_col6" class="data row5 col6" >nan</td>
#       <td id="T_a4771_row5_col7" class="data row5 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_a4771_level0_row6" class="row_heading level0 row6" >transformer3</th>
#       <td id="T_a4771_row6_col0" class="data row6 col0" >0.384</td>
#       <td id="T_a4771_row6_col1" class="data row6 col1" >0.691</td>
#       <td id="T_a4771_row6_col2" class="data row6 col2" >0.691</td>
#       <td id="T_a4771_row6_col3" class="data row6 col3" >0.482</td>
#       <td id="T_a4771_row6_col4" class="data row6 col4" >0.588</td>
#       <td id="T_a4771_row6_col5" class="data row6 col5" >0.668</td>
#       <td id="T_a4771_row6_col6" class="data row6 col6" >0.760</td>
#       <td id="T_a4771_row6_col7" class="data row6 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_a4771_level0_row7" class="row_heading level0 row7" >transformer4</th>
#       <td id="T_

# %% [markdown]
# ## conditional effect

# %%
# @dataclass
# class Config:
#     T: int = 3000
#     n_ts: int = 50
#     n_f: int = 10
#     pct_zero_corr: float = 0.5
#     split_conditional: float = 0.25
#     split_shift: float = 0.25
#     split_seasonal: float = 0.
#     split_cs: float = 0.25
#     split_cs_shift: float = 0.25
#     low_corr: float = 0.1
#     high_corr: float = 0.2

@dataclass
class Config:
    T: int = 3000
    n_ts: int = 10
    n_f: int = 10
    pct_zero_corr: float = 0.5
    split_conditional: float = 1.0
    split_shift: float = 0.
    split_seasonal: float = 0.
    split_cs: float = 0.
    split_cs_shift: float = 0.
    low_corr: float = 0.1
    high_corr: float = 0.2

# %%
z = generators.Generator(Config.T, Config.n_ts, Config.n_f)

# %%
# %%time
z.generate_dataset(pct_zero_corr = Config.pct_zero_corr,
                  split_conditional = Config.split_conditional,
                  split_shift = Config.split_shift,
                  split_seasonal = Config.split_seasonal,
                  split_cs=Config.split_cs,
                  split_cs_shift=Config.split_cs_shift,
                  low_corr=Config.low_corr, 
                  high_corr=Config.high_corr)
# Out:
# CPU times: user 11.9 ms, sys: 10.6 ms, total: 22.5 ms
# Wall time: 28.3 ms

# %%
z.get_dataloader(n_rolling=10)

# %%
m = GlobalMLP(Config.n_ts, Config.n_f, 10, dropout=0.2).to(device)
optimizer = torch.optim.Adam(m.parameters(), lr=0.001)
#optimizer = torch.optim.SGD(m.parameters(), lr=1e-3)

model_nn1 = torch_benchmarks.TorchWrapper(m, optimizer=optimizer)
model_nn1.fit(z.train, test=z.test, epochs=100)
# Out:
# 100%|██████████| 100/100 [00:10<00:00,  9.14it/s]

# %%
m = PerSeriesThenGlobalMLP(Config.n_ts, Config.n_f, 10, dropout=0.2).to(device)
optimizer = torch.optim.AdamW(m.parameters(), lr=0.001)
#optimizer = torch.optim.SGD(m.parameters(), lr=1e-3)

model_nn2 = torch_benchmarks.TorchWrapper(m, optimizer=optimizer)
model_nn2.fit(z.train, test=z.test, epochs=100)
# Out:
# 100%|██████████| 100/100 [00:15<00:00,  6.39it/s]

# %%
m = TransformerEncoderModel(Config.n_ts, Config.n_f, 10, dropout=0.5).to(device)
optimizer = torch.optim.AdamW(m.parameters(), lr=0.001)
#optimizer = torch.optim.SGD(m.parameters(), lr=1e-3)


model_torch = torch_benchmarks.TorchWrapper(m, optimizer=optimizer)
model_torch.fit(z.train, test=z.test, epochs=80)
# Out:
# 100%|██████████| 80/80 [00:16<00:00,  4.73it/s]

# %%
m = DualAttentionTransformer(Config.n_ts, Config.n_f, 10, d_model=128, dim_feedforward=512, dropout=0.2, num_layers_series=2, num_layers_time=2).to(device)
optimizer = torch.optim.AdamW(m.parameters(), lr=0.001)
#optimizer = torch.optim.SGD(m.parameters(), lr=1e-3)


model_torch2 = torch_benchmarks.TorchWrapper(m, optimizer=optimizer)
model_torch2.fit(z.train, test=z.test, epochs=40)
# Out:
# 100%|██████████| 40/40 [00:42<00:00,  1.07s/it]

# %%
m = MLPSpatioTransformer(Config.n_ts, Config.n_f, 10, d_model=128, dim_feedforward=512, dropout=0.5, num_layers=2, mlp_layers=2).to(device)
optimizer = torch.optim.AdamW(m.parameters(), lr=0.001)
# optimizer = torch.optim.SGD(m.parameters(), lr=1e-3)


model_torch3 = torch_benchmarks.TorchWrapper(m, optimizer=optimizer)
model_torch3.fit(z.train, test=z.test, epochs=60)
# Out:
# /Users/gremy/Code/TSNN-1/tsnn-env/lib/python3.11/site-packages/torch/nn/modules/transformer.py:392: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   warnings.warn(
# 100%|██████████| 60/60 [00:12<00:00,  4.77it/s]

# %%
m = AlternatingDualAttentionTransformer(Config.n_ts, Config.n_f, 10, d_model=128, dim_feedforward=512, dropout=0.5, num_layers=2).to(device)
optimizer = torch.optim.AdamW(m.parameters(), lr=0.001)
# optimizer = torch.optim.SGD(m.parameters(), lr=1e-3)


model_torch4 = torch_benchmarks.TorchWrapper(m, optimizer=optimizer)
model_torch4.fit(z.train, test=z.test, epochs=60)
# Out:
# 100%|██████████| 60/60 [01:54<00:00,  1.92s/it]

# %%
comp = benchmark_comparison.Comparator(models=[model_nn1, model_nn2, model_torch, model_torch2, model_torch3, model_torch4],
                                        model_names=['NN1', 'NN2', 'transformer', 'transformer2', 'transformer3', 'transformer4'])

# %%
comp.correl(z, mode='train')
# Out:
# /Users/gremy/Code/TSNN-1/tsnn-env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# <style type="text/css">
# #T_a953a_row0_col0, #T_a953a_row1_col0, #T_a953a_row2_col1, #T_a953a_row2_col2, #T_a953a_row3_col1, #T_a953a_row3_col2 {
#   background-color: #f7b79b;
#   color: #000000;
# }
# #T_a953a_row0_col1, #T_a953a_row0_col2, #T_a953a_row0_col3, #T_a953a_row0_col4, #T_a953a_row0_col5, #T_a953a_row0_col6, #T_a953a_row0_col7, #T_a953a_row1_col2, #T_a953a_row1_col3, #T_a953a_row1_col4, #T_a953a_row1_col5, #T_a953a_row1_col6, #T_a953a_row1_col7, #T_a953a_row2_col3, #T_a953a_row2_col4, #T_a953a_row2_col5, #T_a953a_row2_col6, #T_a953a_row2_col7, #T_a953a_row3_col4, #T_a953a_row3_col5, #T_a953a_row3_col6, #T_a953a_row3_col7, #T_a953a_row4_col5, #T_a953a_row4_col6, #T_a953a_row4_col7, #T_a953a_row5_col6, #T_a953a_row5_col7, #T_a953a_row6_col7 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_a953a_row1_col1, #T_a953a_row2_col0 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_a953a_row3_col0 {
#   background-color: #b50927;
#   color: #f1f1f1;
# }
# #T_a953a_row3_col3 {
#   background-color: #b70d28;
#   color: #f1f1f1;
# }
# #T_a953a_row4_col0 {
#   background-color: #c12b30;
#   color: #f1f1f1;
# }
# #T_a953a_row4_col1, #T_a953a_row4_col2 {
#   background-color: #f7b99e;
#   color: #000000;
# }
# #T_a953a_row4_col3 {
#   background-color: #c32e31;
#   color: #f1f1f1;
# }
# #T_a953a_row4_col4 {
#   background-color: #c43032;
#   color: #f1f1f1;
# }
# #T_a953a_row5_col0, #T_a953a_row5_col3 {
#   background-color: #ec8165;
#   color: #f1f1f1;
# }
# #T_a953a_row5_col1, #T_a953a_row5_col2 {
#   background-color: #ef886b;
#   color: #f1f1f1;
# }
# #T_a953a_row5_col4 {
#   background-color: #ed8366;
#   color: #f1f1f1;
# }
# #T_a953a_row5_col5 {
#   background-color: #ee8468;
#   color: #f1f1f1;
# }
# #T_a953a_row6_col0 {
#   background-color: #f6a283;
#   color: #000000;
# }
# #T_a953a_row6_col1, #T_a953a_row6_col2 {
#   background-color: #f7aa8c;
#   color: #000000;
# }
# #T_a953a_row6_col3, #T_a953a_row6_col4 {
#   background-color: #f6a385;
#   color: #000000;
# }
# #T_a953a_row6_col5 {
#   background-color: #f6a586;
#   color: #000000;
# }
# #T_a953a_row6_col6 {
#   background-color: #f29274;
#   color: #f1f1f1;
# }
# #T_a953a_row7_col0, #T_a953a_row7_col3, #T_a953a_row7_col4, #T_a953a_row7_col5 {
#   background-color: #f4c6af;
#   color: #000000;
# }
# #T_a953a_row7_col1, #T_a953a_row7_col2 {
#   background-color: #f39577;
#   color: #000000;
# }
# #T_a953a_row7_col6 {
#   background-color: #f59f80;
#   color: #000000;
# }
# #T_a953a_row7_col7 {
#   background-color: #f7a98b;
#   color: #000000;
# }
# </style>
# <table id="T_a953a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a953a_level0_col0" class="col_heading level0 col0" >true</th>
#       <th id="T_a953a_level0_col1" class="col_heading level0 col1" >optimal</th>
#       <th id="T_a953a_level0_col2" class="col_heading level0 col2" >conditional</th>
#       <th id="T_a953a_level0_col3" class="col_heading level0 col3" >NN1</th>
#       <th id="T_a953a_level0_col4" class="col_heading level0 col4" >NN2</th>
#       <th id="T_a953a_level0_col5" class="col_heading level0 col5" >transformer</th>
#       <th id="T_a953a_level0_col6" class="col_heading level0 col6" >transformer2</th>
#       <th id="T_a953a_level0_col7" class="col_heading level0 col7" >transformer3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a953a_level0_row0" class="row_heading level0 row0" >optimal</th>
#       <td id="T_a953a_row0_col0" class="data row0 col0" >0.340</td>
#       <td id="T_a953a_row0_col1" class="data row0 col1" >nan</td>
#       <td id="T_a953a_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_a953a_row0_col3" class="data row0 col3" >nan</td>
#       <td id="T_a953a_row0_col4" class="data row0 col4" >nan</td>
#       <td id="T_a953a_row0_col5" class="data row0 col5" >nan</td>
#       <td id="T_a953a_row0_col6" class="data row0 col6" >nan</td>
#       <td id="T_a953a_row0_col7" class="data row0 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_a953a_level0_row1" class="row_heading level0 row1" >conditional</th>
#       <td id="T_a953a_row1_col0" class="data row1 col0" >0.340</td>
#       <td id="T_a953a_row1_col1" class="data row1 col1" >1.000</td>
#       <td id="T_a953a_row1_col2" class="data row1 col2" >nan</td>
#       <td id="T_a953a_row1_col3" class="data row1 col3" >nan</td>
#       <td id="T_a953a_row1_col4" class="data row1 col4" >nan</td>
#       <td id="T_a953a_row1_col5" class="data row1 col5" >nan</td>
#       <td id="T_a953a_row1_col6" class="data row1 col6" >nan</td>
#       <td id="T_a953a_row1_col7" class="data row1 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_a953a_level0_row2" class="row_heading level0 row2" >NN1</th>
#       <td id="T_a953a_row2_col0" class="data row2 col0" >0.993</td>
#       <td id="T_a953a_row2_col1" class="data row2 col1" >0.339</td>
#       <td id="T_a953a_row2_col2" class="data row2 col2" >0.339</td>
#       <td id="T_a953a_row2_col3" class="data row2 col3" >nan</td>
#       <td id="T_a953a_row2_col4" class="data row2 col4" >nan</td>
#       <td id="T_a953a_row2_col5" class="data row2 col5" >nan</td>
#       <td id="T_a953a_row2_col6" class="data row2 col6" >nan</td>
#       <td id="T_a953a_row2_col7" class="data row2 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_a953a_level0_row3" class="row_heading level0 row3" >NN2</th>
#       <td id="T_a953a_row3_col0" class="data row3 col0" >0.991</td>
#       <td id="T_a953a_row3_col1" class="data row3 col1" >0.337</td>
#       <td id="T_a953a_row3_col2" class="data row3 col2" >0.337</td>
#       <td id="T_a953a_row3_col3" class="data row3 col3" >0.983</td>
#       <td id="T_a953a_row3_col4" class="data row3 col4" >nan</td>
#       <td id="T_a953a_row3_col5" class="data row3 col5" >nan</td>
#       <td id="T_a953a_row3_col6" class="data row3 col6" >nan</td>
#       <td id="T_a953a_row3_col7" class="data row3 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_a953a_level0_row4" class="row_heading level0 row4" >transformer</th>
#       <td id="T_a953a_row4_col0" class="data row4 col0" >0.923</td>
#       <td id="T_a953a_row4_col1" class="data row4 col1" >0.327</td>
#       <td id="T_a953a_row4_col2" class="data row4 col2" >0.327</td>
#       <td id="T_a953a_row4_col3" class="data row4 col3" >0.917</td>
#       <td id="T_a953a_row4_col4" class="data row4 col4" >0.913</td>
#       <td id="T_a953a_row4_col5" class="data row4 col5" >nan</td>
#       <td id="T_a953a_row4_col6" class="data row4 col6" >nan</td>
#       <td id="T_a953a_row4_col7" class="data row4 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_a953a_level0_row5" class="row_heading level0 row5" >transformer2</th>
#       <td id="T_a953a_row5_col0" class="data row5 col0" >0.615</td>
#       <td id="T_a953a_row5_col1" class="data row5 col1" >0.581</td>
#       <td id="T_a953a_row5_col2" class="data row5 col2" >0.581</td>
#       <td id="T_a953a_row5_col3" class="data row5 col3" >0.611</td>
#       <td id="T_a953a_row5_col4" class="data row5 col4" >0.608</td>
#       <td id="T_a953a_row5_col5" class="data row5 col5" >0.599</td>
#       <td id="T_a953a_row5_col6" class="data row5 col6" >nan</td>
#       <td id="T_a953a_row5_col7" class="data row5 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_a953a_level0_row6" class="row_heading level0 row6" >transformer3</th>
#       <td id="T_a953a_row6_col0" class="data row6 col0" >0.456</td>
#       <td id="T_a953a_row6_col1" class="data row6 col1" >0.408</td>
#       <td id="T_a953a_row6_col2" class="data row6 col2" >0.408</td>
#       <td id="T_a953a_row6_col3" class="data row6 col3" >0.452</td>
#       <td id="T_a953a_row6_col4" class="data row6 col4" >0.450</td>
#       <td id="T_a953a_row6_col5" class="data row6 col5" >0.441</td>
#       <td id="T_a953a_row6_col6" class="data row6 col6" >0.535</td>
#       <td id="T_a953a_row6_col7" class="data row6 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_a953a_level0_row7" class="row_heading level0 row7" >transformer4</th>
#       <td id="T_a953a_row7_col0" class="data row7 col0" >0.236</td>
#       <td id="T_a953a_row7_col1" class="data row7 col1" >0.516</td>
#       <td id="T_a953a_row7_col2" class="data row7 col2" >0.516</td>
#       <td id="T_a953a_row7_col3" class="data row7 col3"

# %%
comp.correl(z, mode='test')
# Out:
# /Users/gremy/Code/TSNN-1/tsnn-env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# <style type="text/css">
# #T_c9adf_row0_col0, #T_c9adf_row1_col0, #T_c9adf_row3_col3, #T_c9adf_row4_col3 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_c9adf_row0_col1, #T_c9adf_row0_col2, #T_c9adf_row0_col3, #T_c9adf_row0_col4, #T_c9adf_row0_col5, #T_c9adf_row0_col6, #T_c9adf_row0_col7, #T_c9adf_row1_col2, #T_c9adf_row1_col3, #T_c9adf_row1_col4, #T_c9adf_row1_col5, #T_c9adf_row1_col6, #T_c9adf_row1_col7, #T_c9adf_row2_col3, #T_c9adf_row2_col4, #T_c9adf_row2_col5, #T_c9adf_row2_col6, #T_c9adf_row2_col7, #T_c9adf_row3_col4, #T_c9adf_row3_col5, #T_c9adf_row3_col6, #T_c9adf_row3_col7, #T_c9adf_row4_col5, #T_c9adf_row4_col6, #T_c9adf_row4_col7, #T_c9adf_row5_col6, #T_c9adf_row5_col7, #T_c9adf_row6_col7 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_c9adf_row1_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_c9adf_row2_col0, #T_c9adf_row2_col1, #T_c9adf_row2_col2 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_c9adf_row3_col0, #T_c9adf_row7_col3 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_c9adf_row3_col1, #T_c9adf_row3_col2, #T_c9adf_row4_col1, #T_c9adf_row4_col2 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_c9adf_row4_col0 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_c9adf_row4_col4 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# #T_c9adf_row5_col0 {
#   background-color: #f0cdbb;
#   color: #000000;
# }
# #T_c9adf_row5_col1, #T_c9adf_row5_col2 {
#   background-color: #f18d6f;
#   color: #f1f1f1;
# }
# #T_c9adf_row5_col3 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_c9adf_row5_col4, #T_c9adf_row6_col4 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_c9adf_row5_col5 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_c9adf_row6_col0, #T_c9adf_row6_col3 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_c9adf_row6_col1, #T_c9adf_row6_col2 {
#   background-color: #f7b99e;
#   color: #000000;
# }
# #T_c9adf_row6_col5 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_c9adf_row6_col6 {
#   background-color: #f7a98b;
#   color: #000000;
# }
# #T_c9adf_row7_col0 {
#   background-color: #efcebd;
#   color: #000000;
# }
# #T_c9adf_row7_col1, #T_c9adf_row7_col2 {
#   background-color: #f49a7b;
#   color: #000000;
# }
# #T_c9adf_row7_col4 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_c9adf_row7_col5 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_c9adf_row7_col6 {
#   background-color: #f59d7e;
#   color: #000000;
# }
# #T_c9adf_row7_col7 {
#   background-color: #f7b093;
#   color: #000000;
# }
# </style>
# <table id="T_c9adf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c9adf_level0_col0" class="col_heading level0 col0" >true</th>
#       <th id="T_c9adf_level0_col1" class="col_heading level0 col1" >optimal</th>
#       <th id="T_c9adf_level0_col2" class="col_heading level0 col2" >conditional</th>
#       <th id="T_c9adf_level0_col3" class="col_heading level0 col3" >NN1</th>
#       <th id="T_c9adf_level0_col4" class="col_heading level0 col4" >NN2</th>
#       <th id="T_c9adf_level0_col5" class="col_heading level0 col5" >transformer</th>
#       <th id="T_c9adf_level0_col6" class="col_heading level0 col6" >transformer2</th>
#       <th id="T_c9adf_level0_col7" class="col_heading level0 col7" >transformer3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c9adf_level0_row0" class="row_heading level0 row0" >optimal</th>
#       <td id="T_c9adf_row0_col0" class="data row0 col0" >0.334</td>
#       <td id="T_c9adf_row0_col1" class="data row0 col1" >nan</td>
#       <td id="T_c9adf_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_c9adf_row0_col3" class="data row0 col3" >nan</td>
#       <td id="T_c9adf_row0_col4" class="data row0 col4" >nan</td>
#       <td id="T_c9adf_row0_col5" class="data row0 col5" >nan</td>
#       <td id="T_c9adf_row0_col6" class="data row0 col6" >nan</td>
#       <td id="T_c9adf_row0_col7" class="data row0 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_c9adf_level0_row1" class="row_heading level0 row1" >conditional</th>
#       <td id="T_c9adf_row1_col0" class="data row1 col0" >0.334</td>
#       <td id="T_c9adf_row1_col1" class="data row1 col1" >1.000</td>
#       <td id="T_c9adf_row1_col2" class="data row1 col2" >nan</td>
#       <td id="T_c9adf_row1_col3" class="data row1 col3" >nan</td>
#       <td id="T_c9adf_row1_col4" class="data row1 col4" >nan</td>
#       <td id="T_c9adf_row1_col5" class="data row1 col5" >nan</td>
#       <td id="T_c9adf_row1_col6" class="data row1 col6" >nan</td>
#       <td id="T_c9adf_row1_col7" class="data row1 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_c9adf_level0_row2" class="row_heading level0 row2" >NN1</th>
#       <td id="T_c9adf_row2_col0" class="data row2 col0" >0.019</td>
#       <td id="T_c9adf_row2_col1" class="data row2 col1" >0.016</td>
#       <td id="T_c9adf_row2_col2" class="data row2 col2" >0.016</td>
#       <td id="T_c9adf_row2_col3" class="data row2 col3" >nan</td>
#       <td id="T_c9adf_row2_col4" class="data row2 col4" >nan</td>
#       <td id="T_c9adf_row2_col5" class="data row2 col5" >nan</td>
#       <td id="T_c9adf_row2_col6" class="data row2 col6" >nan</td>
#       <td id="T_c9adf_row2_col7" class="data row2 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_c9adf_level0_row3" class="row_heading level0 row3" >NN2</th>
#       <td id="T_c9adf_row3_col0" class="data row3 col0" >0.025</td>
#       <td id="T_c9adf_row3_col1" class="data row3 col1" >0.033</td>
#       <td id="T_c9adf_row3_col2" class="data row3 col2" >0.033</td>
#       <td id="T_c9adf_row3_col3" class="data row3 col3" >0.335</td>
#       <td id="T_c9adf_row3_col4" class="data row3 col4" >nan</td>
#       <td id="T_c9adf_row3_col5" class="data row3 col5" >nan</td>
#       <td id="T_c9adf_row3_col6" class="data row3 col6" >nan</td>
#       <td id="T_c9adf_row3_col7" class="data row3 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_c9adf_level0_row4" class="row_heading level0 row4" >transformer</th>
#       <td id="T_c9adf_row4_col0" class="data row4 col0" >0.007</td>
#       <td id="T_c9adf_row4_col1" class="data row4 col1" >0.039</td>
#       <td id="T_c9adf_row4_col2" class="data row4 col2" >0.039</td>
#       <td id="T_c9adf_row4_col3" class="data row4 col3" >0.330</td>
#       <td id="T_c9adf_row4_col4" class="data row4 col4" >0.148</td>
#       <td id="T_c9adf_row4_col5" class="data row4 col5" >nan</td>
#       <td id="T_c9adf_row4_col6" class="data row4 col6" >nan</td>
#       <td id="T_c9adf_row4_col7" class="data row4 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_c9adf_level0_row5" class="row_heading level0 row5" >transformer2</th>
#       <td id="T_c9adf_row5_col0" class="data row5 col0" >0.172</td>
#       <td id="T_c9adf_row5_col1" class="data row5 col1" >0.557</td>
#       <td id="T_c9adf_row5_col2" class="data row5 col2" >0.557</td>
#       <td id="T_c9adf_row5_col3" class="data row5 col3" >0.080</td>
#       <td id="T_c9adf_row5_col4" class="data row5 col4" >0.044</td>
#       <td id="T_c9adf_row5_col5" class="data row5 col5" >0.136</td>
#       <td id="T_c9adf_row5_col6" class="data row5 col6" >nan</td>
#       <td id="T_c9adf_row5_col7" class="data row5 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_c9adf_level0_row6" class="row_heading level0 row6" >transformer3</th>
#       <td id="T_c9adf_row6_col0" class="data row6 col0" >0.104</td>
#       <td id="T_c9adf_row6_col1" class="data row6 col1" >0.325</td>
#       <td id="T_c9adf_row6_col2" class="data row6 col2" >0.325</td>
#       <td id="T_c9adf_row6_col3" class="data row6 col3" >0.106</td>
#       <td id="T_c9adf_row6_col4" class="data row6 col4" >0.046</td>
#       <td id="T_c9adf_row6_col5" class="data row6 col5" >0.075</td>
#       <td id="T_c9adf_row6_col6" class="data row6 col6" >0.421</td>
#       <td id="T_c9adf_row6_col7" class="data row6 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_c9adf_level0_row7" class="row_heading level0 row7" >transformer4</th>
#       <td id="T_c9adf_row7_col0" class="data row7 col0" >0.165</td>
#       <td id="T_c9adf_row7_col1" class="data row7 col1" >0.494</td>
#       <td id="T_c9adf_row7_col2" class="data row7 col2" >0.494</td>

# %% [markdown]
# # Testing the sparse attention

# %% [markdown]
# ## Basic setup

# %%
@dataclass
class Config:
    T: int = 3000
    n_ts: int = 10
    n_f: int = 10
    pct_zero_corr: float = 0.5
    split_conditional: float = 0.
    split_shift: float = 0.
    split_seasonal: float = 0.
    split_cs: float = 0.
    split_cs_shift: float = 1.0
    low_corr: float = 0.1
    high_corr: float = 0.2

# %%
z = generators.Generator(Config.T, Config.n_ts, Config.n_f)

# %%
# %%time
z.generate_dataset(pct_zero_corr = Config.pct_zero_corr,
                  split_conditional = Config.split_conditional,
                  split_shift = Config.split_shift,
                  split_seasonal = Config.split_seasonal,
                  split_cs=Config.split_cs,
                  split_cs_shift=Config.split_cs_shift,
                  low_corr=Config.low_corr, 
                  high_corr=Config.high_corr)
# Out:
# CPU times: user 9.65 ms, sys: 2.69 ms, total: 12.3 ms
# Wall time: 11.1 ms

# %%
z.get_dataloader(n_rolling=10)

# %%
def causal_mask(b, h, q_idx, kv_idx):
    return q_idx >= kv_idx

# def causal_mask(b, h, q_idx, kv_idx):
#     return q_idx >= (kv_idx+100)

def plot_mask(mask_fn, seq_len=20, title=None, device="cpu"):
    """
    Plot a binary attention mask defined by mask_fn(b,h,q_idx,kv_idx)
    as a (seq_len x seq_len) matrix.
    """
    q_idx = torch.arange(seq_len, device=device)
    kv_idx = torch.arange(seq_len, device=device)
    b = torch.zeros(1, device=device) 
    h = torch.zeros(1, device=device)

    mask = mask_fn(b, h, q_idx[:, None], kv_idx[None, :])
    mask = mask.float().cpu()

    return pd.DataFrame(mask).style.background_gradient(axis=None).format(precision=0)

def build_attention_mask(mask_fn, seq_len, device="cpu"):
    q_idx = torch.arange(seq_len, device=device)
    kv_idx = torch.arange(seq_len, device=device)
    b = torch.zeros(1, device=device)
    h = torch.zeros(1, device=device)
    mask_bool = mask_fn(b, h, q_idx[:, None], kv_idx[None, :])  # (seq_len, seq_len)
    return mask_bool

# %%
mask_fn = causal_mask
plot_mask(mask_fn, seq_len=5)
# Out:
# <style type="text/css">
# #T_969b5_row0_col0, #T_969b5_row1_col0, #T_969b5_row1_col1, #T_969b5_row2_col0, #T_969b5_row2_col1, #T_969b5_row2_col2, #T_969b5_row3_col0, #T_969b5_row3_col1, #T_969b5_row3_col2, #T_969b5_row3_col3, #T_969b5_row4_col0, #T_969b5_row4_col1, #T_969b5_row4_col2, #T_969b5_row4_col3, #T_969b5_row4_col4 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_969b5_row0_col1, #T_969b5_row0_col2, #T_969b5_row0_col3, #T_969b5_row0_col4, #T_969b5_row1_col2, #T_969b5_row1_col3, #T_969b5_row1_col4, #T_969b5_row2_col3, #T_969b5_row2_col4, #T_969b5_row3_col4 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_969b5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_969b5_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_969b5_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_969b5_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_969b5_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_969b5_level0_col4" class="col_heading level0 col4" >4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_969b5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_969b5_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_969b5_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_969b5_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_969b5_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_969b5_row0_col4" class="data row0 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_969b5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_969b5_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_969b5_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_969b5_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_969b5_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_969b5_row1_col4" class="data row1 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_969b5_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_969b5_row2_col0" class="data row2 col0" >1</td>
#       <td id="T_969b5_row2_col1" class="data row2 col1" >1</td>
#       <td id="T_969b5_row2_col2" class="data row2 col2" >1</td>
#       <td id="T_969b5_row2_col3" class="data row2 col3" >0</td>
#       <td id="T_969b5_row2_col4" class="data row2 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_969b5_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_969b5_row3_col0" class="data row3 col0" >1</td>
#       <td id="T_969b5_row3_col1" class="data row3 col1" >1</td>
#       <td id="T_969b5_row3_col2" class="data row3 col2" >1</td>
#       <td id="T_969b5_row3_col3" class="data row3 col3" >1</td>
#       <td id="T_969b5_row3_col4" class="data row3 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_969b5_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_969b5_row4_col0" class="data row4 col0" >1</td>
#       <td id="T_969b5_row4_col1" class="data row4 col1" >1</td>
#       <td id="T_969b5_row4_col2" class="data row4 col2" >1</td>
#       <td id="T_969b5_row4_col3" class="data row4 col3" >1</td>
#       <td id="T_969b5_row4_col4" class="data row4 col4" >1</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Models with sparse attention

# %%
from torch.nn.attention.flex_attention import BlockMask, _mask_mod_signature, and_masks, or_masks


class TransformerEncoderModelSparse(nn.Module):
    def __init__(self, n_ts, n_f, n_rolling, mask, mask_=None, d_model=128, nhead=8, num_layers=2, dropout=0.5, attn_l1_coeff=0, sparsify=None):
        super().__init__()
        self.mask = mask
        self.sparsify = sparsify
        self.input_dim = n_ts * n_f
        self.d_model = d_model

        # Linear projection of (n_ts*n_f) features
        self.input_proj = nn.Linear(self.input_dim, d_model)

        # Positional encoding (learned or sinusoidal)
        self.pos_embedding = nn.Parameter(torch.randn(1, n_rolling, d_model))

        # Transformer encoder
        encoder_layer = transformers.TransformerEncoderLayer(
            d_model=d_model,
            nhead=nhead,
            dim_feedforward = 4 * d_model,
            dropout=dropout,
        )
        self.encoder = transformers.TransformerEncoder(encoder_layer, num_layers=num_layers)

        # prediction
        self.decoder = nn.Sequential(
            nn.LayerNorm(d_model),
            nn.Linear(d_model, n_ts)
        )
        
        self.decoder = nn.Sequential(
            # nn.LayerNorm(d_model),
            # nn.Linear(d_model, d_model),
            # nn.ReLU(),
            # nn.Dropout(0.2),
            nn.Linear(d_model, n_ts),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(n_ts, n_ts)
        )
        

    def forward(self, x, mask=None):
        # x: (batch, n_rolling, n_ts, n_f)
        B, n_rolling, n_ts, n_f = x.shape

        # Flatten dimensions that are not lookback
        x = x.reshape(B, n_rolling, n_ts*n_f)
        x = self.input_proj(x) + self.pos_embedding[:, :n_rolling, :]

        encoded = self.encoder(x, mask=self.mask, sparsify=self.sparsify)  

        # last time step’s embedding for prediction
        out = self.decoder(encoded[:, -1, :])  # (B, N)
        return out

# %%
# Transformer model with both TS then CS attention.

class DualAttentionTransformerSparse(nn.Module):
    def __init__(
        self,
        n_ts,          # number of time series (N)
        n_f,           # number of input features per timestamp
        n_rolling,     # lookback window length (T)
        mask,
        d_model=128,
        nhead_time=8,      # heads for temporal attention (stage 1)
        nhead_series=8,    # heads for cross-series attention (stage 2)
        num_layers_time=1,
        num_layers_series=1,
        dim_feedforward=512,
        dropout=0.8,
        sparsify=None
    ):
        super().__init__()
        
        self.n_ts = n_ts
        self.n_rolling = n_rolling
        self.d_model = d_model

        self.mask = mask
        self.sparsify = sparsify
        # ------------------------------------------------------------------
        # 1. Input projection: (n_f) → d_model  (shared across all series & timesteps)
        # ------------------------------------------------------------------
        self.input_proj = nn.Linear(n_f, d_model)

        # Positional encoding for the temporal dimension (stage 1)
        self.pos_emb_time = nn.Parameter(torch.randn(1, n_rolling, d_model))
        # self.pos_emb_time = torch.arange(1, n_rolling)

        # ------------------------------------------------------------------
        # Stage 1: Temporal Transformer (attention over time, independent per series)
        # ------------------------------------------------------------------
        temporal_layer = transformers.TransformerEncoderLayer(
            d_model=d_model,
            nhead=nhead_time,
            dim_feedforward=dim_feedforward,
            dropout=dropout,
            # activation="gelu",
        )
        self.temporal_transformer = transformers.TransformerEncoder(
            temporal_layer, num_layers=num_layers_time
        )

        # ------------------------------------------------------------------
        # Stage 2: Cross-Series Transformer (attention over the N series)
        # ------------------------------------------------------------------
        series_layer = transformers.TransformerEncoderLayer(
            d_model=d_model,
            nhead=nhead_series,
            dim_feedforward=dim_feedforward,
            dropout=dropout,
            # activation="gelu",
        )
        self.series_transformer = transformers.TransformerEncoder(
            series_layer, num_layers=num_layers_series
        )

        # Optional positional encoding for the series dimension
        # (can be learned or fixed; here learned)
        
        self.pos_emb_series = nn.Parameter(torch.randn(1, n_ts, d_model))
        # self.pos_emb_series = torch.arange(1, n_ts)

        # ------------------------------------------------------------------
        # Final prediction head: d_model → 1 (forecast scalar per series)
        # ------------------------------------------------------------------
        self.output_head = nn.Sequential(
            nn.LayerNorm(d_model),
            nn.ReLU(),
            nn.Dropout(dropout),
            nn.Linear(d_model, 1)
        )

    def forward(self, x):
        """
        x : (B, n_rolling, n_ts, n_f)   float tensor
        Returns: (B, n_ts)               predicted scalar for each series
        """
        B, T, N, F = x.shape  # T = n_rolling, N = n_ts, F = n_f

        # ------------------------------------------------------------------
        # 1. Project features → d_model
        # ------------------------------------------------------------------
        # (B, T, N, F) → (B, T, N, d_model)
        x = self.input_proj(x)

        # ------------------------------------------------------------------
        # 2. Reshape so that batch × series becomes the new "batch"
        #    → (B*N, T, d_model)
        # ------------------------------------------------------------------
        x = x.permute(0, 2, 1, 3).reshape(B * N, T, self.d_model)  # (B*N, T, d_model)

        # Add temporal positional encoding
        x = x + self.pos_emb_time[:, :T, :]

        # ------------------------------------------------------------------
        # 3. Temporal Transformer (causal attention over time)
        # ------------------------------------------------------------------
        # x = self.temporal_transformer(x, mask=self.causal_mask_time)  # (B*N, T, d_model)
        x = self.temporal_transformer(x, mask=self.mask, sparsify=self.sparsify)  # (B*N, T, d_model)

        # Take the last timestep representation
        x_last = x[:, -1, :]  # (B*N, d_model)

        # ------------------------------------------------------------------
        # 4. Reshape back to have series dimension explicit
        #    → (B, N, d_model)
        # ------------------------------------------------------------------
        x_series = x_last.view(B, N, self.d_model)

        # Add series positional encoding
        x_series = x_series + self.pos_emb_series

        # ------------------------------------------------------------------
        # 5. Cross-Series Transformer (full attention over the N series)
        # ------------------------------------------------------------------
        # No mask needed here → full bidirectional attention across series
        x_series = self.series_transformer(x_series, sparsify=self.sparsify)  # (B, N, d_model)

        # ------------------------------------------------------------------
        # 6. Final prediction
        # ------------------------------------------------------------------
        out = self.output_head(x_series)      # (B, N, 1)
        out = out.squeeze(-1)                 # (B, N) = (B, n_ts)

        return out

# %%
# MLP in the TS dimension, then transformer in CS dimension.

class MLPSpatioTransformerSparse(nn.Module):
    """
    Architecture:
    1. Treat each series independently → collapse (T, F) → d_model via shared MLP
    2. Reshape to (B, N, d_model)
    3. Apply Transformer with attention over the N series (cross-series communication)
    4. Predict one scalar per series from the final d_model representations
    """
    def __init__(
        self,
        n_ts,              # N: number of time series
        n_f,               # F: number of input features
        n_rolling,         # T: lookback length
        d_model=256,
        nhead=8,
        num_layers=2,
        dim_feedforward=512,
        dropout=0.8,
        mlp_layers=3,      # depth of the per-series MLP
        sparsify=None
    ):
        super().__init__()
        
        self.n_ts = n_ts
        self.n_rolling = n_rolling
        self.d_model = d_model

        self.sparsify = sparsify

        # --------------------------------------------------------------
        # 1. Per-series MLP: processes each (T, F) window independently
        #    Input size per series: T * F
        # --------------------------------------------------------------
        input_dim = n_rolling * n_f
        mlp = []
        dim = input_dim
        
        for i in range(mlp_layers):
            mlp.extend([
                nn.Linear(dim, d_model),
                nn.GELU(),
                nn.LayerNorm(d_model),
                nn.Dropout(dropout)
            ])
            dim = d_model
            
        # Final projection to exact d_model (in case of residual connections or skip)
        mlp.append(nn.Linear(dim, d_model))
        self.per_series_mlp = nn.Sequential(*mlp)

        # --------------------------------------------------------------
        # 2. Positional encoding for the series dimension (N)
        #    (learned, because series usually don't have natural ordering)
        # --------------------------------------------------------------
        self.pos_embedding = nn.Parameter(torch.randn(1, n_ts, d_model))

        # --------------------------------------------------------------
        # 3. Cross-series Transformer (attention over the N dimension)
        # --------------------------------------------------------------

        encoder_layer = transformers.TransformerEncoderLayer(
            d_model=d_model,
            nhead=nhead,
            dim_feedforward=dim_feedforward,
            dropout=dropout,
            # activation="gelu",
        )
        self.transformer = transformers.TransformerEncoder(
            encoder_layer, num_layers=num_layers
        )

        # --------------------------------------------------------------
        # 4. Final prediction head: d_model → 1
        # --------------------------------------------------------------
        self.output_head = nn.Sequential(
            nn.LayerNorm(d_model),
            nn.GELU(),
            nn.Dropout(dropout),
            nn.Linear(d_model, 1)
        )

    def forward(self, x):
        """
        x : (B, T, N, F)
        Returns: (B, N)
        """
        B, T, N, F = x.shape

        # --------------------------------------------------------------
        # 1. Reshape so each series is a separate sample
        #    (B, T, N, F) → (B*N, T*F)
        # --------------------------------------------------------------
        x = x.permute(0, 2, 1, 3).reshape(B * N, T * F)   # (B*N, T*F)

        # --------------------------------------------------------------
        # 2. Per-series MLP encoding
        # --------------------------------------------------------------
        h = self.per_series_mlp(x)                        # (B*N, d_model)

        # --------------------------------------------------------------
        # 3. Reshape back to explicit series dimension
        #    (B*N, d_model) → (B, N, d_model)
        # --------------------------------------------------------------
        h = h.view(B, N, self.d_model)

        # Add learned positional encoding for the series axis
        h = h + self.pos_embedding

        # --------------------------------------------------------------
        # 4. Cross-series Transformer (full bidirectional attention over N)
        # --------------------------------------------------------------
        h = self.transformer(h, sparsify=self.sparsify) # (B, N, d_model)
        # --------------------------------------------------------------
        # 5. Final prediction
        # --------------------------------------------------------------
        out = self.output_head(h)                         # (B, N, 1)
        out = out.squeeze(-1)                             # (B, N)

        return out

# %%
# Lets add one more model, alternating TS and CS transformers.
class AlternatingDualAttentionTransformerSparse(nn.Module):
    def __init__(
        self,
        n_ts,
        n_f,
        n_rolling,
        mask,
        d_model=128,
        nhead=8,
        num_layers=2,
        dim_feedforward=512,
        dropout=0.1,
        sparsify=None
    ):
        super().__init__()
        self.d_model = d_model
        self.n_rolling = n_rolling
        self.n_ts = n_ts

        self.mask = mask
        self.sparsify = sparsify

        self.input_proj = nn.Linear(n_f, d_model)

        # ←←← THIS IS THE FIX ←←←
        self.pos_emb_time   = nn.Parameter(torch.randn(1, 1, d_model))   # broadcasts over T
        self.pos_emb_series = nn.Parameter(torch.randn(1, 1, d_model))   # broadcasts over N


        self.dropout = nn.Dropout(dropout)

        self.blocks = nn.ModuleList()
        for _ in range(num_layers):
            temp = transformers.TransformerEncoder(
                transformers.TransformerEncoderLayer(
                d_model=d_model,
                nhead=nhead,
                dim_feedforward=dim_feedforward,
                dropout=dropout,
                # activation="gelu",
                ), num_layers=1
            )
            series = transformers.TransformerEncoder(
                transformers.TransformerEncoderLayer(
                d_model=d_model,
                nhead=nhead,
                dim_feedforward=dim_feedforward,
                dropout=dropout,
                # activation="gelu",
                ), num_layers=1
            )
            self.blocks.append(nn.ModuleDict({
                'temporal': temp,
                'series': series,
                'norm1': nn.LayerNorm(d_model),
                'norm2': nn.LayerNorm(d_model),
            }))

        self.register_buffer("causal_mask",
                             torch.triu(torch.ones(n_rolling, n_rolling), diagonal=1).bool())

        self.output_head = nn.Sequential(
            nn.LayerNorm(d_model),
            nn.GELU(),
            nn.Dropout(dropout),
            nn.Linear(d_model, 1)
        )

    def forward(self, x):
        B, T, N, _ = x.shape

        x = self.input_proj(x)                                  # (B,T,N,d_model)

        # ←←← NOW SAFE ←←←
        x = x + self.pos_emb_time + self.pos_emb_series

        for block in self.blocks:
            # Temporal
            res = x
            x = x.permute(0, 2, 1, 3).reshape(B*N, T, self.d_model)
            x = block['temporal'](x,  mask=self.mask, sparsify=self.sparsify)
            x = x.reshape(B, N, T, self.d_model).permute(0, 2, 1, 3)
            x = block['norm1'](res + self.dropout(x))

            # Cross-series
            res = x
            x = x.reshape(B*T, N, self.d_model)
            x = block['series'](x,  sparsify=self.sparsify)
            x = x.reshape(B, T, N, self.d_model)
            x = block['norm2'](res + self.dropout(x))

        # Take last timestep
        x = x[:, -1, :, :]                                      # (B, N, d_model)
        return self.output_head(x).squeeze(-1)

# %% [markdown]
# ## Running the models

# %%
mask = causal_mask
mask = build_attention_mask(mask, 10, device=device)
def custom_mask_mod(b, h, q_idx, kv_idx):
    return mask[q_idx, kv_idx]

m = TransformerEncoderModelSparse(Config.n_ts, Config.n_f, 10, mask=mask, dropout=0.5, num_layers=1, sparsify=None).to(device)
optimizer = torch.optim.AdamW(m.parameters(), lr=0.001)
# optimizer = torch.optim.SGD(m.parameters(), lr=0.001)


model_causal = torch_benchmarks.TorchWrapper(m, optimizer=optimizer)

# %%
model_causal.fit(z.train, test=z.test, epochs=100)
# Out:
# 100%|██████████| 100/100 [00:17<00:00,  5.82it/s]

# %%
# Function used to make the attention matrix sparse

def keep_topk_per_row(x, k=2):
    vals, idx = torch.topk(x, k=k, dim=-1, largest=True)
    out = torch.zeros_like(x)
    out.scatter_(-1, idx, 1)
    return out

# %%
mask = causal_mask
mask = build_attention_mask(mask, 10, device=device)
def custom_mask_mod(b, h, q_idx, kv_idx):
    return mask[q_idx, kv_idx]

m = TransformerEncoderModelSparse(Config.n_ts, Config.n_f, 10, mask=mask, dropout=0.5, num_layers=1, sparsify=keep_topk_per_row).to(device)
optimizer = torch.optim.AdamW(m.parameters(), lr=0.001)
# optimizer = torch.optim.SGD(m.parameters(), lr=0.001)


model_sparse = torch_benchmarks.TorchWrapper(m, optimizer=optimizer)

# %%
model_sparse.fit(z.train, test=z.test, epochs=200)
# Out:
# 100%|██████████| 200/200 [00:32<00:00,  6.12it/s]

# %%
mask = causal_mask
mask = build_attention_mask(mask, 10, device=device)
def custom_mask_mod(b, h, q_idx, kv_idx):
    return mask[q_idx, kv_idx]

m = DualAttentionTransformerSparse(Config.n_ts, Config.n_f, 10, mask=mask, dropout=0.5, dim_feedforward=128, sparsify=None).to(device)
optimizer = torch.optim.AdamW(m.parameters(), lr=0.001)
# optimizer = torch.optim.SGD(m.parameters(), lr=0.001)


model_causal2 = torch_benchmarks.TorchWrapper(m, optimizer=optimizer)

# %%
mask = causal_mask
mask = build_attention_mask(mask, 10, device=device)
def custom_mask_mod(b, h, q_idx, kv_idx):
    return mask[q_idx, kv_idx]

m = DualAttentionTransformerSparse(Config.n_ts, Config.n_f, 10, mask=mask, dropout=0.5, dim_feedforward=128, sparsify=keep_topk_per_row).to(device)
optimizer = torch.optim.AdamW(m.parameters(), lr=0.001)
# optimizer = torch.optim.SGD(m.parameters(), lr=0.001)


model_sparse2 = torch_benchmarks.TorchWrapper(m, optimizer=optimizer)

# %%
model_causal2.fit(z.train, test=z.test, epochs=100)
# Out:
# 100%|██████████| 100/100 [00:45<00:00,  2.20it/s]

# %%
model_sparse2.fit(z.train, test=z.test, epochs=200)
# Out:
# 100%|██████████| 200/200 [01:33<00:00,  2.13it/s]

# %%
m = MLPSpatioTransformerSparse(Config.n_ts, Config.n_f, 10, d_model=128, dim_feedforward=512, dropout=0.5, 
                               num_layers=2, mlp_layers=2, sparsify=keep_topk_per_row).to(device)
optimizer = torch.optim.AdamW(m.parameters(), lr=0.001)
# optimizer = torch.optim.SGD(m.parameters(), lr=1e-3)


model_sparse3 = torch_benchmarks.TorchWrapper(m, optimizer=optimizer)
model_sparse3.fit(z.train, test=z.test, epochs=100)
# Out:
# 100%|██████████| 100/100 [00:27<00:00,  3.69it/s]

# %%
m = AlternatingDualAttentionTransformerSparse(Config.n_ts, Config.n_f, 10, mask=mask, d_model=128, dim_feedforward=512, 
                                              dropout=0.5, num_layers=2, sparsify=keep_topk_per_row).to(device)
optimizer = torch.optim.AdamW(m.parameters(), lr=0.001)
# optimizer = torch.optim.SGD(m.parameters(), lr=1e-3)


model_sparse4 = torch_benchmarks.TorchWrapper(m, optimizer=optimizer)
model_sparse4.fit(z.train, test=z.test, epochs=200)
# Out:
# 100%|██████████| 200/200 [05:59<00:00,  1.80s/it]

# %%
comp = benchmark_comparison.Comparator(models=[model_causal, model_sparse, model_causal2, model_sparse2, model_sparse3, model_sparse4], 
                                        model_names=['causal', 'sparse', 'causal2', 'sparse2', 'sparse3', 'sparse4'])

# %%
comp.correl(z, mode='train')
# Out:
# /Users/gremy/Code/TSNN-1/tsnn-env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# <style type="text/css">
# #T_a1473_row0_col0, #T_a1473_row1_col0 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_a1473_row0_col1, #T_a1473_row0_col2, #T_a1473_row0_col3, #T_a1473_row0_col4, #T_a1473_row0_col5, #T_a1473_row0_col6, #T_a1473_row0_col7, #T_a1473_row1_col2, #T_a1473_row1_col3, #T_a1473_row1_col4, #T_a1473_row1_col5, #T_a1473_row1_col6, #T_a1473_row1_col7, #T_a1473_row2_col3, #T_a1473_row2_col4, #T_a1473_row2_col5, #T_a1473_row2_col6, #T_a1473_row2_col7, #T_a1473_row3_col4, #T_a1473_row3_col5, #T_a1473_row3_col6, #T_a1473_row3_col7, #T_a1473_row4_col5, #T_a1473_row4_col6, #T_a1473_row4_col7, #T_a1473_row5_col6, #T_a1473_row5_col7, #T_a1473_row6_col7 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_a1473_row1_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_a1473_row2_col0 {
#   background-color: #e8765c;
#   color: #f1f1f1;
# }
# #T_a1473_row2_col1, #T_a1473_row2_col2 {
#   background-color: #f5c4ac;
#   color: #000000;
# }
# #T_a1473_row3_col0 {
#   background-color: #d85646;
#   color: #f1f1f1;
# }
# #T_a1473_row3_col1, #T_a1473_row3_col2 {
#   background-color: #f5c1a9;
#   color: #000000;
# }
# #T_a1473_row3_col3 {
#   background-color: #ed8366;
#   color: #f1f1f1;
# }
# #T_a1473_row4_col0 {
#   background-color: #f6a385;
#   color: #000000;
# }
# #T_a1473_row4_col1, #T_a1473_row4_col2 {
#   background-color: #ec8165;
#   color: #f1f1f1;
# }
# #T_a1473_row4_col3, #T_a1473_row5_col4 {
#   background-color: #f6a586;
#   color: #000000;
# }
# #T_a1473_row4_col4 {
#   background-color: #f5a081;
#   color: #000000;
# }
# #T_a1473_row5_col0 {
#   background-color: #f7a98b;
#   color: #000000;
# }
# #T_a1473_row5_col1, #T_a1473_row5_col2 {
#   background-color: #f6a283;
#   color: #000000;
# }
# #T_a1473_row5_col3 {
#   background-color: #f7a889;
#   color: #000000;
# }
# #T_a1473_row5_col5 {
#   background-color: #e57058;
#   color: #f1f1f1;
# }
# #T_a1473_row6_col0 {
#   background-color: #f08b6e;
#   color: #f1f1f1;
# }
# #T_a1473_row6_col1, #T_a1473_row6_col2 {
#   background-color: #ef886b;
#   color: #f1f1f1;
# }
# #T_a1473_row6_col3 {
#   background-color: #f59c7d;
#   color: #000000;
# }
# #T_a1473_row6_col4 {
#   background-color: #f29274;
#   color: #f1f1f1;
# }
# #T_a1473_row6_col5 {
#   background-color: #dd5f4b;
#   color: #f1f1f1;
# }
# #T_a1473_row6_col6 {
#   background-color: #e97a5f;
#   color: #f1f1f1;
# }
# #T_a1473_row7_col0 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_a1473_row7_col1, #T_a1473_row7_col2 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_a1473_row7_col3 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# #T_a1473_row7_col4 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_a1473_row7_col5, #T_a1473_row7_col6 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# #T_a1473_row7_col7 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# </style>
# <table id="T_a1473">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a1473_level0_col0" class="col_heading level0 col0" >true</th>
#       <th id="T_a1473_level0_col1" class="col_heading level0 col1" >optimal</th>
#       <th id="T_a1473_level0_col2" class="col_heading level0 col2" >cs_shift</th>
#       <th id="T_a1473_level0_col3" class="col_heading level0 col3" >causal</th>
#       <th id="T_a1473_level0_col4" class="col_heading level0 col4" >sparse</th>
#       <th id="T_a1473_level0_col5" class="col_heading level0 col5" >causal2</th>
#       <th id="T_a1473_level0_col6" class="col_heading level0 col6" >sparse2</th>
#       <th id="T_a1473_level0_col7" class="col_heading level0 col7" >sparse3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a1473_level0_row0" class="row_heading level0 row0" >optimal</th>
#       <td id="T_a1473_row0_col0" class="data row0 col0" >0.296</td>
#       <td id="T_a1473_row0_col1" class="data row0 col1" >nan</td>
#       <td id="T_a1473_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_a1473_row0_col3" class="data row0 col3" >nan</td>
#       <td id="T_a1473_row0_col4" class="data row0 col4" >nan</td>
#       <td id="T_a1473_row0_col5" class="data row0 col5" >nan</td>
#       <td id="T_a1473_row0_col6" class="data row0 col6" >nan</td>
#       <td id="T_a1473_row0_col7" class="data row0 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_a1473_level0_row1" class="row_heading level0 row1" >cs_shift</th>
#       <td id="T_a1473_row1_col0" class="data row1 col0" >0.296</td>
#       <td id="T_a1473_row1_col1" class="data row1 col1" >1.000</td>
#       <td id="T_a1473_row1_col2" class="data row1 col2" >nan</td>
#       <td id="T_a1473_row1_col3" class="data row1 col3" >nan</td>
#       <td id="T_a1473_row1_col4" class="data row1 col4" >nan</td>
#       <td id="T_a1473_row1_col5" class="data row1 col5" >nan</td>
#       <td id="T_a1473_row1_col6" class="data row1 col6" >nan</td>
#       <td id="T_a1473_row1_col7" class="data row1 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_a1473_level0_row2" class="row_heading level0 row2" >causal</th>
#       <td id="T_a1473_row2_col0" class="data row2 col0" >0.662</td>
#       <td id="T_a1473_row2_col1" class="data row2 col1" >0.254</td>
#       <td id="T_a1473_row2_col2" class="data row2 col2" >0.254</td>
#       <td id="T_a1473_row2_col3" class="data row2 col3" >nan</td>
#       <td id="T_a1473_row2_col4" class="data row2 col4" >nan</td>
#       <td id="T_a1473_row2_col5" class="data row2 col5" >nan</td>
#       <td id="T_a1473_row2_col6" class="data row2 col6" >nan</td>
#       <td id="T_a1473_row2_col7" class="data row2 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_a1473_level0_row3" class="row_heading level0 row3" >sparse</th>
#       <td id="T_a1473_row3_col0" class="data row3 col0" >0.783</td>
#       <td id="T_a1473_row3_col1" class="data row3 col1" >0.266</td>
#       <td id="T_a1473_row3_col2" class="data row3 col2" >0.266</td>
#       <td id="T_a1473_row3_col3" class="data row3 col3" >0.606</td>
#       <td id="T_a1473_row3_col4" class="data row3 col4" >nan</td>
#       <td id="T_a1473_row3_col5" class="data row3 col5" >nan</td>
#       <td id="T_a1473_row3_col6" class="data row3 col6" >nan</td>
#       <td id="T_a1473_row3_col7" class="data row3 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_a1473_level0_row4" class="row_heading level0 row4" >causal2</th>
#       <td id="T_a1473_row4_col0" class="data row4 col0" >0.449</td>
#       <td id="T_a1473_row4_col1" class="data row4 col1" >0.615</td>
#       <td id="T_a1473_row4_col2" class="data row4 col2" >0.615</td>
#       <td id="T_a1473_row4_col3" class="data row4 col3" >0.441</td>
#       <td id="T_a1473_row4_col4" class="data row4 col4" >0.465</td>
#       <td id="T_a1473_row4_col5" class="data row4 col5" >nan</td>
#       <td id="T_a1473_row4_col6" class="data row4 col6" >nan</td>
#       <td id="T_a1473_row4_col7" class="data row4 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_a1473_level0_row5" class="row_heading level0 row5" >sparse2</th>
#       <td id="T_a1473_row5_col0" class="data row5 col0" >0.422</td>
#       <td id="T_a1473_row5_col1" class="data row5 col1" >0.460</td>
#       <td id="T_a1473_row5_col2" class="data row5 col2" >0.460</td>
#       <td id="T_a1473_row5_col3" class="data row5 col3" >0.429</td>
#       <td id="T_a1473_row5_col4" class="data row5 col4" >0.443</td>
#       <td id="T_a1473_row5_col5" class="data row5 col5" >0.681</td>
#       <td id="T_a1473_row5_col6" class="data row5 col6" >nan</td>
#       <td id="T_a1473_row5_col7" class="data row5 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_a1473_level0_row6" class="row_heading level0 row6" >sparse3</th>
#       <td id="T_a1473_row6_col0" class="data row6 col0" >0.567</td>
#       <td id="T_a1473_row6_col1" class="data row6 col1" >0.586</td>
#       <td id="T_a1473_row6_col2" class="data row6 col2" >0.586</td>
#       <td id="T_a1473_row6_col3" class="data row6 col3" >0.491</td>
#       <td id="T_a1473_row6_col4" class="data row6 col4" >0.536</td>
#       <td id="T_a1473_row6_col5" class="data row6 col5" >0.755</td>
#       <td id="T_a1473_row6_col6" class="data row6 col6" >0.648</td>
#       <td id="T_a1473_row6_col7" class="data row6 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_a1473_level0_row7" class="row_heading level0 row7" >

# %%
comp.correl(z, mode='test')
# Out:
# /Users/gremy/Code/TSNN-1/tsnn-env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# <style type="text/css">
# #T_70cf7_row0_col0, #T_70cf7_row1_col0 {
#   background-color: #f7bca1;
#   color: #000000;
# }
# #T_70cf7_row0_col1, #T_70cf7_row0_col2, #T_70cf7_row0_col3, #T_70cf7_row0_col4, #T_70cf7_row0_col5, #T_70cf7_row0_col6, #T_70cf7_row0_col7, #T_70cf7_row1_col2, #T_70cf7_row1_col3, #T_70cf7_row1_col4, #T_70cf7_row1_col5, #T_70cf7_row1_col6, #T_70cf7_row1_col7, #T_70cf7_row2_col3, #T_70cf7_row2_col4, #T_70cf7_row2_col5, #T_70cf7_row2_col6, #T_70cf7_row2_col7, #T_70cf7_row3_col4, #T_70cf7_row3_col5, #T_70cf7_row3_col6, #T_70cf7_row3_col7, #T_70cf7_row4_col5, #T_70cf7_row4_col6, #T_70cf7_row4_col7, #T_70cf7_row5_col6, #T_70cf7_row5_col7, #T_70cf7_row6_col7 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_70cf7_row1_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_70cf7_row2_col0 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_70cf7_row2_col1, #T_70cf7_row2_col2 {
#   background-color: #f1ccb8;
#   color: #000000;
# }
# #T_70cf7_row3_col0, #T_70cf7_row7_col5 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# #T_70cf7_row3_col1, #T_70cf7_row3_col2 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_70cf7_row3_col3, #T_70cf7_row5_col1, #T_70cf7_row5_col2 {
#   background-color: #f5a081;
#   color: #000000;
# }
# #T_70cf7_row4_col0 {
#   background-color: #f7b396;
#   color: #000000;
# }
# #T_70cf7_row4_col1, #T_70cf7_row4_col2 {
#   background-color: #ec8165;
#   color: #f1f1f1;
# }
# #T_70cf7_row4_col3 {
#   background-color: #f7a889;
#   color: #000000;
# }
# #T_70cf7_row4_col4 {
#   background-color: #f6a385;
#   color: #000000;
# }
# #T_70cf7_row5_col0 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# #T_70cf7_row5_col3 {
#   background-color: #f7ad90;
#   color: #000000;
# }
# #T_70cf7_row5_col4, #T_70cf7_row6_col4 {
#   background-color: #f7a98b;
#   color: #000000;
# }
# #T_70cf7_row5_col5 {
#   background-color: #e8765c;
#   color: #f1f1f1;
# }
# #T_70cf7_row6_col0 {
#   background-color: #f7b99e;
#   color: #000000;
# }
# #T_70cf7_row6_col1, #T_70cf7_row6_col2 {
#   background-color: #ee8468;
#   color: #f1f1f1;
# }
# #T_70cf7_row6_col3 {
#   background-color: #f7af91;
#   color: #000000;
# }
# #T_70cf7_row6_col5 {
#   background-color: #de614d;
#   color: #f1f1f1;
# }
# #T_70cf7_row6_col6 {
#   background-color: #ec7f63;
#   color: #f1f1f1;
# }
# #T_70cf7_row7_col0 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_70cf7_row7_col1, #T_70cf7_row7_col2 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_70cf7_row7_col3 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_70cf7_row7_col4 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_70cf7_row7_col6 {
#   background-color: #f3c8b2;
#   color: #000000;
# }
# #T_70cf7_row7_col7 {
#   background-color: #f3c7b1;
#   color: #000000;
# }
# </style>
# <table id="T_70cf7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_70cf7_level0_col0" class="col_heading level0 col0" >true</th>
#       <th id="T_70cf7_level0_col1" class="col_heading level0 col1" >optimal</th>
#       <th id="T_70cf7_level0_col2" class="col_heading level0 col2" >cs_shift</th>
#       <th id="T_70cf7_level0_col3" class="col_heading level0 col3" >causal</th>
#       <th id="T_70cf7_level0_col4" class="col_heading level0 col4" >sparse</th>
#       <th id="T_70cf7_level0_col5" class="col_heading level0 col5" >causal2</th>
#       <th id="T_70cf7_level0_col6" class="col_heading level0 col6" >sparse2</th>
#       <th id="T_70cf7_level0_col7" class="col_heading level0 col7" >sparse3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_70cf7_level0_row0" class="row_heading level0 row0" >optimal</th>
#       <td id="T_70cf7_row0_col0" class="data row0 col0" >0.309</td>
#       <td id="T_70cf7_row0_col1" class="data row0 col1" >nan</td>
#       <td id="T_70cf7_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_70cf7_row0_col3" class="data row0 col3" >nan</td>
#       <td id="T_70cf7_row0_col4" class="data row0 col4" >nan</td>
#       <td id="T_70cf7_row0_col5" class="data row0 col5" >nan</td>
#       <td id="T_70cf7_row0_col6" class="data row0 col6" >nan</td>
#       <td id="T_70cf7_row0_col7" class="data row0 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_70cf7_level0_row1" class="row_heading level0 row1" >cs_shift</th>
#       <td id="T_70cf7_row1_col0" class="data row1 col0" >0.309</td>
#       <td id="T_70cf7_row1_col1" class="data row1 col1" >1.000</td>
#       <td id="T_70cf7_row1_col2" class="data row1 col2" >nan</td>
#       <td id="T_70cf7_row1_col3" class="data row1 col3" >nan</td>
#       <td id="T_70cf7_row1_col4" class="data row1 col4" >nan</td>
#       <td id="T_70cf7_row1_col5" class="data row1 col5" >nan</td>
#       <td id="T_70cf7_row1_col6" class="data row1 col6" >nan</td>
#       <td id="T_70cf7_row1_col7" class="data row1 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_70cf7_level0_row2" class="row_heading level0 row2" >causal</th>
#       <td id="T_70cf7_row2_col0" class="data row2 col0" >0.187</td>
#       <td id="T_70cf7_row2_col1" class="data row2 col1" >0.190</td>
#       <td id="T_70cf7_row2_col2" class="data row2 col2" >0.190</td>
#       <td id="T_70cf7_row2_col3" class="data row2 col3" >nan</td>
#       <td id="T_70cf7_row2_col4" class="data row2 col4" >nan</td>
#       <td id="T_70cf7_row2_col5" class="data row2 col5" >nan</td>
#       <td id="T_70cf7_row2_col6" class="data row2 col6" >nan</td>
#       <td id="T_70cf7_row2_col7" class="data row2 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_70cf7_level0_row3" class="row_heading level0 row3" >sparse</th>
#       <td id="T_70cf7_row3_col0" class="data row3 col0" >0.209</td>
#       <td id="T_70cf7_row3_col1" class="data row3 col1" >0.200</td>
#       <td id="T_70cf7_row3_col2" class="data row3 col2" >0.200</td>
#       <td id="T_70cf7_row3_col3" class="data row3 col3" >0.463</td>
#       <td id="T_70cf7_row3_col4" class="data row3 col4" >nan</td>
#       <td id="T_70cf7_row3_col5" class="data row3 col5" >nan</td>
#       <td id="T_70cf7_row3_col6" class="data row3 col6" >nan</td>
#       <td id="T_70cf7_row3_col7" class="data row3 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_70cf7_level0_row4" class="row_heading level0 row4" >causal2</th>
#       <td id="T_70cf7_row4_col0" class="data row4 col0" >0.365</td>
#       <td id="T_70cf7_row4_col1" class="data row4 col1" >0.617</td>
#       <td id="T_70cf7_row4_col2" class="data row4 col2" >0.617</td>
#       <td id="T_70cf7_row4_col3" class="data row4 col3" >0.425</td>
#       <td id="T_70cf7_row4_col4" class="data row4 col4" >0.451</td>
#       <td id="T_70cf7_row4_col5" class="data row4 col5" >nan</td>
#       <td id="T_70cf7_row4_col6" class="data row4 col6" >nan</td>
#       <td id="T_70cf7_row4_col7" class="data row4 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_70cf7_level0_row5" class="row_heading level0 row5" >sparse2</th>
#       <td id="T_70cf7_row5_col0" class="data row5 col0" >0.301</td>
#       <td id="T_70cf7_row5_col1" class="data row5 col1" >0.461</td>
#       <td id="T_70cf7_row5_col2" class="data row5 col2" >0.461</td>
#       <td id="T_70cf7_row5_col3" class="data row5 col3" >0.395</td>
#       <td id="T_70cf7_row5_col4" class="data row5 col4" >0.416</td>
#       <td id="T_70cf7_row5_col5" class="data row5 col5" >0.663</td>
#       <td id="T_70cf7_row5_col6" class="data row5 col6" >nan</td>
#       <td id="T_70cf7_row5_col7" class="data row5 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_70cf7_level0_row6" class="row_heading level0 row6" >sparse3</th>
#       <td id="T_70cf7_row6_col0" class="data row6 col0" >0.324</td>
#       <td id="T_70cf7_row6_col1" class="data row6 col1" >0.594</td>
#       <td id="T_70cf7_row6_col2" class="data row6 col2" >0.594</td>
#       <td id="T_70cf7_row6_col3" class="data row6 col3" >0.384</td>
#       <td id="T_70cf7_row6_col4" class="data row6 col4" >0.418</td>
#       <td id="T_70cf7_row6_col5" class="data row6 col5" >0.745</td>
#       <td id="T_70cf7_row6_col6" class="data row6 col6" >0.622</td>
#       <td id="T_70cf7_row6_col7" class="data row6 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_70cf7_level0_row7" class="row_heading level0 row7" >sparse4</th>
#       <td id="T_70cf7_row7_col0" clas

# %% [markdown]
# # Training the model on multiple targets at once

# %%
# Let's try to update the code so using a (B, T, N, F), we train it on a (B, T, N) target instead of just (B, N) (corresponding to only the last step).
# This should hopefully make the training of transformer models much faster.

# %% [markdown]
# ## Basic example

# %%
z.get_dataloader(n_rolling=10, roll_y='true')

# %%
# We modify the basic transformer model to the following

class TransformerEncoderModelMultiT(nn.Module):
    def __init__(self, n_ts, n_f, n_rolling, d_model=128, nhead=8, num_layers=2, dropout=0.1):
        super().__init__()
        self.input_dim = n_ts * n_f
        self.d_model = d_model
        self.n_rolling = n_rolling
        self.n_ts = n_ts

        # Input projection
        self.input_proj = nn.Linear(self.input_dim, d_model)

        # Positional encoding
        self.pos_embedding = nn.Parameter(torch.randn(1, n_rolling, d_model))

        # Transformer encoder
        encoder_layer = nn.TransformerEncoderLayer(
            d_model=d_model,
            nhead=nhead,
            dim_feedforward=4 * d_model,
            dropout=dropout,
            activation='gelu',  # usually better than relu
            batch_first=True
        )
        self.encoder = nn.TransformerEncoder(encoder_layer, num_layers=num_layers)

        # NEW: Direct prediction head applied to EVERY time step
        self.decoder = nn.Sequential(
            nn.LayerNorm(d_model),
            nn.Linear(d_model, n_ts)   # output N values per time step
        )

    def forward(self, x, mask=None):
        # x: (B, T, N, F) where T == n_rolling
        B, T, N, F = x.shape
        assert T <= self.n_rolling, f"Input sequence length {T} > max {self.n_rolling}"

        # Flatten features
        x = x.reshape(B, T, N * F)                  # (B, T, N*F)
        x = self.input_proj(x)                      # (B, T, d_model)
        x = x + self.pos_embedding[:, :T, :]        # add pos encoding

        # Causal mask so each position only attends to past + itself
        causal_mask = torch.triu(torch.ones(T, T, device=x.device), diagonal=1).bool()
        encoded = self.encoder(x, mask=causal_mask)  # (B, T, d_model)

        # Predict at EVERY time step → (B, T, N)
        out = self.decoder(encoded)                  # (B, T, N)

        return out

# %%
# The code we use to train it is:

m = TransformerEncoderModelMultiT(Config.n_ts, Config.n_f, 10).to(device)
optimizer = torch.optim.AdamW(m.parameters(), lr=0.001)
#optimizer = torch.optim.SGD(m.parameters(), lr=1e-3)

# %%
model_torch = torch_benchmarks.TorchWrapper(m, optimizer=optimizer)
model_torch.fit(z.train, test=z.test, epochs=80)
# Out:
# 100%|██████████| 80/80 [00:24<00:00,  3.23it/s]

# %% [markdown]
# ## CS transformer models in multiT

# %%
class DualAttentionTransformerMultiT(nn.Module):
    def __init__(
        self,
        n_ts,              # number of time series (N)
        n_f,               # number of input features per timestamp
        n_rolling,         # lookback window length (T)
        d_model=128,
        nhead_time=8,      # heads for temporal attention
        nhead_series=8,    # heads for cross-series attention
        num_layers_time=2,
        num_layers_series=2,
        dim_feedforward=512,
        dropout=0.1,       # ← lowered from 0.8 — 0.8 kills gradients!
    ):
        super().__init__()
        
        self.n_ts = n_ts
        self.n_rolling = n_rolling
        self.d_model = d_model

        # Input projection
        self.input_proj = nn.Linear(n_f, d_model)

        # Positional encodings
        self.pos_emb_time = nn.Parameter(torch.randn(1, n_rolling, d_model))
        self.pos_emb_series = nn.Parameter(torch.randn(1, 1, n_ts, d_model))  # (1,1,N,d_model)

        # Stage 1: Temporal Transformer (per series)
        temporal_layer = nn.TransformerEncoderLayer(
            d_model=d_model,
            nhead=nhead_time,
            dim_feedforward=dim_feedforward,
            dropout=dropout,
            batch_first=True,
            activation="gelu",
        )
        self.temporal_transformer = nn.TransformerEncoder(
            temporal_layer, num_layers=num_layers_time
        )

        # Causal mask for temporal attention
        self.register_buffer(
            "causal_mask_time",
            torch.triu(torch.ones(n_rolling, n_rolling), diagonal=1).bool()
        )

        # Stage 2: Cross-Series Transformer — now applied per timestep!
        series_layer = nn.TransformerEncoderLayer(
            d_model=d_model,
            nhead=nhead_series,
            dim_feedforward=dim_feedforward,
            dropout=dropout,
            batch_first=True,
            activation="gelu",
        )
        self.series_transformer = nn.TransformerEncoder(
            series_layer, num_layers=num_layers_series
        )

        self.output_head = nn.Sequential(
        nn.LayerNorm(d_model),
        nn.GELU(),
        nn.Dropout(dropout),
        nn.Linear(d_model, 1)          # ← outputs (B,T,N,1)
    )
        
    def forward(self, x):
        """
        x : (B, T, N, F)
        Returns: (B, T, N) — prediction for every timestep and every series
        """
        B, T, N, F = x.shape

        # 1. Project input
        x = self.input_proj(x)                                      # (B, T, N, d_model)

        # 2. Add temporal positional encoding
        x = x + self.pos_emb_time[:, :T, :].unsqueeze(2)            # (B, T, 1, d_model)

        # 3. Temporal attention (independent per series)
        # Reshape: (B, T, N, d_model) → (B*N, T, d_model)
        x_temp = x.permute(0, 2, 1, 3).reshape(B * N, T, self.d_model)
        x_temp = self.temporal_transformer(x_temp, mask=self.causal_mask_time)
        x = x_temp.reshape(B, N, T, self.d_model).permute(0, 2, 1, 3)  # (B, T, N, d_model)

        # 4. Add series positional encoding
        x = x + self.pos_emb_series                                 # (B, T, N, d_model)

        # 5. Cross-Series attention — now per timestep!
        # Reshape: (B, T, N, d_model) → (B*T, N, d_model)
        x_series = x.reshape(B * T, N, self.d_model)
        x_series = self.series_transformer(x_series)                # (B*T, N, d_model)
        x = x_series.reshape(B, T, N, self.d_model)                 # (B, T, N, d_model)

        # 6. Predict at EVERY timestep
        out = self.output_head(x)          # (B, T, N, 1)
        out = out.squeeze(-1)              # ← NOW (B, T, N) — correct!

        return out

# %%
class AlternatingDualAttentionTransformerMultiT(nn.Module):
    def __init__(
        self,
        n_ts,
        n_f,
        n_rolling,
        d_model=128,
        nhead=8,
        num_layers=2,
        dim_feedforward=512,
        dropout=0.1,
    ):
        super().__init__()
        self.d_model = d_model
        self.n_rolling = n_rolling
        self.n_ts = n_ts

        self.input_proj = nn.Linear(n_f, d_model)

        # Positional embeddings
        self.pos_emb_time   = nn.Parameter(torch.randn(1, 1, d_model))
        self.pos_emb_series = nn.Parameter(torch.randn(1, 1, d_model))

        self.dropout = nn.Dropout(dropout)

        self.blocks = nn.ModuleList()
        for _ in range(num_layers):
            temp = nn.TransformerEncoder(
                nn.TransformerEncoderLayer(
                    d_model, nhead, dim_feedforward, dropout,
                    activation="gelu", batch_first=True
                ),
                num_layers=1
            )
            series = nn.TransformerEncoder(
                nn.TransformerEncoderLayer(
                    d_model, nhead, dim_feedforward, dropout,
                    activation="gelu", batch_first=True
                ),
                num_layers=1
            )
            self.blocks.append(nn.ModuleDict({
                'temporal': temp,
                'series': series,
                'norm1': nn.LayerNorm(d_model),
                'norm2': nn.LayerNorm(d_model),
            }))

        self.register_buffer(
            "causal_mask",
            torch.triu(torch.ones(n_rolling, n_rolling), diagonal=1).bool()
        )

        # FIXED: Predict 1 value per series per timestep
        self.output_head = nn.Sequential(
            nn.LayerNorm(d_model),
            nn.GELU(),
            nn.Dropout(dropout),
            nn.Linear(d_model, 1)          # ← NOW CORRECT
        )

    def forward(self, x):
        B, T, N, _ = x.shape

        x = self.input_proj(x)                                      # (B, T, N, d_model)
        x = x + self.pos_emb_time + self.pos_emb_series

        for block in self.blocks:
            # Temporal attention
            res = x
            x = x.permute(0, 2, 1, 3).reshape(B * N, T, self.d_model)
            x = block['temporal'](x, mask=self.causal_mask)
            x = x.reshape(B, N, T, self.d_model).permute(0, 2, 1, 3)
            x = block['norm1'](res + self.dropout(x))

            # Cross-series attention
            res = x
            x = x.reshape(B * T, N, self.d_model)
            x = block['series'](x)
            x = x.reshape(B, T, N, self.d_model)
            x = block['norm2'](res + self.dropout(x))

        # Predict at every timestep → (B, T, N, 1) → squeeze → (B, T, N)
        out = self.output_head(x)          # (B, T, N, 1)
        out = out.squeeze(-1)              # ← NOW (B, T, N) — perfect!

        return out

# %% [markdown]
# ## Comparing both setups

# %%
# Here lets compare running the dual transformer using both setups

# %%
@dataclass
class Config:
    T: int = 3000
    n_ts: int = 5
    n_f: int = 10
    pct_zero_corr: float = 0.5
    split_conditional: float = 0.25
    split_shift: float = 0.25
    split_seasonal: float = 0.
    split_cs: float = 0.25
    split_cs_shift: float = 0.25
    low_corr: float = 0.1
    high_corr: float = 0.2

# @dataclass
# class Config:
#     T: int = 3000
#     n_ts: int = 20
#     n_f: int = 10
#     pct_zero_corr: float = 0.5
#     split_conditional: float = 1.0
#     split_shift: float = 0.
#     split_seasonal: float = 0.
#     split_cs: float = 0.
#     split_cs_shift: float = 0.
#     low_corr: float = 0.1
#     high_corr: float = 0.2

# %%
z = generators.Generator(Config.T, Config.n_ts, Config.n_f)

# %%
# %%time
z.generate_dataset(pct_zero_corr = Config.pct_zero_corr,
                  split_conditional = Config.split_conditional,
                  split_shift = Config.split_shift,
                  split_seasonal = Config.split_seasonal,
                  split_cs=Config.split_cs,
                  split_cs_shift=Config.split_cs_shift,
                  low_corr=Config.low_corr, 
                  high_corr=Config.high_corr)
# Out:
# CPU times: user 5.84 ms, sys: 1.19 ms, total: 7.02 ms
# Wall time: 6.47 ms

# %%
z.get_dataloader(n_rolling=10)

# %%
m = DualAttentionTransformer(Config.n_ts, Config.n_f, 10, d_model=128, dim_feedforward=512, dropout=0.5, num_layers_series=2, num_layers_time=2).to(device)
optimizer = torch.optim.AdamW(m.parameters(), lr=0.001)
#optimizer = torch.optim.SGD(m.parameters(), lr=1e-3)


model_torch2 = torch_benchmarks.TorchWrapper(m, optimizer=optimizer)
model_torch2.fit(z.train, test=z.test, epochs=40)
# Out:
# 100%|██████████| 40/40 [00:24<00:00,  1.65it/s]

# %%
m = AlternatingDualAttentionTransformer(Config.n_ts, Config.n_f, 10, d_model=128, dim_feedforward=512, dropout=0.5, num_layers=2).to(device)
optimizer = torch.optim.AdamW(m.parameters(), lr=0.001)
# optimizer = torch.optim.SGD(m.parameters(), lr=1e-3)


model_torch4 = torch_benchmarks.TorchWrapper(m, optimizer=optimizer)
model_torch4.fit(z.train, test=z.test, epochs=60)
# Out:
# 100%|██████████| 60/60 [00:58<00:00,  1.03it/s]

# %%
comp = benchmark_comparison.Comparator(models=[model_torch2, model_torch4], 
                                        model_names=['transformer2', 'transformer4'])

# %%
comp.correl(z, mode='train')
# Out:
# /Users/gremy/Code/TSNN-1/tsnn-env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# <style type="text/css">
# #T_d05d9_row0_col0 {
#   background-color: #f7bca1;
#   color: #000000;
# }
# #T_d05d9_row0_col1, #T_d05d9_row0_col2, #T_d05d9_row0_col3, #T_d05d9_row0_col4, #T_d05d9_row0_col5, #T_d05d9_row0_col6, #T_d05d9_row0_col7, #T_d05d9_row1_col2, #T_d05d9_row1_col3, #T_d05d9_row1_col4, #T_d05d9_row1_col5, #T_d05d9_row1_col6, #T_d05d9_row1_col7, #T_d05d9_row2_col3, #T_d05d9_row2_col4, #T_d05d9_row2_col5, #T_d05d9_row2_col6, #T_d05d9_row2_col7, #T_d05d9_row3_col4, #T_d05d9_row3_col5, #T_d05d9_row3_col6, #T_d05d9_row3_col7, #T_d05d9_row4_col5, #T_d05d9_row4_col6, #T_d05d9_row4_col7, #T_d05d9_row5_col6, #T_d05d9_row5_col7, #T_d05d9_row6_col7 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_d05d9_row1_col0 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_d05d9_row1_col1, #T_d05d9_row7_col1 {
#   background-color: #f6a586;
#   color: #000000;
# }
# #T_d05d9_row2_col0, #T_d05d9_row7_col4 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_d05d9_row2_col1 {
#   background-color: #f39475;
#   color: #000000;
# }
# #T_d05d9_row2_col2, #T_d05d9_row4_col2, #T_d05d9_row5_col3, #T_d05d9_row7_col6 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_d05d9_row3_col0 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_d05d9_row3_col1 {
#   background-color: #f08a6c;
#   color: #f1f1f1;
# }
# #T_d05d9_row3_col2, #T_d05d9_row4_col3 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_d05d9_row3_col3 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_d05d9_row4_col0 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# #T_d05d9_row4_col1, #T_d05d9_row6_col0 {
#   background-color: #f7aa8c;
#   color: #000000;
# }
# #T_d05d9_row4_col4, #T_d05d9_row5_col2, #T_d05d9_row5_col4 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_d05d9_row5_col0 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_d05d9_row5_col1 {
#   background-color: #f7b79b;
#   color: #000000;
# }
# #T_d05d9_row5_col5 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_d05d9_row6_col1 {
#   background-color: #e67259;
#   color: #f1f1f1;
# }
# #T_d05d9_row6_col2 {
#   background-color: #f6a385;
#   color: #000000;
# }
# #T_d05d9_row6_col3 {
#   background-color: #f5c4ac;
#   color: #000000;
# }
# #T_d05d9_row6_col4, #T_d05d9_row7_col2 {
#   background-color: #f4987a;
#   color: #000000;
# }
# #T_d05d9_row6_col5 {
#   background-color: #f2c9b4;
#   color: #000000;
# }
# #T_d05d9_row6_col6 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_d05d9_row7_col0 {
#   background-color: #f7b599;
#   color: #000000;
# }
# #T_d05d9_row7_col3 {
#   background-color: #f3c8b2;
#   color: #000000;
# }
# #T_d05d9_row7_col5 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_d05d9_row7_col7 {
#   background-color: #e7745b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_d05d9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d05d9_level0_col0" class="col_heading level0 col0" >true</th>
#       <th id="T_d05d9_level0_col1" class="col_heading level0 col1" >optimal</th>
#       <th id="T_d05d9_level0_col2" class="col_heading level0 col2" >linear</th>
#       <th id="T_d05d9_level0_col3" class="col_heading level0 col3" >conditional</th>
#       <th id="T_d05d9_level0_col4" class="col_heading level0 col4" >shift</th>
#       <th id="T_d05d9_level0_col5" class="col_heading level0 col5" >cs</th>
#       <th id="T_d05d9_level0_col6" class="col_heading level0 col6" >cs_shift</th>
#       <th id="T_d05d9_level0_col7" class="col_heading level0 col7" >transformer2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d05d9_level0_row0" class="row_heading level0 row0" >optimal</th>
#       <td id="T_d05d9_row0_col0" class="data row0 col0" >0.306</td>
#       <td id="T_d05d9_row0_col1" class="data row0 col1" >nan</td>
#       <td id="T_d05d9_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_d05d9_row0_col3" class="data row0 col3" >nan</td>
#       <td id="T_d05d9_row0_col4" class="data row0 col4" >nan</td>
#       <td id="T_d05d9_row0_col5" class="data row0 col5" >nan</td>
#       <td id="T_d05d9_row0_col6" class="data row0 col6" >nan</td>
#       <td id="T_d05d9_row0_col7" class="data row0 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_d05d9_level0_row1" class="row_heading level0 row1" >linear</th>
#       <td id="T_d05d9_row1_col0" class="data row1 col0" >0.135</td>
#       <td id="T_d05d9_row1_col1" class="data row1 col1" >0.440</td>
#       <td id="T_d05d9_row1_col2" class="data row1 col2" >nan</td>
#       <td id="T_d05d9_row1_col3" class="data row1 col3" >nan</td>
#       <td id="T_d05d9_row1_col4" class="data row1 col4" >nan</td>
#       <td id="T_d05d9_row1_col5" class="data row1 col5" >nan</td>
#       <td id="T_d05d9_row1_col6" class="data row1 col6" >nan</td>
#       <td id="T_d05d9_row1_col7" class="data row1 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_d05d9_level0_row2" class="row_heading level0 row2" >conditional</th>
#       <td id="T_d05d9_row2_col0" class="data row2 col0" >0.164</td>
#       <td id="T_d05d9_row2_col1" class="data row2 col1" >0.525</td>
#       <td id="T_d05d9_row2_col2" class="data row2 col2" >0.020</td>
#       <td id="T_d05d9_row2_col3" class="data row2 col3" >nan</td>
#       <td id="T_d05d9_row2_col4" class="data row2 col4" >nan</td>
#       <td id="T_d05d9_row2_col5" class="data row2 col5" >nan</td>
#       <td id="T_d05d9_row2_col6" class="data row2 col6" >nan</td>
#       <td id="T_d05d9_row2_col7" class="data row2 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_d05d9_level0_row3" class="row_heading level0 row3" >shift</th>
#       <td id="T_d05d9_row3_col0" class="data row3 col0" >0.180</td>
#       <td id="T_d05d9_row3_col1" class="data row3 col1" >0.571</td>
#       <td id="T_d05d9_row3_col2" class="data row3 col2" >0.031</td>
#       <td id="T_d05d9_row3_col3" class="data row3 col3" >0.027</td>
#       <td id="T_d05d9_row3_col4" class="data row3 col4" >nan</td>
#       <td id="T_d05d9_row3_col5" class="data row3 col5" >nan</td>
#       <td id="T_d05d9_row3_col6" class="data row3 col6" >nan</td>
#       <td id="T_d05d9_row3_col7" class="data row3 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_d05d9_level0_row4" class="row_heading level0 row4" >cs</th>
#       <td id="T_d05d9_row4_col0" class="data row4 col0" >0.124</td>
#       <td id="T_d05d9_row4_col1" class="data row4 col1" >0.407</td>
#       <td id="T_d05d9_row4_col2" class="data row4 col2" >0.016</td>
#       <td id="T_d05d9_row4_col3" class="data row4 col3" >0.036</td>
#       <td id="T_d05d9_row4_col4" class="data row4 col4" >0.009</td>
#       <td id="T_d05d9_row4_col5" class="data row4 col5" >nan</td>
#       <td id="T_d05d9_row4_col6" class="data row4 col6" >nan</td>
#       <td id="T_d05d9_row4_col7" class="data row4 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_d05d9_level0_row5" class="row_heading level0 row5" >cs_shift</th>
#       <td id="T_d05d9_row5_col0" class="data row5 col0" >0.092</td>
#       <td id="T_d05d9_row5_col1" class="data row5 col1" >0.340</td>
#       <td id="T_d05d9_row5_col2" class="data row5 col2" >0.009</td>
#       <td id="T_d05d9_row5_col3" class="data row5 col3" >0.021</td>
#       <td id="T_d05d9_row5_col4" class="data row5 col4" >0.010</td>
#       <td id="T_d05d9_row5_col5" class="data row5 col5" >0.007</td>
#       <td id="T_d05d9_row5_col6" class="data row5 col6" >nan</td>
#       <td id="T_d05d9_row5_col7" class="data row5 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_d05d9_level0_row6" class="row_heading level0 row6" >transformer2</th>
#       <td id="T_d05d9_row6_col0" class="data row6 col0" >0.412</td>
#       <td id="T_d05d9_row6_col1" class="data row6 col1" >0.677</td>
#       <td id="T_d05d9_row6_col2" class="data row6 col2" >0.448</td>
#       <td id="T_d05d9_row6_col3" class="data row6 col3" >0.253</td>
#       <td id="T_d05d9_row6_col4" class="data row6 col4" >0.504</td>
#       <td id="T_d05d9_row6_col5" class="data row6 col5" >0.217</td>
#       <td id="T_d05d9_row6_col6" class="data row6 col6" >0.066</td>
#       <td id="T_d05d9_row6_col7" class="data row6 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_d05d9_level0_row7" class="row_heading level0 row7" >transformer4</th>
#       <td id="T_d05d9_row7

# %%
comp.correl(z, mode='test')
# Out:
# /Users/gremy/Code/TSNN-1/tsnn-env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# <style type="text/css">
# #T_71a27_row0_col0 {
#   background-color: #f6bfa6;
#   color: #000000;
# }
# #T_71a27_row0_col1, #T_71a27_row0_col2, #T_71a27_row0_col3, #T_71a27_row0_col4, #T_71a27_row0_col5, #T_71a27_row0_col6, #T_71a27_row0_col7, #T_71a27_row1_col2, #T_71a27_row1_col3, #T_71a27_row1_col4, #T_71a27_row1_col5, #T_71a27_row1_col6, #T_71a27_row1_col7, #T_71a27_row2_col3, #T_71a27_row2_col4, #T_71a27_row2_col5, #T_71a27_row2_col6, #T_71a27_row2_col7, #T_71a27_row3_col4, #T_71a27_row3_col5, #T_71a27_row3_col6, #T_71a27_row3_col7, #T_71a27_row4_col5, #T_71a27_row4_col6, #T_71a27_row4_col7, #T_71a27_row5_col6, #T_71a27_row5_col7, #T_71a27_row6_col7 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_71a27_row1_col0, #T_71a27_row7_col4 {
#   background-color: #ecd3c5;
#   color: #000000;
# }
# #T_71a27_row1_col1 {
#   background-color: #f7a688;
#   color: #000000;
# }
# #T_71a27_row2_col0 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# #T_71a27_row2_col1, #T_71a27_row7_col2 {
#   background-color: #f39577;
#   color: #000000;
# }
# #T_71a27_row2_col2 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_71a27_row3_col0 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_71a27_row3_col1 {
#   background-color: #f08a6c;
#   color: #f1f1f1;
# }
# #T_71a27_row3_col2, #T_71a27_row5_col2, #T_71a27_row5_col5 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_71a27_row3_col3, #T_71a27_row7_col6 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_71a27_row4_col0 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_71a27_row4_col1 {
#   background-color: #f7ac8e;
#   color: #000000;
# }
# #T_71a27_row4_col2, #T_71a27_row4_col3 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_71a27_row4_col4, #T_71a27_row5_col4 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_71a27_row5_col0 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_71a27_row5_col1 {
#   background-color: #f7b497;
#   color: #000000;
# }
# #T_71a27_row5_col3 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_71a27_row6_col0 {
#   background-color: #f4c5ad;
#   color: #000000;
# }
# #T_71a27_row6_col1 {
#   background-color: #e67259;
#   color: #f1f1f1;
# }
# #T_71a27_row6_col2 {
#   background-color: #f6a283;
#   color: #000000;
# }
# #T_71a27_row6_col3 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# #T_71a27_row6_col4 {
#   background-color: #f4987a;
#   color: #000000;
# }
# #T_71a27_row6_col5 {
#   background-color: #f3c7b1;
#   color: #000000;
# }
# #T_71a27_row6_col6 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_71a27_row7_col0 {
#   background-color: #efcebd;
#   color: #000000;
# }
# #T_71a27_row7_col1 {
#   background-color: #f7a98b;
#   color: #000000;
# }
# #T_71a27_row7_col3 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_71a27_row7_col5 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_71a27_row7_col7 {
#   background-color: #ec7f63;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_71a27">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_71a27_level0_col0" class="col_heading level0 col0" >true</th>
#       <th id="T_71a27_level0_col1" class="col_heading level0 col1" >optimal</th>
#       <th id="T_71a27_level0_col2" class="col_heading level0 col2" >linear</th>
#       <th id="T_71a27_level0_col3" class="col_heading level0 col3" >conditional</th>
#       <th id="T_71a27_level0_col4" class="col_heading level0 col4" >shift</th>
#       <th id="T_71a27_level0_col5" class="col_heading level0 col5" >cs</th>
#       <th id="T_71a27_level0_col6" class="col_heading level0 col6" >cs_shift</th>
#       <th id="T_71a27_level0_col7" class="col_heading level0 col7" >transformer2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_71a27_level0_row0" class="row_heading level0 row0" >optimal</th>
#       <td id="T_71a27_row0_col0" class="data row0 col0" >0.288</td>
#       <td id="T_71a27_row0_col1" class="data row0 col1" >nan</td>
#       <td id="T_71a27_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_71a27_row0_col3" class="data row0 col3" >nan</td>
#       <td id="T_71a27_row0_col4" class="data row0 col4" >nan</td>
#       <td id="T_71a27_row0_col5" class="data row0 col5" >nan</td>
#       <td id="T_71a27_row0_col6" class="data row0 col6" >nan</td>
#       <td id="T_71a27_row0_col7" class="data row0 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_71a27_level0_row1" class="row_heading level0 row1" >linear</th>
#       <td id="T_71a27_row1_col0" class="data row1 col0" >0.131</td>
#       <td id="T_71a27_row1_col1" class="data row1 col1" >0.431</td>
#       <td id="T_71a27_row1_col2" class="data row1 col2" >nan</td>
#       <td id="T_71a27_row1_col3" class="data row1 col3" >nan</td>
#       <td id="T_71a27_row1_col4" class="data row1 col4" >nan</td>
#       <td id="T_71a27_row1_col5" class="data row1 col5" >nan</td>
#       <td id="T_71a27_row1_col6" class="data row1 col6" >nan</td>
#       <td id="T_71a27_row1_col7" class="data row1 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_71a27_level0_row2" class="row_heading level0 row2" >conditional</th>
#       <td id="T_71a27_row2_col0" class="data row2 col0" >0.144</td>
#       <td id="T_71a27_row2_col1" class="data row2 col1" >0.518</td>
#       <td id="T_71a27_row2_col2" class="data row2 col2" >-0.001</td>
#       <td id="T_71a27_row2_col3" class="data row2 col3" >nan</td>
#       <td id="T_71a27_row2_col4" class="data row2 col4" >nan</td>
#       <td id="T_71a27_row2_col5" class="data row2 col5" >nan</td>
#       <td id="T_71a27_row2_col6" class="data row2 col6" >nan</td>
#       <td id="T_71a27_row2_col7" class="data row2 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_71a27_level0_row3" class="row_heading level0 row3" >shift</th>
#       <td id="T_71a27_row3_col0" class="data row3 col0" >0.153</td>
#       <td id="T_71a27_row3_col1" class="data row3 col1" >0.573</td>
#       <td id="T_71a27_row3_col2" class="data row3 col2" >0.010</td>
#       <td id="T_71a27_row3_col3" class="data row3 col3" >0.032</td>
#       <td id="T_71a27_row3_col4" class="data row3 col4" >nan</td>
#       <td id="T_71a27_row3_col5" class="data row3 col5" >nan</td>
#       <td id="T_71a27_row3_col6" class="data row3 col6" >nan</td>
#       <td id="T_71a27_row3_col7" class="data row3 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_71a27_level0_row4" class="row_heading level0 row4" >cs</th>
#       <td id="T_71a27_row4_col0" class="data row4 col0" >0.134</td>
#       <td id="T_71a27_row4_col1" class="data row4 col1" >0.405</td>
#       <td id="T_71a27_row4_col2" class="data row4 col2" >0.024</td>
#       <td id="T_71a27_row4_col3" class="data row4 col3" >0.026</td>
#       <td id="T_71a27_row4_col4" class="data row4 col4" >0.016</td>
#       <td id="T_71a27_row4_col5" class="data row4 col5" >nan</td>
#       <td id="T_71a27_row4_col6" class="data row4 col6" >nan</td>
#       <td id="T_71a27_row4_col7" class="data row4 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_71a27_level0_row5" class="row_heading level0 row5" >cs_shift</th>
#       <td id="T_71a27_row5_col0" class="data row5 col0" >0.102</td>
#       <td id="T_71a27_row5_col1" class="data row5 col1" >0.358</td>
#       <td id="T_71a27_row5_col2" class="data row5 col2" >0.012</td>
#       <td id="T_71a27_row5_col3" class="data row5 col3" >0.044</td>
#       <td id="T_71a27_row5_col4" class="data row5 col4" >0.021</td>
#       <td id="T_71a27_row5_col5" class="data row5 col5" >0.009</td>
#       <td id="T_71a27_row5_col6" class="data row5 col6" >nan</td>
#       <td id="T_71a27_row5_col7" class="data row5 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_71a27_level0_row6" class="row_heading level0 row6" >transformer2</th>
#       <td id="T_71a27_row6_col0" class="data row6 col0" >0.249</td>
#       <td id="T_71a27_row6_col1" class="data row6 col1" >0.673</td>
#       <td id="T_71a27_row6_col2" class="data row6 col2" >0.461</td>
#       <td id="T_71a27_row6_col3" class="data row6 col3" >0.208</td>
#       <td id="T_71a27_row6_col4" class="data row6 col4" >0.504</td>
#       <td id="T_71a27_row6_col5" class="data row6 col5" >0.234</td>
#       <td id="T_71a27_row6_col6" class="data row6 col6" >0.075</td>
#       <td id="T_71a27_row6_col7" class="data r

# %%
z.get_dataloader(n_rolling=10, roll_y=True)

# %%
# The code we use to train it is:

m = DualAttentionTransformerMultiT(
    n_ts=Config.n_ts,
    n_f=Config.n_f,
    n_rolling=10,
    d_model=128,
    nhead_time=8,
    nhead_series=8,
    num_layers_time=2,
    num_layers_series=2,
    dropout=0.3
).to(device)
optimizer = torch.optim.AdamW(m.parameters(), lr=0.001)
#optimizer = torch.optim.SGD(m.parameters(), lr=1e-3)

# %%
model_torch2_multi = torch_benchmarks.TorchWrapper(m, optimizer=optimizer)
model_torch2_multi.fit(z.train, test=z.test, epochs=20)
# Out:
# 100%|██████████| 20/20 [00:18<00:00,  1.09it/s]

# %%
# The code we use to train it is:

m = AlternatingDualAttentionTransformerMultiT(
    n_ts=Config.n_ts,
    n_f=Config.n_f,
    n_rolling=10,
    d_model=128,
    nhead=8,
    num_layers=2,
    dropout=0.3
).to(device)
optimizer = torch.optim.AdamW(m.parameters(), lr=0.001)
#optimizer = torch.optim.SGD(m.parameters(), lr=1e-3)

model_torch4_multi = torch_benchmarks.TorchWrapper(m, optimizer=optimizer)
model_torch4_multi.fit(z.train, test=z.test, epochs=20)
# Out:
# 100%|██████████| 20/20 [00:19<00:00,  1.00it/s]

# %%
comp = benchmark_comparison.Comparator(models=[model_torch2_multi, model_torch4_multi], 
                                        model_names=['transformer_multi2', 'transformer_multi4'])

# %%
comp.correl(z, mode='train')
# Out:
# ---------------------------------------------------------------------------
# UserWarning                               Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 comp.correl(z, mode='train')
#
# File ~/Code/TSNN-1/tsnn/benchmarks/benchmark_comparison.py:39, in Comparator.correl(self, generator, mode, return_values)
#      37     prediction = pd.Series(self.models[k].predict(dataloader)).rename(self.model_names[k])
#      38     if len(prediction) != len(res[0]):
# ---> 39         raise UserWarning(
#      40             f'data dimension mismatch for model {self.model_names[k]}, the dataloader object must match the prediction model')
#      41     res.append(prediction)
#      42 res = pd.concat(res, axis=1).corr()
#
# UserWarning: data dimension mismatch for model transformer_multi2, the dataloader object must match the prediction model

# %%
comp.correl(z, mode='test')
# Out:
# <style type="text/css">
# #T_52032_row0_col0, #T_52032_row1_col1, #T_52032_row2_col2, #T_52032_row3_col3, #T_52032_row4_col4, #T_52032_row6_col6, #T_52032_row7_col7, #T_52032_row8_col8, #T_52032_row9_col9 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_52032_row0_col1, #T_52032_row0_col2, #T_52032_row0_col3, #T_52032_row0_col4, #T_52032_row0_col5, #T_52032_row0_col6, #T_52032_row0_col7, #T_52032_row0_col8, #T_52032_row0_col9, #T_52032_row1_col2, #T_52032_row1_col3, #T_52032_row1_col4, #T_52032_row1_col5, #T_52032_row1_col6, #T_52032_row1_col7, #T_52032_row1_col8, #T_52032_row1_col9, #T_52032_row2_col3, #T_52032_row2_col4, #T_52032_row2_col5, #T_52032_row2_col6, #T_52032_row2_col7, #T_52032_row2_col8, #T_52032_row2_col9, #T_52032_row3_col4, #T_52032_row3_col5, #T_52032_row3_col6, #T_52032_row3_col7, #T_52032_row3_col8, #T_52032_row3_col9, #T_52032_row4_col5, #T_52032_row4_col6, #T_52032_row4_col7, #T_52032_row4_col8, #T_52032_row4_col9, #T_52032_row5_col0, #T_52032_row5_col1, #T_52032_row5_col2, #T_52032_row5_col3, #T_52032_row5_col4, #T_52032_row5_col5, #T_52032_row5_col6, #T_52032_row5_col7, #T_52032_row5_col8, #T_52032_row5_col9, #T_52032_row6_col5, #T_52032_row6_col7, #T_52032_row6_col8, #T_52032_row6_col9, #T_52032_row7_col5, #T_52032_row7_col8, #T_52032_row7_col9, #T_52032_row8_col5, #T_52032_row8_col9, #T_52032_row9_col5 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_52032_row1_col0, #T_52032_row3_col0, #T_52032_row8_col6, #T_52032_row9_col2, #T_52032_row9_col6 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_52032_row2_col0, #T_52032_row4_col3, #T_52032_row8_col2, #T_52032_row8_col4, #T_52032_row8_col7 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_52032_row2_col1 {
#   background-color: #f39778;
#   color: #000000;
# }
# #T_52032_row3_col1 {
#   background-color: #f7b396;
#   color: #000000;
# }
# #T_52032_row3_col2 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_52032_row4_col0, #T_52032_row8_col1, #T_52032_row9_col1 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_52032_row4_col1 {
#   background-color: #f59f80;
#   color: #000000;
# }
# #T_52032_row4_col2 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_52032_row6_col0, #T_52032_row6_col3, #T_52032_row7_col0, #T_52032_row7_col3, #T_52032_row7_col4, #T_52032_row8_col3 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_52032_row6_col1 {
#   background-color: #f18f71;
#   color: #f1f1f1;
# }
# #T_52032_row6_col2 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_52032_row6_col4 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_52032_row7_col1 {
#   background-color: #f6a586;
#   color: #000000;
# }
# #T_52032_row7_col2, #T_52032_row7_col6, #T_52032_row9_col3 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_52032_row8_col0, #T_52032_row9_col0 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_52032_row9_col4, #T_52032_row9_col7 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_52032_row9_col8 {
#   background-color: #f08b6e;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_52032">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_52032_level0_col0" class="col_heading level0 col0" >true</th>
#       <th id="T_52032_level0_col1" class="col_heading level0 col1" >optimal</th>
#       <th id="T_52032_level0_col2" class="col_heading level0 col2" >linear</th>
#       <th id="T_52032_level0_col3" class="col_heading level0 col3" >conditional</th>
#       <th id="T_52032_level0_col4" class="col_heading level0 col4" >shift</th>
#       <th id="T_52032_level0_col5" class="col_heading level0 col5" >seasonal</th>
#       <th id="T_52032_level0_col6" class="col_heading level0 col6" >cs</th>
#       <th id="T_52032_level0_col7" class="col_heading level0 col7" >cs_shift</th>
#       <th id="T_52032_level0_col8" class="col_heading level0 col8" >transformer_multi2</th>
#       <th id="T_52032_level0_col9" class="col_heading level0 col9" >transformer_multi4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_52032_level0_row0" class="row_heading level0 row0" >true</th>
#       <td id="T_52032_row0_col0" class="data row0 col0" >1.000</td>
#       <td id="T_52032_row0_col1" class="data row0 col1" >nan</td>
#       <td id="T_52032_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_52032_row0_col3" class="data row0 col3" >nan</td>
#       <td id="T_52032_row0_col4" class="data row0 col4" >nan</td>
#       <td id="T_52032_row0_col5" class="data row0 col5" >nan</td>
#       <td id="T_52032_row0_col6" class="data row0 col6" >nan</td>
#       <td id="T_52032_row0_col7" class="data row0 col7" >nan</td>
#       <td id="T_52032_row0_col8" class="data row0 col8" >nan</td>
#       <td id="T_52032_row0_col9" class="data row0 col9" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_52032_level0_row1" class="row_heading level0 row1" >optimal</th>
#       <td id="T_52032_row1_col0" class="data row1 col0" >0.005</td>
#       <td id="T_52032_row1_col1" class="data row1 col1" >1.000</td>
#       <td id="T_52032_row1_col2" class="data row1 col2" >nan</td>
#       <td id="T_52032_row1_col3" class="data row1 col3" >nan</td>
#       <td id="T_52032_row1_col4" class="data row1 col4" >nan</td>
#       <td id="T_52032_row1_col5" class="data row1 col5" >nan</td>
#       <td id="T_52032_row1_col6" class="data row1 col6" >nan</td>
#       <td id="T_52032_row1_col7" class="data row1 col7" >nan</td>
#       <td id="T_52032_row1_col8" class="data row1 col8" >nan</td>
#       <td id="T_52032_row1_col9" class="data row1 col9" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_52032_level0_row2" class="row_heading level0 row2" >linear</th>
#       <td id="T_52032_row2_col0" class="data row2 col0" >-0.011</td>
#       <td id="T_52032_row2_col1" class="data row2 col1" >0.511</td>
#       <td id="T_52032_row2_col2" class="data row2 col2" >1.000</td>
#       <td id="T_52032_row2_col3" class="data row2 col3" >nan</td>
#       <td id="T_52032_row2_col4" class="data row2 col4" >nan</td>
#       <td id="T_52032_row2_col5" class="data row2 col5" >nan</td>
#       <td id="T_52032_row2_col6" class="data row2 col6" >nan</td>
#       <td id="T_52032_row2_col7" class="data row2 col7" >nan</td>
#       <td id="T_52032_row2_col8" class="data row2 col8" >nan</td>
#       <td id="T_52032_row2_col9" class="data row2 col9" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_52032_level0_row3" class="row_heading level0 row3" >conditional</th>
#       <td id="T_52032_row3_col0" class="data row3 col0" >0.006</td>
#       <td id="T_52032_row3_col1" class="data row3 col1" >0.364</td>
#       <td id="T_52032_row3_col2" class="data row3 col2" >0.047</td>
#       <td id="T_52032_row3_col3" class="data row3 col3" >1.000</td>
#       <td id="T_52032_row3_col4" class="data row3 col4" >nan</td>
#       <td id="T_52032_row3_col5" class="data row3 col5" >nan</td>
#       <td id="T_52032_row3_col6" class="data row3 col6" >nan</td>
#       <td id="T_52032_row3_col7" class="data row3 col7" >nan</td>
#       <td id="T_52032_row3_col8" class="data row3 col8" >nan</td>
#       <td id="T_52032_row3_col9" class="data row3 col9" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_52032_level0_row4" class="row_heading level0 row4" >shift</th>
#       <td id="T_52032_row4_col0" class="data row4 col0" >-0.001</td>
#       <td id="T_52032_row4_col1" class="data row4 col1" >0.471</td>
#       <td id="T_52032_row4_col2" class="data row4 col2" >0.051</td>
#       <td id="T_52032_row4_col3" class="data row4 col3" >-0.011</td>
#       <td id="T_52032_row4_col4" class="data row4 col4" >1.000</td>
#       <td id="T_52032_row4_col5" class="data row4 col5" >nan</td>
#       <td id="T_52032_row4_col6" class="data row4 col6" >nan</td>
#       <td id="T_52032_row4_col7" class="data row4 col7" >nan</td>
#       <td id="T_52032_row4_col8" class="data row4 col8" >nan</td>
#       <td id="T_52032_row4_col9" class="data row4 col9" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_52032_level0_row5" class="row_heading level0 row5" >seasonal</th>
#       <td id="T_52032_row5_col0" class="data row5 col0" >nan</td>
#       <td id="T_52032_row5_col1" class="data row5 col1" >nan</td>
#       <td id="T_52032

# %% [markdown]
# # Running many models on many datasets

# %%
# Global data
num_time_steps = 3000
num_time_series = 5
num_features = 10

# %%
num_epochs = 10
choice_optimizer = "AdamW" #Choose between "SGD", "Adam", "AdamW"
learning_rate = 0.001
weight_decay = 0.01 #For AdamW only

# %% [markdown]
# ## Defining the data

# %%
@dataclass
class Config:
    T: int = num_time_steps
    n_ts: int = num_time_series
    n_f: int = num_features
    pct_zero_corr: float = 0.5
    split_conditional: float = 0.0
    split_shift: float = 0.0
    split_seasonal: float = 0.0
    split_cs: float = 0.0
    split_cs_shift: float = 0.0
    #split_cs_shift: float = 1.0
    low_corr: float = 0.1
    high_corr: float = 0.2

# %%
dic_data = {}

z1 = generators.Generator(Config.T, Config.n_ts, Config.n_f)
z1.generate_dataset(pct_zero_corr = Config.pct_zero_corr,
                  split_conditional = 1.0,
                  split_shift = Config.split_shift,
                  split_seasonal = Config.split_seasonal,
                  split_cs=Config.split_cs,
                  split_cs_shift=Config.split_cs_shift,
                  low_corr=Config.low_corr, 
                  high_corr=Config.high_corr)
z1.get_dataloader(n_rolling=10)

z2 = generators.Generator(Config.T, Config.n_ts, Config.n_f)
z2.generate_dataset(pct_zero_corr = Config.pct_zero_corr,
                  split_conditional = Config.split_conditional,
                  split_shift = 1.0,
                  split_seasonal = Config.split_seasonal,
                  split_cs=Config.split_cs,
                  split_cs_shift=Config.split_cs_shift,
                  low_corr=Config.low_corr, 
                  high_corr=Config.high_corr)
z2.get_dataloader(n_rolling=10)

z3 = generators.Generator(Config.T, Config.n_ts, Config.n_f)
z3.generate_dataset(pct_zero_corr = Config.pct_zero_corr,
                  split_conditional = Config.split_conditional,
                  split_shift = Config.split_shift,
                  split_seasonal = Config.split_seasonal,
                  split_cs= 1.0,
                  split_cs_shift=Config.split_cs_shift,
                  low_corr=Config.low_corr, 
                  high_corr=Config.high_corr)
z3.get_dataloader(n_rolling=10)

z4 = generators.Generator(Config.T, Config.n_ts, Config.n_f)
z4.generate_dataset(pct_zero_corr = Config.pct_zero_corr,
                  split_conditional = Config.split_conditional,
                  split_shift = Config.split_shift,
                  split_seasonal = Config.split_seasonal,
                  split_cs=Config.split_cs,
                  split_cs_shift=1.0,
                  low_corr=Config.low_corr, 
                  high_corr=Config.high_corr)
z4.get_dataloader(n_rolling=10)


dic_data["d_cond"] = z1
dic_data["d_shift"] = z2
dic_data["d_cs"] = z3
dic_data["d_cs_shift"] = z4

# %% [markdown]
# ## Defining the models

# %%
# Let's also define a dic of models, varying here dropout in the basic transformer.

# %%
class TransformerEncoderModel(nn.Module):
    def __init__(self, n_ts, n_f, n_rolling, d_model=128, nhead=8, num_layers=2, dropout=0.8):
        super().__init__()
        self.input_dim = n_ts * n_f
        self.d_model = d_model

        # Linear projection of (n_ts*n_f) features
        self.input_proj = nn.Linear(self.input_dim, d_model)

        # Positional encoding (learned or sinusoidal)
        self.pos_embedding = nn.Parameter(torch.randn(1, n_rolling, d_model))

        # Transformer encoder
        encoder_layer = nn.TransformerEncoderLayer(
            d_model=d_model,
            nhead=nhead,
            dim_feedforward=4 * d_model,
            dropout=dropout,
            batch_first=True
        )
        self.encoder = nn.TransformerEncoder(encoder_layer, num_layers=num_layers)

        # prediction
        self.decoder = nn.Sequential(
            nn.LayerNorm(d_model),
            nn.Linear(d_model, n_ts)
        )

    def forward(self, x, mask=None):
        # x: (batch, n_rolling, n_ts, n_f)
        B, n_rolling, n_ts, n_f = x.shape

        # Flatten dimensions that are not lookback
        x = x.reshape(B, n_rolling, n_ts*n_f)
        x = self.input_proj(x) + self.pos_embedding[:, :n_rolling, :]

        # pass through Transformer encoder
        causal_mask = torch.triu(torch.ones(n_rolling, n_rolling, device=x.device), diagonal=1).bool()
        encoded = self.encoder(x, mask=causal_mask)  

        # last time step’s embedding for prediction
        out = self.decoder(encoded[:, -1, :])  # (B, N)
        return out

# %%
#dropout_values = [0, 0.25, 0.5, 0.8, 0.85, 0.9]
dropout_values = [0.25, 0.8,]

# %%
dic_models = {}

for i in range(len(dropout_values)):
    m = TransformerEncoderModel(Config.n_ts, Config.n_f, 10, dropout=dropout_values[i]).to(device)
    #m = TransformerEncoderModel(10, 5).to(device)
    model_name = "m_dropout_" + str(dropout_values[i])
    dic_models[model_name] = m

# %%
dic_models.keys()
# Out:
# dict_keys(['m_dropout_0.25', 'm_dropout_0.8'])

# %%
dic_data.keys()
# Out:
# dict_keys(['d_cond', 'd_shift', 'd_cs', 'd_cs_shift'])

# %% [markdown]
# ## Running all the models on all the data

# %%
# OK now let's run the code on all the models.

# %%
#Let's now run the above on all the indexes and see what we get

correls_IS = np.zeros((len(dic_models.keys()), len(dic_data.keys())))
correls_OOS = np.zeros((len(dic_models.keys()), len(dic_data.keys())))

keys_model = list(dic_models.keys())
keys_data = list(dic_data.keys())

for index1 in range(len(keys_model)):
    for index2 in range(len(keys_data)):

        model_name = keys_model[index1]
        data_name = keys_data[index2]
        
        z = dic_data[data_name]
        m = dic_models[model_name]
        
        if choice_optimizer=="Adam":
            optimizer = torch.optim.Adam(m.parameters(), lr=learning_rate)
        elif choice_optimizer=="AdamW":
            optimizer = torch.optim.AdamW(m.parameters(), lr=learning_rate, weight_decay=weight_decay)
        else:
            optimizer = torch.optim.SGD(m.parameters(), lr=learning_rate)
        model_torch = torch_benchmarks.TorchWrapper(m, optimizer=optimizer)
        model_torch.fit(z.train, test=z.test, epochs=num_epochs, plot=False)
        
        comp = benchmark_comparison.Comparator(models=[model_torch], model_names=['model_torch'])
        
        out_train = comp.correl(z, mode="train", return_values=True).loc["model_torch", "optimal"]
        out_test = comp.correl(z, mode="test", return_values=True).loc["model_torch", "optimal"]

        correls_IS[index1][index2] = out_train
        correls_OOS[index1][index2] = out_test

        print(model_name, data_name, " done")

pd_correls_IS = pd.DataFrame(correls_IS, index=keys_model, columns=keys_data)
pd_correls_OOS = pd.DataFrame(correls_OOS, index=keys_model, columns=keys_data)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]100%|██████████| 10/10 [00:02<00:00,  4.70it/s]
# /Users/gremy/Code/TSNN-1/tsnn-env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# /Users/gremy/Code/TSNN-1/tsnn-env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# m_dropout_0.25 d_cond  done
# 100%|██████████| 10/10 [00:01<00:00,  5.39it/s]
# /Users/gremy/Code/TSNN-1/tsnn-env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# /Users/gremy/Code/TSNN-1/tsnn-env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# m_dropout_0.25 d_shift  done
# 100%|██████████| 10/10 [00:01<00:00,  5.31it/s]
# /Users/gremy/Code/TSNN-1/tsnn-env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# /Users/gremy/Code/TSNN-1/tsnn-env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# m_dropout_0.25 d_cs  done
# 100%|██████████| 10/10 [00:01<00:00,  5.31it/s]
# /Users/gremy/Code/TSNN-1/tsnn-env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# /Users/gremy/Code/TSNN-1/tsnn-env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# m_dropout_0.25 d_cs_shift  done
# 100%|██████████| 10/10 [00:01<00:00,  5.28it/s]
# /Users/gremy/Code/TSNN-1/tsnn-env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# /Users/gremy/Code/TSNN-1/tsnn-env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# m_dropout_0.8 d_cond  done
# 100%|██████████| 10/10 [00:01<00:00,  5.45it/s]
# /Users/gremy/Code/TSNN-1/tsnn-env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# /Users/gremy/Code/TSNN-1/tsnn-env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# m_dropout_0.8 d_shift  done
# 100%|██████████| 10/10 [00:01<00:00,  5.27it/s]
# /Users/gremy/Code/TSNN-1/tsnn-env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# /Users/gremy/Code/TSNN-1/tsnn-env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# m_dropout_0.8 d_cs  done
# 100%|██████████| 10/10 [00:01<00:00,  5.21it/s]
# /Users/gremy/Code/TSNN-1/tsnn-env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# /Users/gremy/Code/TSNN-1/tsnn-env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# m_dropout_0.8 d_cs_shift  done

# %%
print("Correlation IS between model prediction and optimal y for the different models and the different datasets.")
pd_correls_IS.style.background_gradient(cmap='coolwarm', vmin=-1, vmax=1).format(precision=4)
# Out:
# Correlation IS between model prediction and optimal y for the different models and the different datasets.
# <style type="text/css">
# #T_5fc00_row0_col0 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_5fc00_row0_col1 {
#   background-color: #ec8165;
#   color: #f1f1f1;
# }
# #T_5fc00_row0_col2 {
#   background-color: #ef886b;
#   color: #f1f1f1;
# }
# #T_5fc00_row0_col3 {
#   background-color: #f29072;
#   color: #f1f1f1;
# }
# #T_5fc00_row1_col0, #T_5fc00_row1_col1 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_5fc00_row1_col2 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_5fc00_row1_col3 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# </style>
# <table id="T_5fc00">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5fc00_level0_col0" class="col_heading level0 col0" >d_cond</th>
#       <th id="T_5fc00_level0_col1" class="col_heading level0 col1" >d_shift</th>
#       <th id="T_5fc00_level0_col2" class="col_heading level0 col2" >d_cs</th>
#       <th id="T_5fc00_level0_col3" class="col_heading level0 col3" >d_cs_shift</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5fc00_level0_row0" class="row_heading level0 row0" >m_dropout_0.25</th>
#       <td id="T_5fc00_row0_col0" class="data row0 col0" >0.1108</td>
#       <td id="T_5fc00_row0_col1" class="data row0 col1" >0.6147</td>
#       <td id="T_5fc00_row0_col2" class="data row0 col2" >0.5857</td>
#       <td id="T_5fc00_row0_col3" class="data row0 col3" >0.5395</td>
#     </tr>
#     <tr>
#       <th id="T_5fc00_level0_row1" class="row_heading level0 row1" >m_dropout_0.8</th>
#       <td id="T_5fc00_row1_col0" class="data row1 col0" >0.0091</td>
#       <td id="T_5fc00_row1_col1" class="data row1 col1" >0.0130</td>
#       <td id="T_5fc00_row1_col2" class="data row1 col2" >0.0869</td>
#       <td id="T_5fc00_row1_col3" class="data row1 col3" >0.0282</td>
#     </tr>
#   </tbody>
# </table>

# %%
print("Correlation OOS between model prediction and optimal y for the different models and the different datasets.")
pd_correls_OOS.style.background_gradient(cmap='coolwarm', vmin=-1, vmax=1).format(precision=4)
# Out:
# Correlation OOS between model prediction and optimal y for the different models and the different datasets.
# <style type="text/css">
# #T_b2d6f_row0_col0, #T_b2d6f_row1_col3 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_b2d6f_row0_col1, #T_b2d6f_row0_col2 {
#   background-color: #ee8669;
#   color: #f1f1f1;
# }
# #T_b2d6f_row0_col3 {
#   background-color: #f39778;
#   color: #000000;
# }
# #T_b2d6f_row1_col0, #T_b2d6f_row1_col1 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_b2d6f_row1_col2 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# </style>
# <table id="T_b2d6f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b2d6f_level0_col0" class="col_heading level0 col0" >d_cond</th>
#       <th id="T_b2d6f_level0_col1" class="col_heading level0 col1" >d_shift</th>
#       <th id="T_b2d6f_level0_col2" class="col_heading level0 col2" >d_cs</th>
#       <th id="T_b2d6f_level0_col3" class="col_heading level0 col3" >d_cs_shift</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b2d6f_level0_row0" class="row_heading level0 row0" >m_dropout_0.25</th>
#       <td id="T_b2d6f_row0_col0" class="data row0 col0" >0.0151</td>
#       <td id="T_b2d6f_row0_col1" class="data row0 col1" >0.5909</td>
#       <td id="T_b2d6f_row0_col2" class="data row0 col2" >0.5862</td>
#       <td id="T_b2d6f_row0_col3" class="data row0 col3" >0.5125</td>
#     </tr>
#     <tr>
#       <th id="T_b2d6f_level0_row1" class="row_heading level0 row1" >m_dropout_0.8</th>
#       <td id="T_b2d6f_row1_col0" class="data row1 col0" >0.0229</td>
#       <td id="T_b2d6f_row1_col1" class="data row1 col1" >0.0209</td>
#       <td id="T_b2d6f_row1_col2" class="data row1 col2" >0.0848</td>
#       <td id="T_b2d6f_row1_col3" class="data row1 col3" >0.0142</td>
#     </tr>
#   </tbody>
# </table>
