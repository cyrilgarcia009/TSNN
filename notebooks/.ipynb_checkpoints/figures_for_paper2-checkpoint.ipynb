# %%
# === SETUP: Run this first! ===
import os
import sys

# Change to project root and add to Python path
notebook_dir = os.getcwd()
project_root = os.path.dirname(notebook_dir)  # Goes up one level from 'notebooks/'
os.chdir(project_root)
sys.path.insert(0, project_root)

print(f"Project root: {project_root}")
print(f"tsnn module path: {os.path.join(project_root, 'tsnn')}")
# Out:
# Project root: /Users/gremy/Code/TSNN-1
# tsnn module path: /Users/gremy/Code/TSNN-1/tsnn

# %%
# %load_ext autoreload
# %autoreload 2

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.linear_model import LassoCV, RidgeCV, LinearRegression
import torch
from torch.utils.data import Dataset, random_split
from torch.utils.data import DataLoader
import importlib
import sys
sys.path.append('/Users/cyrilgarcia/notebooks/tsnn/')

import tsnn

from tsnn.generators import generators
from tsnn import tstorch
from tsnn.benchmarks import benchmark_comparison, ml_benchmarks, torch_benchmarks
from tsnn import utils
from tsnn.tstorch import transformers
import torch.nn.functional as F
import math
from typing import Optional

from sklearn.linear_model import LinearRegression
from sklearn.ensemble import HistGradientBoostingRegressor
from sklearn.neural_network import MLPRegressor

from torch import nn
from tqdm import tqdm
device = 'mps'


plt.style.use('ggplot')

# %%
# This is the new version of the notebook to make all the figures for the paper.

# %%
from tsnn.tstorch import models
from tsnn.benchmarks import torch_benchmarks
from tsnn.benchmarks.torch_benchmarks import MSELossWithL1Sparsity

# %% [markdown]
# # Defining the data parameters

# %%
# The first thing that we want to do is define all of parameters of the data we will be testing on.

# %% [markdown]
# For now we will be working with the following effects:
# - Simple linear dependency
# - TS shift with lags chosen randomly for each feature, but constant accros stocks
# - CS shift, with lags chosen randomly for each stock and each feature
# - TS-CS shift: combination of the two lags above
# - Conditioning of one feature by another

# %% [markdown]
# We will fix the following global correlation levels: $\rho$ = 1,2,5,10,20,50. The first and last might not be too meaningful.

# %% [markdown]
# Next let's fix the size of the data that we want to test. We will always work with $T=4000$ points, and use $2500$ for training, $1500$ for testing. For the other dimensions:
# - Default 1: n_ts = 10, n_rolling = 10, n_f = 20. This gives $\gamma = 0.8$.
# - Default 2: n_ts = 10, n_rolling = 10, n_f = 5. This gives $\gamma = 0.2$.

# %% [markdown]
# Could also add two extra cases to test larger n_rolling or n_ts:
# - Long TS: n_ts = 10, n_rolling = 40, n_f = 5. This gives $\gamma = 0.8$.
# - Long CS: n_ts = 40, n_rolling = 10, n_f = 5. This gives $\gamma = 0.8$.

# %% [markdown]
# Next we need to compute a $\rho$ per feature. In the case where n_f=5, we will simply take $\frac{\rho}{\sqrt{5}}$ per feature. In the case n_f=20, we will take $\frac{\rho}{\sqrt{10}}$ for half of the features and $0$ for the half.

# %% [markdown]
# # Running the TC transformer

# %%
# Task one: let's run the best version of the TS-CS transformer on all of the above.

# %%
def causal_mask(b, h, q_idx, kv_idx):
    return q_idx >= kv_idx

def causal_mask_radius(b, h, q_idx, kv_idx):
    return (q_idx >= kv_idx) & (q_idx <= kv_idx+1)

def plot_mask(mask_fn, seq_len=20, title=None, device="cpu"):
    """
    Plot a binary attention mask defined by mask_fn(b,h,q_idx,kv_idx)
    as a (seq_len x seq_len) matrix.
    """
    q_idx = torch.arange(seq_len, device=device)
    kv_idx = torch.arange(seq_len, device=device)
    b = torch.zeros(1, device=device) 
    h = torch.zeros(1, device=device)

    mask = mask_fn(b, h, q_idx[:, None], kv_idx[None, :])
    mask = mask.float().cpu()

    return pd.DataFrame(mask).style.background_gradient(axis=None).format(precision=0)

def build_attention_mask(mask_fn, seq_len, device="cpu"):
    q_idx = torch.arange(seq_len, device=device)
    kv_idx = torch.arange(seq_len, device=device)
    b = torch.zeros(1, device=device)
    h = torch.zeros(1, device=device)
    mask_bool = mask_fn(b, h, q_idx[:, None], kv_idx[None, :])  # (seq_len, seq_len)
    return mask_bool

# %%
def get_ols_corr(N_fea, T_train, rho, oos=True):
    ratio = N_fea/T_train
    if oos:
        return rho / np.sqrt(rho**2 + (1-rho**2) * ratio/(1-ratio))
    else:
        return rho / np.sqrt(rho**2 + (1-rho**2) * ratio)

# %%
def run_models(rhos, effect, T=4000, n_ts=10, n_f=20, n_rolling=10):

    embeddings_dict = {'d_lin': "none", 'd_cond': "none", 'd_shift': "T", 'd_cs': "C", 'd_cs_shift': "both", 'd_all': "both"}

    mask = causal_mask
    mask_c = build_attention_mask(mask, n_rolling, device=device)

    if n_f < 10:
        pct_zero_corr = 0
    else:
        pct_zero_corr = 0.5

    cs = [rho/np.sqrt((1-pct_zero_corr)*n_f) for rho in rhos]

    arg_list = {'d_lin': {'pct_zero_corr': pct_zero_corr, 'split_conditional': 0.0, 'split_shift': 0.0, 'split_seasonal': 0.0, 'split_cs': 0.0, 'split_cs_shift': 0.0}, 
                'd_cond': {'pct_zero_corr': pct_zero_corr, 'split_conditional': 1.0, 'split_shift': 0.0, 'split_seasonal': 0.0, 'split_cs': 0.0, 'split_cs_shift': 0.0},  
                'd_shift': {'pct_zero_corr': pct_zero_corr, 'split_conditional': 0.0, 'split_shift': 1.0, 'split_seasonal': 0.0, 'split_cs': 0.0, 'split_cs_shift': 0.0}, 
                'd_cs': {'pct_zero_corr': pct_zero_corr, 'split_conditional': 0.0, 'split_shift': 0.0, 'split_seasonal': 0.0, 'split_cs': 1.0, 'split_cs_shift': 0.0}, 
                'd_cs_shift': {'pct_zero_corr': pct_zero_corr, 'split_conditional': 0.0, 'split_shift': 0.0, 'split_seasonal': 0.0, 'split_cs': 0.0, 'split_cs_shift': 1.0}, 
                'd_all': {'pct_zero_corr': pct_zero_corr, 'split_conditional': 0.2, 'split_shift': 0.2, 'split_seasonal': 0.0, 'split_cs': 0.2, 'split_cs_shift': 0.2}
               }
    
    z = generators.Generator(T, n_ts, n_f)
    
    res_train = []
    res_test = []
    for (i,c) in enumerate(cs):
        print("Running correl level:", rhos[i])
        theo_correl_is = get_ols_corr(n_ts*n_f*n_rolling, T*0.625, rhos[i], oos=False)
        theo_correl_oos = get_ols_corr(n_ts*n_f*n_rolling, T*0.625, rhos[i], oos=True)

        z.generate_dataset(
                pct_zero_corr=arg_list[effect]['pct_zero_corr'],
                split_conditional=arg_list[effect]['split_conditional'],
                split_shift=arg_list[effect]['split_shift'],
                split_seasonal=arg_list[effect]['split_seasonal'],
                split_cs=arg_list[effect]['split_cs'],
                split_cs_shift=arg_list[effect]['split_cs_shift'],
                random_ts_shift=n_rolling-1,
                low_corr=c,
                high_corr=c,
                shuffle_cs=True
            )

        z.get_dataloader()


        models_torch = {
            'full_attention_TC': models.CustomBiDimensionalTransformer(
                n_ts, n_f, n_rolling, mask=mask_c, layers='TC', nhead=8,
                dropout=0.1, dim_feedforward=256, sparsify=None, roll_y=True, embeddings=embeddings_dict[effect],
            ).to(device),
            'full_attention_TCTC': models.CustomBiDimensionalTransformer(
                n_ts, n_f, n_rolling, mask=mask_c, layers='TCTC', nhead=8,
                dropout=0.1, dim_feedforward=256, sparsify=None, roll_y=True, embeddings=embeddings_dict[effect],
            ).to(device),
        }

        models_torch = {
            k: torch_benchmarks.TorchWrapper(
                models_torch[k], 
                optimizer=torch.optim.AdamW(models_torch[k].parameters(), lr=0.001),
                loss_fn=nn.MSELoss()  
            ) for k in models_torch
        }


        z.get_dataloader(n_rolling=n_rolling, roll_y=True)
        for k in models_torch:
            models_torch[k].fit(z.train, test=z.test, epochs=40, plot=False, verbose=0)
            
      
        comp = benchmark_comparison.Comparator(models=[models_torch[k] for k in models_torch], 
        model_names=[k for k in models_torch]
        )

        corr_train = comp.correl(z, mode="train", return_values=True)
        corr_test  = comp.correl(z, mode="test",  return_values=True)

        for k in models_torch:

            train_corr = corr_train.loc[k, "optimal"]
            test_corr  = corr_test.loc[k, "optimal"]

            res_train.append({
                "rho": rhos[i],
                "model": k,
                "train_corr_optimal": train_corr
            })
            res_test.append({
                "rho": rhos[i],
                "model": k,
                "test_corr_optimal": test_corr
            })


        res_train.append({
                "rho": rhos[i],
                "model": "theo_correl",
                "train_corr_optimal": theo_correl_is
            })
        res_test.append({
                "rho": rhos[i],
                "model": "theo_correl",
                "test_corr_optimal": theo_correl_oos
            })

    
    res_train = pd.DataFrame(res_train)
    res_test  = pd.DataFrame(res_test)

    res_train = res_train.pivot(index="rho", columns="model", values="train_corr_optimal")
    res_test  = res_test.pivot(index="rho", columns="model", values="test_corr_optimal")

    return res_train, res_test

# %%
tfull_shift_train, tfull_shift_test = run_models([0.02, 0.05, 0.1, 0.2, 0.5], 'd_shift')
# Out:
# Running correl level: 0.02
# /Users/gremy/Code/TSNN-1/tsnn-env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# /Users/gremy/Code/TSNN-1/tsnn-env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# Running correl level: 0.05
# /Users/gremy/Code/TSNN-1/tsnn-env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# /Users/gremy/Code/TSNN-1/tsnn-env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# Running correl level: 0.1
# /Users/gremy/Code/TSNN-1/tsnn-env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# /Users/gremy/Code/TSNN-1/tsnn-env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# Running correl level: 0.2
# /Users/gremy/Code/TSNN-1/tsnn-env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# /Users/gremy/Code/TSNN-1/tsnn-env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# Running correl level: 0.5
# /Users/gremy/Code/TSNN-1/tsnn-env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# /Users/gremy/Code/TSNN-1/tsnn-env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)

# %%
display(tfull_shift_train.T.style.background_gradient(cmap='coolwarm', vmin=-1, vmax=1).format(precision=3))
display(tfull_shift_test.T.style.background_gradient(cmap='coolwarm', vmin=-1, vmax=1).format(precision=3))
# Out:
# <style type="text/css">
# #T_f3fad_row0_col0 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_f3fad_row0_col1 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_f3fad_row0_col2, #T_f3fad_row2_col2 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_f3fad_row0_col3 {
#   background-color: #f4c5ad;
#   color: #000000;
# }
# #T_f3fad_row0_col4 {
#   background-color: #ef886b;
#   color: #f1f1f1;
# }
# #T_f3fad_row1_col0, #T_f3fad_row2_col0 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_f3fad_row1_col1 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_f3fad_row1_col2 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# #T_f3fad_row1_col3 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# #T_f3fad_row1_col4 {
#   background-color: #f49a7b;
#   color: #000000;
# }
# #T_f3fad_row2_col1 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_f3fad_row2_col3 {
#   background-color: #f3c8b2;
#   color: #000000;
# }
# #T_f3fad_row2_col4 {
#   background-color: #f29072;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_f3fad">
#   <thead>
#     <tr>
#       <th class="index_name level0" >rho</th>
#       <th id="T_f3fad_level0_col0" class="col_heading level0 col0" >0.020000</th>
#       <th id="T_f3fad_level0_col1" class="col_heading level0 col1" >0.050000</th>
#       <th id="T_f3fad_level0_col2" class="col_heading level0 col2" >0.100000</th>
#       <th id="T_f3fad_level0_col3" class="col_heading level0 col3" >0.200000</th>
#       <th id="T_f3fad_level0_col4" class="col_heading level0 col4" >0.500000</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f3fad_level0_row0" class="row_heading level0 row0" >full_attention_TC</th>
#       <td id="T_f3fad_row0_col0" class="data row0 col0" >0.025</td>
#       <td id="T_f3fad_row0_col1" class="data row0 col1" >0.073</td>
#       <td id="T_f3fad_row0_col2" class="data row0 col2" >0.115</td>
#       <td id="T_f3fad_row0_col3" class="data row0 col3" >0.249</td>
#       <td id="T_f3fad_row0_col4" class="data row0 col4" >0.583</td>
#     </tr>
#     <tr>
#       <th id="T_f3fad_level0_row1" class="row_heading level0 row1" >full_attention_TCTC</th>
#       <td id="T_f3fad_row1_col0" class="data row1 col0" >0.022</td>
#       <td id="T_f3fad_row1_col1" class="data row1 col1" >0.051</td>
#       <td id="T_f3fad_row1_col2" class="data row1 col2" >0.119</td>
#       <td id="T_f3fad_row1_col3" class="data row1 col3" >0.204</td>
#       <td id="T_f3fad_row1_col4" class="data row1 col4" >0.499</td>
#     </tr>
#     <tr>
#       <th id="T_f3fad_level0_row2" class="row_heading level0 row2" >theo_correl</th>
#       <td id="T_f3fad_row2_col0" class="data row2 col0" >0.022</td>
#       <td id="T_f3fad_row2_col1" class="data row2 col1" >0.056</td>
#       <td id="T_f3fad_row2_col2" class="data row2 col2" >0.112</td>
#       <td id="T_f3fad_row2_col3" class="data row2 col3" >0.222</td>
#       <td id="T_f3fad_row2_col4" class="data row2 col4" >0.542</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_d63e3_row0_col0, #T_d63e3_row1_col0, #T_d63e3_row1_col1, #T_d63e3_row2_col1 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_d63e3_row0_col1, #T_d63e3_row0_col2 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_d63e3_row0_col3 {
#   background-color: #f1ccb8;
#   color: #000000;
# }
# #T_d63e3_row0_col4 {
#   background-color: #f39475;
#   color: #000000;
# }
# #T_d63e3_row1_col2 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_d63e3_row1_col3, #T_d63e3_row2_col3 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_d63e3_row1_col4 {
#   background-color: #f6a586;
#   color: #000000;
# }
# #T_d63e3_row2_col0 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_d63e3_row2_col2 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_d63e3_row2_col4 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# </style>
# <table id="T_d63e3">
#   <thead>
#     <tr>
#       <th class="index_name level0" >rho</th>
#       <th id="T_d63e3_level0_col0" class="col_heading level0 col0" >0.020000</th>
#       <th id="T_d63e3_level0_col1" class="col_heading level0 col1" >0.050000</th>
#       <th id="T_d63e3_level0_col2" class="col_heading level0 col2" >0.100000</th>
#       <th id="T_d63e3_level0_col3" class="col_heading level0 col3" >0.200000</th>
#       <th id="T_d63e3_level0_col4" class="col_heading level0 col4" >0.500000</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d63e3_level0_row0" class="row_heading level0 row0" >full_attention_TC</th>
#       <td id="T_d63e3_row0_col0" class="data row0 col0" >0.031</td>
#       <td id="T_d63e3_row0_col1" class="data row0 col1" >0.084</td>
#       <td id="T_d63e3_row0_col2" class="data row0 col2" >0.082</td>
#       <td id="T_d63e3_row0_col3" class="data row0 col3" >0.189</td>
#       <td id="T_d63e3_row0_col4" class="data row0 col4" >0.526</td>
#     </tr>
#     <tr>
#       <th id="T_d63e3_level0_row1" class="row_heading level0 row1" >full_attention_TCTC</th>
#       <td id="T_d63e3_row1_col0" class="data row1 col0" >0.026</td>
#       <td id="T_d63e3_row1_col1" class="data row1 col1" >0.027</td>
#       <td id="T_d63e3_row1_col2" class="data row1 col2" >0.114</td>
#       <td id="T_d63e3_row1_col3" class="data row1 col3" >0.101</td>
#       <td id="T_d63e3_row1_col4" class="data row1 col4" >0.439</td>
#     </tr>
#     <tr>
#       <th id="T_d63e3_level0_row2" class="row_heading level0 row2" >theo_correl</th>
#       <td id="T_d63e3_row2_col0" class="data row2 col0" >0.010</td>
#       <td id="T_d63e3_row2_col1" class="data row2 col1" >0.025</td>
#       <td id="T_d63e3_row2_col2" class="data row2 col2" >0.050</td>
#       <td id="T_d63e3_row2_col3" class="data row2 col3" >0.102</td>
#       <td id="T_d63e3_row2_col4" class="data row2 col4" >0.277</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Running on all effects, default data 1

# %%
tfull_lin_train, tfull_lin_test = run_models([0.02, 0.05, 0.1, 0.2, 0.5], 'd_lin')
# Out:
# Running correl level: 0.02
# /Users/gremy/Code/TSNN-1/tsnn-env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# /Users/gremy/Code/TSNN-1/tsnn-env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# Running correl level: 0.05
# /Users/gremy/Code/TSNN-1/tsnn-env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# /Users/gremy/Code/TSNN-1/tsnn-env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# Running correl level: 0.1
# /Users/gremy/Code/TSNN-1/tsnn-env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# /Users/gremy/Code/TSNN-1/tsnn-env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# Running correl level: 0.2
# /Users/gremy/Code/TSNN-1/tsnn-env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# /Users/gremy/Code/TSNN-1/tsnn-env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# Running correl level: 0.5
# /Users/gremy/Code/TSNN-1/tsnn-env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# /Users/gremy/Code/TSNN-1/tsnn-env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)

# %%
display(tfull_lin_train.T.style.background_gradient(cmap='coolwarm', vmin=-1, vmax=1).format(precision=3))
display(tfull_lin_test.T.style.background_gradient(cmap='coolwarm', vmin=-1, vmax=1).format(precision=3))
# Out:
# <style type="text/css">
# #T_5b8a4_row0_col0, #T_5b8a4_row2_col1 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_5b8a4_row0_col1 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_5b8a4_row0_col2 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_5b8a4_row0_col3 {
#   background-color: #f5c4ac;
#   color: #000000;
# }
# #T_5b8a4_row0_col4 {
#   background-color: #e97a5f;
#   color: #f1f1f1;
# }
# #T_5b8a4_row1_col0 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_5b8a4_row1_col1 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_5b8a4_row1_col2 {
#   background-color: #ecd3c5;
#   color: #000000;
# }
# #T_5b8a4_row1_col3 {
#   background-color: #f3c7b1;
#   color: #000000;
# }
# #T_5b8a4_row1_col4 {
#   background-color: #f08b6e;
#   color: #f1f1f1;
# }
# #T_5b8a4_row2_col0 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_5b8a4_row2_col2 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_5b8a4_row2_col3 {
#   background-color: #f3c8b2;
#   color: #000000;
# }
# #T_5b8a4_row2_col4 {
#   background-color: #f29072;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_5b8a4">
#   <thead>
#     <tr>
#       <th class="index_name level0" >rho</th>
#       <th id="T_5b8a4_level0_col0" class="col_heading level0 col0" >0.020000</th>
#       <th id="T_5b8a4_level0_col1" class="col_heading level0 col1" >0.050000</th>
#       <th id="T_5b8a4_level0_col2" class="col_heading level0 col2" >0.100000</th>
#       <th id="T_5b8a4_level0_col3" class="col_heading level0 col3" >0.200000</th>
#       <th id="T_5b8a4_level0_col4" class="col_heading level0 col4" >0.500000</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5b8a4_level0_row0" class="row_heading level0 row0" >full_attention_TC</th>
#       <td id="T_5b8a4_row0_col0" class="data row0 col0" >0.062</td>
#       <td id="T_5b8a4_row0_col1" class="data row0 col1" >0.087</td>
#       <td id="T_5b8a4_row0_col2" class="data row0 col2" >0.138</td>
#       <td id="T_5b8a4_row0_col3" class="data row0 col3" >0.258</td>
#       <td id="T_5b8a4_row0_col4" class="data row0 col4" >0.647</td>
#     </tr>
#     <tr>
#       <th id="T_5b8a4_level0_row1" class="row_heading level0 row1" >full_attention_TCTC</th>
#       <td id="T_5b8a4_row1_col0" class="data row1 col0" >0.012</td>
#       <td id="T_5b8a4_row1_col1" class="data row1 col1" >0.077</td>
#       <td id="T_5b8a4_row1_col2" class="data row1 col2" >0.131</td>
#       <td id="T_5b8a4_row1_col3" class="data row1 col3" >0.227</td>
#       <td id="T_5b8a4_row1_col4" class="data row1 col4" >0.564</td>
#     </tr>
#     <tr>
#       <th id="T_5b8a4_level0_row2" class="row_heading level0 row2" >theo_correl</th>
#       <td id="T_5b8a4_row2_col0" class="data row2 col0" >0.022</td>
#       <td id="T_5b8a4_row2_col1" class="data row2 col1" >0.056</td>
#       <td id="T_5b8a4_row2_col2" class="data row2 col2" >0.112</td>
#       <td id="T_5b8a4_row2_col3" class="data row2 col3" >0.222</td>
#       <td id="T_5b8a4_row2_col4" class="data row2 col4" >0.542</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_fcbcc_row0_col0 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_fcbcc_row0_col1 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# #T_fcbcc_row0_col2 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_fcbcc_row0_col3 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_fcbcc_row0_col4 {
#   background-color: #e8765c;
#   color: #f1f1f1;
# }
# #T_fcbcc_row1_col0, #T_fcbcc_row2_col0 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_fcbcc_row1_col1 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_fcbcc_row1_col2 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_fcbcc_row1_col3 {
#   background-color: #f5c2aa;
#   color: #000000;
# }
# #T_fcbcc_row1_col4 {
#   background-color: #ec8165;
#   color: #f1f1f1;
# }
# #T_fcbcc_row2_col1 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_fcbcc_row2_col2 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_fcbcc_row2_col3 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_fcbcc_row2_col4 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# </style>
# <table id="T_fcbcc">
#   <thead>
#     <tr>
#       <th class="index_name level0" >rho</th>
#       <th id="T_fcbcc_level0_col0" class="col_heading level0 col0" >0.020000</th>
#       <th id="T_fcbcc_level0_col1" class="col_heading level0 col1" >0.050000</th>
#       <th id="T_fcbcc_level0_col2" class="col_heading level0 col2" >0.100000</th>
#       <th id="T_fcbcc_level0_col3" class="col_heading level0 col3" >0.200000</th>
#       <th id="T_fcbcc_level0_col4" class="col_heading level0 col4" >0.500000</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fcbcc_level0_row0" class="row_heading level0 row0" >full_attention_TC</th>
#       <td id="T_fcbcc_row0_col0" class="data row0 col0" >0.074</td>
#       <td id="T_fcbcc_row0_col1" class="data row0 col1" >0.124</td>
#       <td id="T_fcbcc_row0_col2" class="data row0 col2" >0.139</td>
#       <td id="T_fcbcc_row0_col3" class="data row0 col3" >0.294</td>
#       <td id="T_fcbcc_row0_col4" class="data row0 col4" >0.662</td>
#     </tr>
#     <tr>
#       <th id="T_fcbcc_level0_row1" class="row_heading level0 row1" >full_attention_TCTC</th>
#       <td id="T_fcbcc_row1_col0" class="data row1 col0" >0.014</td>
#       <td id="T_fcbcc_row1_col1" class="data row1 col1" >0.090</td>
#       <td id="T_fcbcc_row1_col2" class="data row1 col2" >0.156</td>
#       <td id="T_fcbcc_row1_col3" class="data row1 col3" >0.259</td>
#       <td id="T_fcbcc_row1_col4" class="data row1 col4" >0.617</td>
#     </tr>
#     <tr>
#       <th id="T_fcbcc_level0_row2" class="row_heading level0 row2" >theo_correl</th>
#       <td id="T_fcbcc_row2_col0" class="data row2 col0" >0.010</td>
#       <td id="T_fcbcc_row2_col1" class="data row2 col1" >0.025</td>
#       <td id="T_fcbcc_row2_col2" class="data row2 col2" >0.050</td>
#       <td id="T_fcbcc_row2_col3" class="data row2 col3" >0.102</td>
#       <td id="T_fcbcc_row2_col4" class="data row2 col4" >0.277</td>
#     </tr>
#   </tbody>
# </table>

# %%
tfull_shift_train, tfull_shift_test = run_models([0.02, 0.05, 0.1, 0.2, 0.5], 'd_shift')
# Out:
# Running correl level: 0.02
# /Users/gremy/Code/TSNN-1/tsnn-env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# /Users/gremy/Code/TSNN-1/tsnn-env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# Running correl level: 0.05
# /Users/gremy/Code/TSNN-1/tsnn-env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# /Users/gremy/Code/TSNN-1/tsnn-env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# Running correl level: 0.1
# /Users/gremy/Code/TSNN-1/tsnn-env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# /Users/gremy/Code/TSNN-1/tsnn-env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# Running correl level: 0.2
# /Users/gremy/Code/TSNN-1/tsnn-env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# /Users/gremy/Code/TSNN-1/tsnn-env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# Running correl level: 0.5
# /Users/gremy/Code/TSNN-1/tsnn-env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# /Users/gremy/Code/TSNN-1/tsnn-env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)

# %%
display(tfull_shift_train.T.style.background_gradient(cmap='coolwarm', vmin=-1, vmax=1).format(precision=3))
display(tfull_shift_test.T.style.background_gradient(cmap='coolwarm', vmin=-1, vmax=1).format(precision=3))
# Out:
# <style type="text/css">
# #T_67ccb_row0_col0, #T_67ccb_row1_col0 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_67ccb_row0_col1, #T_67ccb_row1_col1 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_67ccb_row0_col2, #T_67ccb_row2_col2 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_67ccb_row0_col3 {
#   background-color: #f5c4ac;
#   color: #000000;
# }
# #T_67ccb_row0_col4, #T_67ccb_row2_col4 {
#   background-color: #f29072;
#   color: #f1f1f1;
# }
# #T_67ccb_row1_col2 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_67ccb_row1_col3 {
#   background-color: #f3c7b1;
#   color: #000000;
# }
# #T_67ccb_row1_col4 {
#   background-color: #f39475;
#   color: #000000;
# }
# #T_67ccb_row2_col0 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_67ccb_row2_col1 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_67ccb_row2_col3 {
#   background-color: #f3c8b2;
#   color: #000000;
# }
# </style>
# <table id="T_67ccb">
#   <thead>
#     <tr>
#       <th class="index_name level0" >rho</th>
#       <th id="T_67ccb_level0_col0" class="col_heading level0 col0" >0.020000</th>
#       <th id="T_67ccb_level0_col1" class="col_heading level0 col1" >0.050000</th>
#       <th id="T_67ccb_level0_col2" class="col_heading level0 col2" >0.100000</th>
#       <th id="T_67ccb_level0_col3" class="col_heading level0 col3" >0.200000</th>
#       <th id="T_67ccb_level0_col4" class="col_heading level0 col4" >0.500000</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_67ccb_level0_row0" class="row_heading level0 row0" >full_attention_TC</th>
#       <td id="T_67ccb_row0_col0" class="data row0 col0" >0.012</td>
#       <td id="T_67ccb_row0_col1" class="data row0 col1" >0.049</td>
#       <td id="T_67ccb_row0_col2" class="data row0 col2" >0.111</td>
#       <td id="T_67ccb_row0_col3" class="data row0 col3" >0.250</td>
#       <td id="T_67ccb_row0_col4" class="data row0 col4" >0.540</td>
#     </tr>
#     <tr>
#       <th id="T_67ccb_level0_row1" class="row_heading level0 row1" >full_attention_TCTC</th>
#       <td id="T_67ccb_row1_col0" class="data row1 col0" >0.015</td>
#       <td id="T_67ccb_row1_col1" class="data row1 col1" >0.050</td>
#       <td id="T_67ccb_row1_col2" class="data row1 col2" >0.106</td>
#       <td id="T_67ccb_row1_col3" class="data row1 col3" >0.231</td>
#       <td id="T_67ccb_row1_col4" class="data row1 col4" >0.525</td>
#     </tr>
#     <tr>
#       <th id="T_67ccb_level0_row2" class="row_heading level0 row2" >theo_correl</th>
#       <td id="T_67ccb_row2_col0" class="data row2 col0" >0.022</td>
#       <td id="T_67ccb_row2_col1" class="data row2 col1" >0.056</td>
#       <td id="T_67ccb_row2_col2" class="data row2 col2" >0.112</td>
#       <td id="T_67ccb_row2_col3" class="data row2 col3" >0.222</td>
#       <td id="T_67ccb_row2_col4" class="data row2 col4" >0.542</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_9c37b_row0_col0 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_9c37b_row0_col1 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_9c37b_row0_col2 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_9c37b_row0_col3, #T_9c37b_row1_col3 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_9c37b_row0_col4 {
#   background-color: #f6a586;
#   color: #000000;
# }
# #T_9c37b_row1_col0, #T_9c37b_row2_col0 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_9c37b_row1_col1 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_9c37b_row1_col2 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_9c37b_row1_col4 {
#   background-color: #f7ad90;
#   color: #000000;
# }
# #T_9c37b_row2_col1 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_9c37b_row2_col2 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_9c37b_row2_col3 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_9c37b_row2_col4 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# </style>
# <table id="T_9c37b">
#   <thead>
#     <tr>
#       <th class="index_name level0" >rho</th>
#       <th id="T_9c37b_level0_col0" class="col_heading level0 col0" >0.020000</th>
#       <th id="T_9c37b_level0_col1" class="col_heading level0 col1" >0.050000</th>
#       <th id="T_9c37b_level0_col2" class="col_heading level0 col2" >0.100000</th>
#       <th id="T_9c37b_level0_col3" class="col_heading level0 col3" >0.200000</th>
#       <th id="T_9c37b_level0_col4" class="col_heading level0 col4" >0.500000</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9c37b_level0_row0" class="row_heading level0 row0" >full_attention_TC</th>
#       <td id="T_9c37b_row0_col0" class="data row0 col0" >0.007</td>
#       <td id="T_9c37b_row0_col1" class="data row0 col1" >0.033</td>
#       <td id="T_9c37b_row0_col2" class="data row0 col2" >0.079</td>
#       <td id="T_9c37b_row0_col3" class="data row0 col3" >0.197</td>
#       <td id="T_9c37b_row0_col4" class="data row0 col4" >0.440</td>
#     </tr>
#     <tr>
#       <th id="T_9c37b_level0_row1" class="row_heading level0 row1" >full_attention_TCTC</th>
#       <td id="T_9c37b_row1_col0" class="data row1 col0" >0.008</td>
#       <td id="T_9c37b_row1_col1" class="data row1 col1" >0.022</td>
#       <td id="T_9c37b_row1_col2" class="data row1 col2" >0.066</td>
#       <td id="T_9c37b_row1_col3" class="data row1 col3" >0.200</td>
#       <td id="T_9c37b_row1_col4" class="data row1 col4" >0.397</td>
#     </tr>
#     <tr>
#       <th id="T_9c37b_level0_row2" class="row_heading level0 row2" >theo_correl</th>
#       <td id="T_9c37b_row2_col0" class="data row2 col0" >0.010</td>
#       <td id="T_9c37b_row2_col1" class="data row2 col1" >0.025</td>
#       <td id="T_9c37b_row2_col2" class="data row2 col2" >0.050</td>
#       <td id="T_9c37b_row2_col3" class="data row2 col3" >0.102</td>
#       <td id="T_9c37b_row2_col4" class="data row2 col4" >0.277</td>
#     </tr>
#   </tbody>
# </table>

# %%
tfull_cond_train, tfull_cond_test = run_models([0.02, 0.05, 0.1, 0.2, 0.5], 'd_cond')
# Out:
# Running correl level: 0.02
# /Users/gremy/Code/TSNN-1/tsnn-env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# /Users/gremy/Code/TSNN-1/tsnn-env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# Running correl level: 0.05
# /Users/gremy/Code/TSNN-1/tsnn-env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# /Users/gremy/Code/TSNN-1/tsnn-env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# Running correl level: 0.1
# /Users/gremy/Code/TSNN-1/tsnn-env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# /Users/gremy/Code/TSNN-1/tsnn-env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# Running correl level: 0.2
# /Users/gremy/Code/TSNN-1/tsnn-env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# /Users/gremy/Code/TSNN-1/tsnn-env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# Running correl level: 0.5
# /Users/gremy/Code/TSNN-1/tsnn-env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# /Users/gremy/Code/TSNN-1/tsnn-env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)

# %%
display(tfull_cond_train.T.style.background_gradient(cmap='coolwarm', vmin=-1, vmax=1).format(precision=3))
display(tfull_cond_test.T.style.background_gradient(cmap='coolwarm', vmin=-1, vmax=1).format(precision=3))
# Out:
# <style type="text/css">
# #T_11d22_row0_col0 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_11d22_row0_col1, #T_11d22_row1_col1 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_11d22_row0_col2 {
#   background-color: #ecd3c5;
#   color: #000000;
# }
# #T_11d22_row0_col3 {
#   background-color: #f5c4ac;
#   color: #000000;
# }
# #T_11d22_row0_col4 {
#   background-color: #f29274;
#   color: #f1f1f1;
# }
# #T_11d22_row1_col0, #T_11d22_row2_col0 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_11d22_row1_col2 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_11d22_row1_col3 {
#   background-color: #f4c6af;
#   color: #000000;
# }
# #T_11d22_row1_col4 {
#   background-color: #f59c7d;
#   color: #000000;
# }
# #T_11d22_row2_col1 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_11d22_row2_col2 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_11d22_row2_col3 {
#   background-color: #f3c8b2;
#   color: #000000;
# }
# #T_11d22_row2_col4 {
#   background-color: #f29072;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_11d22">
#   <thead>
#     <tr>
#       <th class="index_name level0" >rho</th>
#       <th id="T_11d22_level0_col0" class="col_heading level0 col0" >0.020000</th>
#       <th id="T_11d22_level0_col1" class="col_heading level0 col1" >0.050000</th>
#       <th id="T_11d22_level0_col2" class="col_heading level0 col2" >0.100000</th>
#       <th id="T_11d22_level0_col3" class="col_heading level0 col3" >0.200000</th>
#       <th id="T_11d22_level0_col4" class="col_heading level0 col4" >0.500000</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_11d22_level0_row0" class="row_heading level0 row0" >full_attention_TC</th>
#       <td id="T_11d22_row0_col0" class="data row0 col0" >0.032</td>
#       <td id="T_11d22_row0_col1" class="data row0 col1" >0.087</td>
#       <td id="T_11d22_row0_col2" class="data row0 col2" >0.129</td>
#       <td id="T_11d22_row0_col3" class="data row0 col3" >0.252</td>
#       <td id="T_11d22_row0_col4" class="data row0 col4" >0.535</td>
#     </tr>
#     <tr>
#       <th id="T_11d22_level0_row1" class="row_heading level0 row1" >full_attention_TCTC</th>
#       <td id="T_11d22_row1_col0" class="data row1 col0" >0.022</td>
#       <td id="T_11d22_row1_col1" class="data row1 col1" >0.090</td>
#       <td id="T_11d22_row1_col2" class="data row1 col2" >0.102</td>
#       <td id="T_11d22_row1_col3" class="data row1 col3" >0.236</td>
#       <td id="T_11d22_row1_col4" class="data row1 col4" >0.489</td>
#     </tr>
#     <tr>
#       <th id="T_11d22_level0_row2" class="row_heading level0 row2" >theo_correl</th>
#       <td id="T_11d22_row2_col0" class="data row2 col0" >0.022</td>
#       <td id="T_11d22_row2_col1" class="data row2 col1" >0.056</td>
#       <td id="T_11d22_row2_col2" class="data row2 col2" >0.112</td>
#       <td id="T_11d22_row2_col3" class="data row2 col3" >0.222</td>
#       <td id="T_11d22_row2_col4" class="data row2 col4" >0.542</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_0c0e3_row0_col0 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_0c0e3_row0_col1 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_0c0e3_row0_col2, #T_0c0e3_row1_col2 {
#   background-color: #ecd3c5;
#   color: #000000;
# }
# #T_0c0e3_row0_col3 {
#   background-color: #f4c5ad;
#   color: #000000;
# }
# #T_0c0e3_row0_col4 {
#   background-color: #f59f80;
#   color: #000000;
# }
# #T_0c0e3_row1_col0, #T_0c0e3_row2_col1 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_0c0e3_row1_col1 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_0c0e3_row1_col3 {
#   background-color: #f4c6af;
#   color: #000000;
# }
# #T_0c0e3_row1_col4 {
#   background-color: #f59d7e;
#   color: #000000;
# }
# #T_0c0e3_row2_col0 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_0c0e3_row2_col2 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_0c0e3_row2_col3 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_0c0e3_row2_col4 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# </style>
# <table id="T_0c0e3">
#   <thead>
#     <tr>
#       <th class="index_name level0" >rho</th>
#       <th id="T_0c0e3_level0_col0" class="col_heading level0 col0" >0.020000</th>
#       <th id="T_0c0e3_level0_col1" class="col_heading level0 col1" >0.050000</th>
#       <th id="T_0c0e3_level0_col2" class="col_heading level0 col2" >0.100000</th>
#       <th id="T_0c0e3_level0_col3" class="col_heading level0 col3" >0.200000</th>
#       <th id="T_0c0e3_level0_col4" class="col_heading level0 col4" >0.500000</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0c0e3_level0_row0" class="row_heading level0 row0" >full_attention_TC</th>
#       <td id="T_0c0e3_row0_col0" class="data row0 col0" >0.036</td>
#       <td id="T_0c0e3_row0_col1" class="data row0 col1" >0.085</td>
#       <td id="T_0c0e3_row0_col2" class="data row0 col2" >0.128</td>
#       <td id="T_0c0e3_row0_col3" class="data row0 col3" >0.245</td>
#       <td id="T_0c0e3_row0_col4" class="data row0 col4" >0.476</td>
#     </tr>
#     <tr>
#       <th id="T_0c0e3_level0_row1" class="row_heading level0 row1" >full_attention_TCTC</th>
#       <td id="T_0c0e3_row1_col0" class="data row1 col0" >0.027</td>
#       <td id="T_0c0e3_row1_col1" class="data row1 col1" >0.088</td>
#       <td id="T_0c0e3_row1_col2" class="data row1 col2" >0.133</td>
#       <td id="T_0c0e3_row1_col3" class="data row1 col3" >0.242</td>
#       <td id="T_0c0e3_row1_col4" class="data row1 col4" >0.479</td>
#     </tr>
#     <tr>
#       <th id="T_0c0e3_level0_row2" class="row_heading level0 row2" >theo_correl</th>
#       <td id="T_0c0e3_row2_col0" class="data row2 col0" >0.010</td>
#       <td id="T_0c0e3_row2_col1" class="data row2 col1" >0.025</td>
#       <td id="T_0c0e3_row2_col2" class="data row2 col2" >0.050</td>
#       <td id="T_0c0e3_row2_col3" class="data row2 col3" >0.102</td>
#       <td id="T_0c0e3_row2_col4" class="data row2 col4" >0.277</td>
#     </tr>
#   </tbody>
# </table>

# %%
tfull_cs_train, tfull_cs_test = run_models([0.02, 0.05, 0.1, 0.2, 0.5], 'd_cs')
# Out:
# Running correl level: 0.02
# /Users/gremy/Code/TSNN-1/tsnn-env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# /Users/gremy/Code/TSNN-1/tsnn-env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# Running correl level: 0.05
# /Users/gremy/Code/TSNN-1/tsnn-env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# /Users/gremy/Code/TSNN-1/tsnn-env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# Running correl level: 0.1
# /Users/gremy/Code/TSNN-1/tsnn-env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# /Users/gremy/Code/TSNN-1/tsnn-env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# Running correl level: 0.2
# /Users/gremy/Code/TSNN-1/tsnn-env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# /Users/gremy/Code/TSNN-1/tsnn-env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# Running correl level: 0.5
# /Users/gremy/Code/TSNN-1/tsnn-env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# /Users/gremy/Code/TSNN-1/tsnn-env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)

# %%
display(tfull_cs_train.T.style.background_gradient(cmap='coolwarm', vmin=-1, vmax=1).format(precision=3))
display(tfull_cs_test.T.style.background_gradient(cmap='coolwarm', vmin=-1, vmax=1).format(precision=3))
# Out:
# <style type="text/css">
# #T_8aa40_row0_col0 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_8aa40_row0_col1, #T_8aa40_row2_col1 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_8aa40_row0_col2, #T_8aa40_row2_col2 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_8aa40_row0_col3, #T_8aa40_row2_col3 {
#   background-color: #f3c8b2;
#   color: #000000;
# }
# #T_8aa40_row0_col4 {
#   background-color: #f39577;
#   color: #000000;
# }
# #T_8aa40_row1_col0, #T_8aa40_row2_col0 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_8aa40_row1_col1 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_8aa40_row1_col2 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_8aa40_row1_col3 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# #T_8aa40_row1_col4 {
#   background-color: #f59f80;
#   color: #000000;
# }
# #T_8aa40_row2_col4 {
#   background-color: #f29072;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_8aa40">
#   <thead>
#     <tr>
#       <th class="index_name level0" >rho</th>
#       <th id="T_8aa40_level0_col0" class="col_heading level0 col0" >0.020000</th>
#       <th id="T_8aa40_level0_col1" class="col_heading level0 col1" >0.050000</th>
#       <th id="T_8aa40_level0_col2" class="col_heading level0 col2" >0.100000</th>
#       <th id="T_8aa40_level0_col3" class="col_heading level0 col3" >0.200000</th>
#       <th id="T_8aa40_level0_col4" class="col_heading level0 col4" >0.500000</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8aa40_level0_row0" class="row_heading level0 row0" >full_attention_TC</th>
#       <td id="T_8aa40_row0_col0" class="data row0 col0" >0.028</td>
#       <td id="T_8aa40_row0_col1" class="data row0 col1" >0.056</td>
#       <td id="T_8aa40_row0_col2" class="data row0 col2" >0.115</td>
#       <td id="T_8aa40_row0_col3" class="data row0 col3" >0.225</td>
#       <td id="T_8aa40_row0_col4" class="data row0 col4" >0.519</td>
#     </tr>
#     <tr>
#       <th id="T_8aa40_level0_row1" class="row_heading level0 row1" >full_attention_TCTC</th>
#       <td id="T_8aa40_row1_col0" class="data row1 col0" >0.020</td>
#       <td id="T_8aa40_row1_col1" class="data row1 col1" >0.048</td>
#       <td id="T_8aa40_row1_col2" class="data row1 col2" >0.106</td>
#       <td id="T_8aa40_row1_col3" class="data row1 col3" >0.207</td>
#       <td id="T_8aa40_row1_col4" class="data row1 col4" >0.471</td>
#     </tr>
#     <tr>
#       <th id="T_8aa40_level0_row2" class="row_heading level0 row2" >theo_correl</th>
#       <td id="T_8aa40_row2_col0" class="data row2 col0" >0.022</td>
#       <td id="T_8aa40_row2_col1" class="data row2 col1" >0.056</td>
#       <td id="T_8aa40_row2_col2" class="data row2 col2" >0.112</td>
#       <td id="T_8aa40_row2_col3" class="data row2 col3" >0.222</td>
#       <td id="T_8aa40_row2_col4" class="data row2 col4" >0.542</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_4084d_row0_col0, #T_4084d_row1_col0 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_4084d_row0_col1, #T_4084d_row2_col2 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_4084d_row0_col2 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_4084d_row0_col3 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# #T_4084d_row0_col4 {
#   background-color: #f39778;
#   color: #000000;
# }
# #T_4084d_row1_col1 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_4084d_row1_col2 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_4084d_row1_col3 {
#   background-color: #f3c8b2;
#   color: #000000;
# }
# #T_4084d_row1_col4 {
#   background-color: #f39475;
#   color: #000000;
# }
# #T_4084d_row2_col0 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_4084d_row2_col1 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_4084d_row2_col3 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_4084d_row2_col4 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# </style>
# <table id="T_4084d">
#   <thead>
#     <tr>
#       <th class="index_name level0" >rho</th>
#       <th id="T_4084d_level0_col0" class="col_heading level0 col0" >0.020000</th>
#       <th id="T_4084d_level0_col1" class="col_heading level0 col1" >0.050000</th>
#       <th id="T_4084d_level0_col2" class="col_heading level0 col2" >0.100000</th>
#       <th id="T_4084d_level0_col3" class="col_heading level0 col3" >0.200000</th>
#       <th id="T_4084d_level0_col4" class="col_heading level0 col4" >0.500000</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4084d_level0_row0" class="row_heading level0 row0" >full_attention_TC</th>
#       <td id="T_4084d_row0_col0" class="data row0 col0" >0.019</td>
#       <td id="T_4084d_row0_col1" class="data row0 col1" >0.053</td>
#       <td id="T_4084d_row0_col2" class="data row0 col2" >0.088</td>
#       <td id="T_4084d_row0_col3" class="data row0 col3" >0.204</td>
#       <td id="T_4084d_row0_col4" class="data row0 col4" >0.510</td>
#     </tr>
#     <tr>
#       <th id="T_4084d_level0_row1" class="row_heading level0 row1" >full_attention_TCTC</th>
#       <td id="T_4084d_row1_col0" class="data row1 col0" >0.019</td>
#       <td id="T_4084d_row1_col1" class="data row1 col1" >0.062</td>
#       <td id="T_4084d_row1_col2" class="data row1 col2" >0.082</td>
#       <td id="T_4084d_row1_col3" class="data row1 col3" >0.224</td>
#       <td id="T_4084d_row1_col4" class="data row1 col4" >0.530</td>
#     </tr>
#     <tr>
#       <th id="T_4084d_level0_row2" class="row_heading level0 row2" >theo_correl</th>
#       <td id="T_4084d_row2_col0" class="data row2 col0" >0.010</td>
#       <td id="T_4084d_row2_col1" class="data row2 col1" >0.025</td>
#       <td id="T_4084d_row2_col2" class="data row2 col2" >0.050</td>
#       <td id="T_4084d_row2_col3" class="data row2 col3" >0.102</td>
#       <td id="T_4084d_row2_col4" class="data row2 col4" >0.277</td>
#     </tr>
#   </tbody>
# </table>

# %%
tfull_cs_shift_train, tfull_cs_shift_test = run_models([0.02, 0.05, 0.1, 0.2, 0.5], 'd_cs_shift')
# Out:
# Running correl level: 0.02
# /Users/gremy/Code/TSNN-1/tsnn-env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# /Users/gremy/Code/TSNN-1/tsnn-env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# Running correl level: 0.05
# /Users/gremy/Code/TSNN-1/tsnn-env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# /Users/gremy/Code/TSNN-1/tsnn-env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# Running correl level: 0.1
# /Users/gremy/Code/TSNN-1/tsnn-env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# /Users/gremy/Code/TSNN-1/tsnn-env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# Running correl level: 0.2
# /Users/gremy/Code/TSNN-1/tsnn-env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# /Users/gremy/Code/TSNN-1/tsnn-env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# Running correl level: 0.5
# /Users/gremy/Code/TSNN-1/tsnn-env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# /Users/gremy/Code/TSNN-1/tsnn-env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)

# %%
display(tfull_cs_shift_train.T.style.background_gradient(cmap='coolwarm', vmin=-1, vmax=1).format(precision=3))
display(tfull_cs_shift_test.T.style.background_gradient(cmap='coolwarm', vmin=-1, vmax=1).format(precision=3))
# Out:
# <style type="text/css">
# #T_ddd25_row0_col0, #T_ddd25_row1_col0, #T_ddd25_row2_col0 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_ddd25_row0_col1, #T_ddd25_row1_col1 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_ddd25_row0_col2 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_ddd25_row0_col3 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_ddd25_row0_col4 {
#   background-color: #f7b497;
#   color: #000000;
# }
# #T_ddd25_row1_col2 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_ddd25_row1_col3 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_ddd25_row1_col4 {
#   background-color: #f7ad90;
#   color: #000000;
# }
# #T_ddd25_row2_col1 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_ddd25_row2_col2 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_ddd25_row2_col3 {
#   background-color: #f3c8b2;
#   color: #000000;
# }
# #T_ddd25_row2_col4 {
#   background-color: #f29072;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_ddd25">
#   <thead>
#     <tr>
#       <th class="index_name level0" >rho</th>
#       <th id="T_ddd25_level0_col0" class="col_heading level0 col0" >0.020000</th>
#       <th id="T_ddd25_level0_col1" class="col_heading level0 col1" >0.050000</th>
#       <th id="T_ddd25_level0_col2" class="col_heading level0 col2" >0.100000</th>
#       <th id="T_ddd25_level0_col3" class="col_heading level0 col3" >0.200000</th>
#       <th id="T_ddd25_level0_col4" class="col_heading level0 col4" >0.500000</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ddd25_level0_row0" class="row_heading level0 row0" >full_attention_TC</th>
#       <td id="T_ddd25_row0_col0" class="data row0 col0" >0.020</td>
#       <td id="T_ddd25_row0_col1" class="data row0 col1" >0.043</td>
#       <td id="T_ddd25_row0_col2" class="data row0 col2" >0.088</td>
#       <td id="T_ddd25_row0_col3" class="data row0 col3" >0.156</td>
#       <td id="T_ddd25_row0_col4" class="data row0 col4" >0.359</td>
#     </tr>
#     <tr>
#       <th id="T_ddd25_level0_row1" class="row_heading level0 row1" >full_attention_TCTC</th>
#       <td id="T_ddd25_row1_col0" class="data row1 col0" >0.023</td>
#       <td id="T_ddd25_row1_col1" class="data row1 col1" >0.041</td>
#       <td id="T_ddd25_row1_col2" class="data row1 col2" >0.094</td>
#       <td id="T_ddd25_row1_col3" class="data row1 col3" >0.186</td>
#       <td id="T_ddd25_row1_col4" class="data row1 col4" >0.394</td>
#     </tr>
#     <tr>
#       <th id="T_ddd25_level0_row2" class="row_heading level0 row2" >theo_correl</th>
#       <td id="T_ddd25_row2_col0" class="data row2 col0" >0.022</td>
#       <td id="T_ddd25_row2_col1" class="data row2 col1" >0.056</td>
#       <td id="T_ddd25_row2_col2" class="data row2 col2" >0.112</td>
#       <td id="T_ddd25_row2_col3" class="data row2 col3" >0.222</td>
#       <td id="T_ddd25_row2_col4" class="data row2 col4" >0.542</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_843d3_row0_col0, #T_843d3_row0_col3, #T_843d3_row1_col1 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_843d3_row0_col1, #T_843d3_row1_col3, #T_843d3_row2_col0 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_843d3_row0_col2, #T_843d3_row0_col4, #T_843d3_row1_col0, #T_843d3_row1_col2, #T_843d3_row1_col4 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_843d3_row2_col1 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_843d3_row2_col2 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_843d3_row2_col3 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_843d3_row2_col4 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# </style>
# <table id="T_843d3">
#   <thead>
#     <tr>
#       <th class="index_name level0" >rho</th>
#       <th id="T_843d3_level0_col0" class="col_heading level0 col0" >0.020000</th>
#       <th id="T_843d3_level0_col1" class="col_heading level0 col1" >0.050000</th>
#       <th id="T_843d3_level0_col2" class="col_heading level0 col2" >0.100000</th>
#       <th id="T_843d3_level0_col3" class="col_heading level0 col3" >0.200000</th>
#       <th id="T_843d3_level0_col4" class="col_heading level0 col4" >0.500000</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_843d3_level0_row0" class="row_heading level0 row0" >full_attention_TC</th>
#       <td id="T_843d3_row0_col0" class="data row0 col0" >-0.000</td>
#       <td id="T_843d3_row0_col1" class="data row0 col1" >0.013</td>
#       <td id="T_843d3_row0_col2" class="data row0 col2" >0.003</td>
#       <td id="T_843d3_row0_col3" class="data row0 col3" >-0.004</td>
#       <td id="T_843d3_row0_col4" class="data row0 col4" >0.001</td>
#     </tr>
#     <tr>
#       <th id="T_843d3_level0_row1" class="row_heading level0 row1" >full_attention_TCTC</th>
#       <td id="T_843d3_row1_col0" class="data row1 col0" >0.002</td>
#       <td id="T_843d3_row1_col1" class="data row1 col1" >-0.002</td>
#       <td id="T_843d3_row1_col2" class="data row1 col2" >0.003</td>
#       <td id="T_843d3_row1_col3" class="data row1 col3" >0.012</td>
#       <td id="T_843d3_row1_col4" class="data row1 col4" >0.006</td>
#     </tr>
#     <tr>
#       <th id="T_843d3_level0_row2" class="row_heading level0 row2" >theo_correl</th>
#       <td id="T_843d3_row2_col0" class="data row2 col0" >0.010</td>
#       <td id="T_843d3_row2_col1" class="data row2 col1" >0.025</td>
#       <td id="T_843d3_row2_col2" class="data row2 col2" >0.050</td>
#       <td id="T_843d3_row2_col3" class="data row2 col3" >0.102</td>
#       <td id="T_843d3_row2_col4" class="data row2 col4" >0.277</td>
#     </tr>
#   </tbody>
# </table>

# %%
tfull_all_train, tfull_all_test = run_models([0.02, 0.05, 0.1, 0.2, 0.5], 'd_all')
# Out:
# Running correl level: 0.02
# /Users/gremy/Code/TSNN-1/tsnn-env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# /Users/gremy/Code/TSNN-1/tsnn-env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# Running correl level: 0.05
# /Users/gremy/Code/TSNN-1/tsnn-env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# /Users/gremy/Code/TSNN-1/tsnn-env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# Running correl level: 0.1
# /Users/gremy/Code/TSNN-1/tsnn-env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# /Users/gremy/Code/TSNN-1/tsnn-env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# Running correl level: 0.2
# /Users/gremy/Code/TSNN-1/tsnn-env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# /Users/gremy/Code/TSNN-1/tsnn-env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# Running correl level: 0.5
# /Users/gremy/Code/TSNN-1/tsnn-env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# /Users/gremy/Code/TSNN-1/tsnn-env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)

# %%
display(tfull_all_train.T.style.background_gradient(cmap='coolwarm', vmin=-1, vmax=1).format(precision=3))
display(tfull_all_test.T.style.background_gradient(cmap='coolwarm', vmin=-1, vmax=1).format(precision=3))
# Out:
# <style type="text/css">
# #T_02bec_row0_col0 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_02bec_row0_col1 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_02bec_row0_col2 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# #T_02bec_row0_col3 {
#   background-color: #f3c7b1;
#   color: #000000;
# }
# #T_02bec_row0_col4 {
#   background-color: #f39577;
#   color: #000000;
# }
# #T_02bec_row1_col0 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_02bec_row1_col1 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_02bec_row1_col2, #T_02bec_row2_col2 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_02bec_row1_col3 {
#   background-color: #f2c9b4;
#   color: #000000;
# }
# #T_02bec_row1_col4 {
#   background-color: #f59f80;
#   color: #000000;
# }
# #T_02bec_row2_col0 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_02bec_row2_col1 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_02bec_row2_col3 {
#   background-color: #f3c8b2;
#   color: #000000;
# }
# #T_02bec_row2_col4 {
#   background-color: #f29072;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_02bec">
#   <thead>
#     <tr>
#       <th class="index_name level0" >rho</th>
#       <th id="T_02bec_level0_col0" class="col_heading level0 col0" >0.020000</th>
#       <th id="T_02bec_level0_col1" class="col_heading level0 col1" >0.050000</th>
#       <th id="T_02bec_level0_col2" class="col_heading level0 col2" >0.100000</th>
#       <th id="T_02bec_level0_col3" class="col_heading level0 col3" >0.200000</th>
#       <th id="T_02bec_level0_col4" class="col_heading level0 col4" >0.500000</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_02bec_level0_row0" class="row_heading level0 row0" >full_attention_TC</th>
#       <td id="T_02bec_row0_col0" class="data row0 col0" >0.038</td>
#       <td id="T_02bec_row0_col1" class="data row0 col1" >0.081</td>
#       <td id="T_02bec_row0_col2" class="data row0 col2" >0.124</td>
#       <td id="T_02bec_row0_col3" class="data row0 col3" >0.231</td>
#       <td id="T_02bec_row0_col4" class="data row0 col4" >0.518</td>
#     </tr>
#     <tr>
#       <th id="T_02bec_level0_row1" class="row_heading level0 row1" >full_attention_TCTC</th>
#       <td id="T_02bec_row1_col0" class="data row1 col0" >0.029</td>
#       <td id="T_02bec_row1_col1" class="data row1 col1" >0.073</td>
#       <td id="T_02bec_row1_col2" class="data row1 col2" >0.115</td>
#       <td id="T_02bec_row1_col3" class="data row1 col3" >0.214</td>
#       <td id="T_02bec_row1_col4" class="data row1 col4" >0.476</td>
#     </tr>
#     <tr>
#       <th id="T_02bec_level0_row2" class="row_heading level0 row2" >theo_correl</th>
#       <td id="T_02bec_row2_col0" class="data row2 col0" >0.022</td>
#       <td id="T_02bec_row2_col1" class="data row2 col1" >0.056</td>
#       <td id="T_02bec_row2_col2" class="data row2 col2" >0.112</td>
#       <td id="T_02bec_row2_col3" class="data row2 col3" >0.222</td>
#       <td id="T_02bec_row2_col4" class="data row2 col4" >0.542</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_96932_row0_col0, #T_96932_row1_col0, #T_96932_row2_col0 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_96932_row0_col1 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_96932_row0_col2 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_96932_row0_col3 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_96932_row0_col4 {
#   background-color: #f7a688;
#   color: #000000;
# }
# #T_96932_row1_col1 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_96932_row1_col2 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_96932_row1_col3 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# #T_96932_row1_col4 {
#   background-color: #f7b093;
#   color: #000000;
# }
# #T_96932_row2_col1 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_96932_row2_col2 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_96932_row2_col3 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_96932_row2_col4 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# </style>
# <table id="T_96932">
#   <thead>
#     <tr>
#       <th class="index_name level0" >rho</th>
#       <th id="T_96932_level0_col0" class="col_heading level0 col0" >0.020000</th>
#       <th id="T_96932_level0_col1" class="col_heading level0 col1" >0.050000</th>
#       <th id="T_96932_level0_col2" class="col_heading level0 col2" >0.100000</th>
#       <th id="T_96932_level0_col3" class="col_heading level0 col3" >0.200000</th>
#       <th id="T_96932_level0_col4" class="col_heading level0 col4" >0.500000</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_96932_level0_row0" class="row_heading level0 row0" >full_attention_TC</th>
#       <td id="T_96932_row0_col0" class="data row0 col0" >0.010</td>
#       <td id="T_96932_row0_col1" class="data row0 col1" >0.074</td>
#       <td id="T_96932_row0_col2" class="data row0 col2" >0.110</td>
#       <td id="T_96932_row0_col3" class="data row0 col3" >0.181</td>
#       <td id="T_96932_row0_col4" class="data row0 col4" >0.430</td>
#     </tr>
#     <tr>
#       <th id="T_96932_level0_row1" class="row_heading level0 row1" >full_attention_TCTC</th>
#       <td id="T_96932_row1_col0" class="data row1 col0" >0.012</td>
#       <td id="T_96932_row1_col1" class="data row1 col1" >0.065</td>
#       <td id="T_96932_row1_col2" class="data row1 col2" >0.107</td>
#       <td id="T_96932_row1_col3" class="data row1 col3" >0.146</td>
#       <td id="T_96932_row1_col4" class="data row1 col4" >0.380</td>
#     </tr>
#     <tr>
#       <th id="T_96932_level0_row2" class="row_heading level0 row2" >theo_correl</th>
#       <td id="T_96932_row2_col0" class="data row2 col0" >0.010</td>
#       <td id="T_96932_row2_col1" class="data row2 col1" >0.025</td>
#       <td id="T_96932_row2_col2" class="data row2 col2" >0.050</td>
#       <td id="T_96932_row2_col3" class="data row2 col3" >0.102</td>
#       <td id="T_96932_row2_col4" class="data row2 col4" >0.277</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Bootstrap

# %%
def run_bootstrap(rho, effect, n=5, T=4000, n_ts=10, n_f=20, n_rolling=10, models_torch=None):

    mask = causal_mask
    mask_c = build_attention_mask(mask, n_rolling, device=device)

    if n_f < 10:
        pct_zero_corr = 0
    else:
        pct_zero_corr = 0.5

    c = rho/np.sqrt((1-pct_zero_corr)*n_f)

    arg_list = {'d_lin': {'pct_zero_corr': pct_zero_corr, 'split_conditional': 0.0, 'split_shift': 0.0, 'split_seasonal': 0.0, 'split_cs': 0.0, 'split_cs_shift': 0.0}, 
                'd_cond': {'pct_zero_corr': pct_zero_corr, 'split_conditional': 1.0, 'split_shift': 0.0, 'split_seasonal': 0.0, 'split_cs': 0.0, 'split_cs_shift': 0.0},  
                'd_shift': {'pct_zero_corr': pct_zero_corr, 'split_conditional': 0.0, 'split_shift': 1.0, 'split_seasonal': 0.0, 'split_cs': 0.0, 'split_cs_shift': 0.0}, 
                'd_cs': {'pct_zero_corr': pct_zero_corr, 'split_conditional': 0.0, 'split_shift': 0.0, 'split_seasonal': 0.0, 'split_cs': 1.0, 'split_cs_shift': 0.0}, 
                'd_cs_shift': {'pct_zero_corr': pct_zero_corr, 'split_conditional': 0.0, 'split_shift': 0.0, 'split_seasonal': 0.0, 'split_cs': 0.0, 'split_cs_shift': 1.0}, 
                'd_all': {'pct_zero_corr': pct_zero_corr, 'split_conditional': 0.2, 'split_shift': 0.2, 'split_seasonal': 0.0, 'split_cs': 0.2, 'split_cs_shift': 0.2}
               }
    
    z = generators.Generator(T, n_ts, n_f)
    
    res_train = []
    res_test = []
    for i in tqdm(range(n)):
        z.generate_dataset(
                pct_zero_corr=arg_list[effect]['pct_zero_corr'],
                split_conditional=arg_list[effect]['split_conditional'],
                split_shift=arg_list[effect]['split_shift'],
                split_seasonal=arg_list[effect]['split_seasonal'],
                split_cs=arg_list[effect]['split_cs'],
                split_cs_shift=arg_list[effect]['split_cs_shift'],
                random_ts_shift=n_rolling-1,
                low_corr=c,
                high_corr=c,
                shuffle_cs=True
            )

        z.get_dataloader()


        models_torch = {
            'full_attention_TC': models.CustomBiDimensionalTransformer(
                n_ts, n_f, n_rolling, mask=mask_c, layers='TC', nhead=8,
                dropout=0.1, dim_feedforward=256, sparsify=None, roll_y=True
            ).to(device),
            'full_attention_TCTC': models.CustomBiDimensionalTransformer(
                n_ts, n_f, n_rolling, mask=mask_c, layers='TCTC', nhead=8,
                dropout=0.1, dim_feedforward=256, sparsify=None, roll_y=True
            ).to(device),
        }

        models_torch = {
            k: torch_benchmarks.TorchWrapper(
                models_torch[k], 
                optimizer=torch.optim.AdamW(models_torch[k].parameters(), lr=0.001),
                loss_fn=nn.MSELoss()  
            ) for k in models_torch
        }


        z.get_dataloader(n_rolling=n_rolling, roll_y=True)
        for k in models_torch:
            models_torch[k].fit(z.train, test=z.test, epochs=10, plot=False, verbose=0)
            
      
        comp = benchmark_comparison.Comparator(models=[models_torch[k] for k in models_torch], 
        model_names=[k for k in models_torch]
        )
        
        # display(comp.correl(z, mode="test"))
        
        res_train.append(comp.correl(z, mode="train", return_values=True)['optimal'])
        res_test.append(comp.correl(z, mode="test", return_values=True)['optimal'])
        
    return res_train, res_test

# %%
#rhos = [0.01, 0.02, 0.05, 0.1, 0.2, 0.5]
#effects = ['d_lin', 'd_shift', 'd_cs', 'd_cs_shift', 'd_cond', 'd_all']

rhos = [0.1]
effects = ['d_shift']

import warnings

for rho in rhos:
    for effect in effects:
        with warnings.catch_warnings():
            warnings.simplefilter("ignore")
            r_train, r_test = run_bootstrap(rho, effect, n=3)
        # pd.concat(r_train, axis=1).T.to_parquet(f'gr_results1/full_{effect}_{c}_train.parquet')
        # pd.concat(r_test, axis=1).T.to_parquet(f'gr_results1/full_{effect}_{c}_test.parquet')
# Out:
# 100%|██████████| 3/3 [01:52<00:00, 37.36s/it]

# %%
r_train
# Out:
# [optimal                     NaN
#  shift                  1.000000
#  full_attention_TC      0.056089
#  full_attention_TCTC    0.042788
#  Name: optimal, dtype: float64,
#  optimal                     NaN
#  shift                  1.000000
#  full_attention_TC      0.163623
#  full_attention_TCTC    0.041542
#  Name: optimal, dtype: float64,
#  optimal                     NaN
#  shift                  1.000000
#  full_attention_TC      0.154661
#  full_attention_TCTC    0.046472
#  Name: optimal, dtype: float64]

# %%
r_test
# Out:
# [optimal                     NaN
#  shift                  1.000000
#  full_attention_TC      0.044705
#  full_attention_TCTC    0.032436
#  Name: optimal, dtype: float64,
#  optimal                     NaN
#  shift                  1.000000
#  full_attention_TC      0.158884
#  full_attention_TCTC    0.036102
#  Name: optimal, dtype: float64,
#  optimal                     NaN
#  shift                  1.000000
#  full_attention_TC      0.155003
#  full_attention_TCTC    0.036472
#  Name: optimal, dtype: float64]

# %% [markdown]
# # Test by hand

# %%
# Let's write some code here to test the models by hand. The first thing we will attempt is to get the sparsity to work on the CS shift model.

# %%
def causal_mask(b, h, q_idx, kv_idx):
    return q_idx >= kv_idx

def causal_mask_radius(b, h, q_idx, kv_idx):
    return (q_idx >= kv_idx) & (q_idx <= kv_idx+1)

def plot_mask(mask_fn, seq_len=20, title=None, device="cpu"):
    """
    Plot a binary attention mask defined by mask_fn(b,h,q_idx,kv_idx)
    as a (seq_len x seq_len) matrix.
    """
    q_idx = torch.arange(seq_len, device=device)
    kv_idx = torch.arange(seq_len, device=device)
    b = torch.zeros(1, device=device) 
    h = torch.zeros(1, device=device)

    mask = mask_fn(b, h, q_idx[:, None], kv_idx[None, :])
    mask = mask.float().cpu()

    return pd.DataFrame(mask).style.background_gradient(axis=None).format(precision=0)

def build_attention_mask(mask_fn, seq_len, device="cpu"):
    q_idx = torch.arange(seq_len, device=device)
    kv_idx = torch.arange(seq_len, device=device)
    b = torch.zeros(1, device=device)
    h = torch.zeros(1, device=device)
    mask_bool = mask_fn(b, h, q_idx[:, None], kv_idx[None, :])  # (seq_len, seq_len)
    return mask_bool

# %%
def get_ols_corr(N_fea, T_train, rho, oos=True):
    ratio = N_fea/T_train
    if oos:
        return rho / np.sqrt(rho**2 + (1-rho**2) * ratio/(1-ratio))
    else:
        return rho / np.sqrt(rho**2 + (1-rho**2) * ratio)

# %%
def keep_topk_per_row3(x, k=3):
    vals, idx = torch.topk(x, k=k, dim=-1, largest=True)
    out = torch.zeros_like(x)
    out.scatter_(-1, idx, 1)
    return out

def keep_topk_per_row5(x, k=3):
    vals, idx = torch.topk(x, k=k, dim=-1, largest=True)
    out = torch.zeros_like(x)
    out.scatter_(-1, idx, 1)
    return out

# %%
def keep_by_max_value2(x, frac=0.2):
    row_max = x.max(dim=-1, keepdim=True).values
    threshold = frac * row_max
    out = (x >= threshold).to(x.dtype)
    return out

def keep_by_max_value5(x, frac=0.2):
    row_max = x.max(dim=-1, keepdim=True).values
    threshold = frac * row_max
    out = (x >= threshold).to(x.dtype)
    return out

# %%
# Parameters

T=4000
n_rolling = 10
n_f = 5
n_ts = 40

rho = 0.05
effect = 'd_cs'

# %%
# Code to run the model with the parameters above.

embeddings_dict = {'d_lin': "none", 'd_cond': "none", 'd_shift': "T", 'd_cs': "C", 'd_cs_shift': "both", 'd_all': "both"}

mask = causal_mask
mask_c = build_attention_mask(mask, n_rolling, device=device)

if n_f < 10:
    pct_zero_corr = 0
else:
    pct_zero_corr = 0.5

c = rho/np.sqrt((1-pct_zero_corr)*n_f)

arg_list = {'d_lin': {'pct_zero_corr': pct_zero_corr, 'split_conditional': 0.0, 'split_shift': 0.0, 'split_seasonal': 0.0, 'split_cs': 0.0, 'split_cs_shift': 0.0}, 
            'd_cond': {'pct_zero_corr': pct_zero_corr, 'split_conditional': 1.0, 'split_shift': 0.0, 'split_seasonal': 0.0, 'split_cs': 0.0, 'split_cs_shift': 0.0},  
            'd_shift': {'pct_zero_corr': pct_zero_corr, 'split_conditional': 0.0, 'split_shift': 1.0, 'split_seasonal': 0.0, 'split_cs': 0.0, 'split_cs_shift': 0.0}, 
            'd_cs': {'pct_zero_corr': pct_zero_corr, 'split_conditional': 0.0, 'split_shift': 0.0, 'split_seasonal': 0.0, 'split_cs': 1.0, 'split_cs_shift': 0.0}, 
            'd_cs_shift': {'pct_zero_corr': pct_zero_corr, 'split_conditional': 0.0, 'split_shift': 0.0, 'split_seasonal': 0.0, 'split_cs': 0.0, 'split_cs_shift': 1.0}, 
            'd_all': {'pct_zero_corr': pct_zero_corr, 'split_conditional': 0.2, 'split_shift': 0.2, 'split_seasonal': 0.0, 'split_cs': 0.2, 'split_cs_shift': 0.2}
            }

z = generators.Generator(T, n_ts, n_f)

res_train = []
res_test = []

print("Running correl level:", rho)
theo_correl_is = get_ols_corr(n_ts*n_f*n_rolling, T*0.625, rho, oos=False)
theo_correl_oos = get_ols_corr(n_ts*n_f*n_rolling, T*0.625, rho, oos=True)

z.generate_dataset(
        pct_zero_corr=arg_list[effect]['pct_zero_corr'],
        split_conditional=arg_list[effect]['split_conditional'],
        split_shift=arg_list[effect]['split_shift'],
        split_seasonal=arg_list[effect]['split_seasonal'],
        split_cs=arg_list[effect]['split_cs'],
        split_cs_shift=arg_list[effect]['split_cs_shift'],
        random_ts_shift=n_rolling-1,
        low_corr=c,
        high_corr=c,
        shuffle_cs=True
    )

z.get_dataloader()


models_torch = {
    'full_attention_CC': models.CustomBiDimensionalTransformer(
        n_ts, n_f, n_rolling, mask=mask_c, layers='CC', nhead=16,
        dropout=0.1, d_model=32, dim_feedforward=128, sparsify=None, roll_y=True, embeddings=embeddings_dict[effect],
    ).to(device),
    'top3_sparse_attention_CC': models.CustomBiDimensionalTransformer(
        n_ts, n_f, n_rolling, mask=mask_c, layers='CC', nhead=16,
        dropout=0.1, d_model=32, dim_feedforward=128, sparsify=keep_topk_per_row3, roll_y=True, embeddings=embeddings_dict[effect],
    ).to(device),
    'top5_sparse_attention_CC': models.CustomBiDimensionalTransformer(
        n_ts, n_f, n_rolling, mask=mask_c, layers='CC', nhead=16,
        dropout=0.1, d_model=32, dim_feedforward=128, sparsify=keep_topk_per_row5, roll_y=True, embeddings=embeddings_dict[effect],
    ).to(device),
    'max2_sparse_attention_CC': models.CustomBiDimensionalTransformer(
        n_ts, n_f, n_rolling, mask=mask_c, layers='CC', nhead=16,
        dropout=0.1, d_model=32, dim_feedforward=128, sparsify=keep_by_max_value2, roll_y=True, embeddings=embeddings_dict[effect],
    ).to(device),
    'max5_sparse_attention_CC': models.CustomBiDimensionalTransformer(
        n_ts, n_f, n_rolling, mask=mask_c, layers='CC', nhead=16,
        dropout=0.1, d_model=32, dim_feedforward=128, sparsify=keep_by_max_value5, roll_y=True, embeddings=embeddings_dict[effect],
    ).to(device),
    # 'top_sparse_attention_TC': models.CustomBiDimensionalTransformer(
    #     n_ts, n_f, n_rolling, mask=mask_c, layers='TC', nhead=1,
    #     dropout=0.1, dim_feedforward=256, sparsify=keep_topk_per_row, roll_y=True, embeddings=embeddings_dict[effect],
    # ).to(device),
    # 'max_sparse_attention_TC': models.CustomBiDimensionalTransformer(
    #     n_ts, n_f, n_rolling, mask=mask_c, layers='TC', nhead=1,
    #     dropout=0.1, dim_feedforward=256, sparsify=keep_by_max_value, roll_y=True, embeddings=embeddings_dict[effect],
    # ).to(device),

}

models_torch = {
    k: torch_benchmarks.TorchWrapper(
        models_torch[k], 
        optimizer=torch.optim.AdamW(models_torch[k].parameters(), lr=0.001),
        loss_fn=nn.MSELoss()  
    ) for k in models_torch
}


z.get_dataloader(n_rolling=n_rolling, roll_y=True)
for k in models_torch:
    models_torch[k].fit(z.train, test=z.test, epochs=40, plot=False, verbose=0)
    

comp = benchmark_comparison.Comparator(models=[models_torch[k] for k in models_torch], 
model_names=[k for k in models_torch]
)

corr_train = comp.correl(z, mode="train", return_values=True)
corr_test  = comp.correl(z, mode="test",  return_values=True)

for k in models_torch:

    train_corr = corr_train.loc[k, "optimal"]
    test_corr  = corr_test.loc[k, "optimal"]

    res_train.append({
        "rho": rho,
        "model": k,
        "train_corr_optimal": train_corr
    })
    res_test.append({
        "rho": rho,
        "model": k,
        "test_corr_optimal": test_corr
    })


res_train.append({
        "rho": rho,
        "model": "theo_correl",
        "train_corr_optimal": theo_correl_is
    })
res_test.append({
        "rho": rho,
        "model": "theo_correl",
        "test_corr_optimal": theo_correl_oos
    })


res_train = pd.DataFrame(res_train)
res_test  = pd.DataFrame(res_test)

res_train = res_train.pivot(index="rho", columns="model", values="train_corr_optimal")
res_test  = res_test.pivot(index="rho", columns="model", values="test_corr_optimal")
# Out:
# Running correl level: 0.05
# /Users/gremy/Code/TSNN-1/tsnn-env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# /Users/gremy/Code/TSNN-1/tsnn-env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)

# %%
res_train
# Out:
# model  full_attention_CC  max2_sparse_attention_CC  max5_sparse_attention_CC  \
# rho
# 0.05            0.015343                  0.040966                  0.014661
#
# model  theo_correl  top3_sparse_attention_CC  top5_sparse_attention_CC
# rho
# 0.05      0.055884                  0.043995                  0.015274

# %%
res_test
# Out:
# model  full_attention_CC  max2_sparse_attention_CC  max5_sparse_attention_CC  \
# rho
# 0.05            0.011246                  0.041484                  0.009541
#
# model  theo_correl  top3_sparse_attention_CC  top5_sparse_attention_CC
# rho
# 0.05      0.025023                  0.043989                  0.008559

# %%
# What is the spasity doing here ? Let's try to visualize it..

# %%
pd.DataFrame(np.array(models_torch['top_sparse_attention_CC'].model.blocks[0].series.layers[0].self_attn.last_attn_weights.mean(0).mean(0).to('cpu'))).style.background_gradient(axis=0).format(precision=3)
# Out:
# /var/folders/vm/1x4t9m015pxd573nk50nfnkh0000gn/T/ipykernel_54236/748466161.py:1: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   pd.DataFrame(np.array(models_torch['top_sparse_attention_CC'].model.blocks[0].series.layers[0].self_attn.last_attn_weights.mean(0).mean(0).to('cpu'))).style.background_gradient(axis=0).format(precision=3)
# <style type="text/css">
# #T_16e36_row0_col0, #T_16e36_row0_col3, #T_16e36_row0_col4, #T_16e36_row0_col6, #T_16e36_row0_col7, #T_16e36_row0_col8, #T_16e36_row0_col9, #T_16e36_row1_col1, #T_16e36_row1_col2, #T_16e36_row1_col4, #T_16e36_row1_col5, #T_16e36_row1_col6, #T_16e36_row1_col7, #T_16e36_row1_col9, #T_16e36_row2_col0, #T_16e36_row2_col1, #T_16e36_row2_col2, #T_16e36_row2_col3, #T_16e36_row2_col5, #T_16e36_row2_col6, #T_16e36_row2_col7, #T_16e36_row2_col8, #T_16e36_row3_col0, #T_16e36_row3_col1, #T_16e36_row3_col2, #T_16e36_row3_col3, #T_16e36_row3_col5, #T_16e36_row3_col6, #T_16e36_row3_col8, #T_16e36_row4_col1, #T_16e36_row4_col2, #T_16e36_row4_col3, #T_16e36_row4_col4, #T_16e36_row4_col7, #T_16e36_row4_col8, #T_16e36_row4_col9, #T_16e36_row5_col1, #T_16e36_row5_col2, #T_16e36_row5_col3, #T_16e36_row5_col5, #T_16e36_row5_col6, #T_16e36_row5_col7, #T_16e36_row5_col8, #T_16e36_row6_col0, #T_16e36_row6_col1, #T_16e36_row6_col3, #T_16e36_row6_col4, #T_16e36_row6_col5, #T_16e36_row6_col8, #T_16e36_row6_col9, #T_16e36_row7_col0, #T_16e36_row7_col1, #T_16e36_row7_col4, #T_16e36_row7_col5, #T_16e36_row7_col6, #T_16e36_row7_col7, #T_16e36_row7_col9, #T_16e36_row8_col0, #T_16e36_row8_col1, #T_16e36_row8_col2, #T_16e36_row8_col4, #T_16e36_row8_col5, #T_16e36_row8_col7, #T_16e36_row8_col9, #T_16e36_row9_col1, #T_16e36_row9_col2, #T_16e36_row9_col3, #T_16e36_row9_col4, #T_16e36_row9_col6, #T_16e36_row9_col7, #T_16e36_row9_col9 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_16e36_row0_col1, #T_16e36_row0_col2, #T_16e36_row2_col9, #T_16e36_row3_col4, #T_16e36_row4_col6, #T_16e36_row6_col7, #T_16e36_row7_col3, #T_16e36_row8_col8, #T_16e36_row9_col0, #T_16e36_row9_col5 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_16e36_row0_col5, #T_16e36_row7_col2 {
#   background-color: #056caa;
#   color: #f1f1f1;
# }
# #T_16e36_row1_col0 {
#   background-color: #187cb6;
#   color: #f1f1f1;
# }
# #T_16e36_row1_col3 {
#   background-color: #045382;
#   color: #f1f1f1;
# }
# #T_16e36_row1_col8 {
#   background-color: #6fa7ce;
#   color: #f1f1f1;
# }
# #T_16e36_row2_col4 {
#   background-color: #88b1d4;
#   color: #000000;
# }
# #T_16e36_row3_col7, #T_16e36_row8_col3 {
#   background-color: #0570b0;
#   color: #f1f1f1;
# }
# #T_16e36_row3_col9 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_16e36_row4_col0 {
#   background-color: #a5bddb;
#   color: #000000;
# }
# #T_16e36_row4_col5 {
#   background-color: #05659f;
#   color: #f1f1f1;
# }
# #T_16e36_row5_col0 {
#   background-color: #e1dfed;
#   color: #000000;
# }
# #T_16e36_row5_col4 {
#   background-color: #046299;
#   color: #f1f1f1;
# }
# #T_16e36_row5_col9 {
#   background-color: #1379b5;
#   color: #f1f1f1;
# }
# #T_16e36_row6_col2 {
#   background-color: #034b76;
#   color: #f1f1f1;
# }
# #T_16e36_row6_col6, #T_16e36_row7_col8 {
#   background-color: #358fc0;
#   color: #f1f1f1;
# }
# #T_16e36_row8_col6 {
#   background-color: #d1d2e6;
#   color: #000000;
# }
# #T_16e36_row9_col8 {
#   background-color: #b1c2de;
#   color: #000000;
# }
# </style>
# <table id="T_16e36">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_16e36_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_16e36_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_16e36_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_16e36_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_16e36_level0_col4" class="col_heading level0 col4" >4</th>
#       <th id="T_16e36_level0_col5" class="col_heading level0 col5" >5</th>
#       <th id="T_16e36_level0_col6" class="col_heading level0 col6" >6</th>
#       <th id="T_16e36_level0_col7" class="col_heading level0 col7" >7</th>
#       <th id="T_16e36_level0_col8" class="col_heading level0 col8" >8</th>
#       <th id="T_16e36_level0_col9" class="col_heading level0 col9" >9</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_16e36_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_16e36_row0_col0" class="data row0 col0" >0.000</td>
#       <td id="T_16e36_row0_col1" class="data row0 col1" >0.443</td>
#       <td id="T_16e36_row0_col2" class="data row0 col2" >0.155</td>
#       <td id="T_16e36_row0_col3" class="data row0 col3" >0.000</td>
#       <td id="T_16e36_row0_col4" class="data row0 col4" >0.000</td>
#       <td id="T_16e36_row0_col5" class="data row0 col5" >0.402</td>
#       <td id="T_16e36_row0_col6" class="data row0 col6" >0.000</td>
#       <td id="T_16e36_row0_col7" class="data row0 col7" >0.000</td>
#       <td id="T_16e36_row0_col8" class="data row0 col8" >0.000</td>
#       <td id="T_16e36_row0_col9" class="data row0 col9" >0.000</td>
#     </tr>
#     <tr>
#       <th id="T_16e36_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_16e36_row1_col0" class="data row1 col0" >0.233</td>
#       <td id="T_16e36_row1_col1" class="data row1 col1" >0.000</td>
#       <td id="T_16e36_row1_col2" class="data row1 col2" >0.000</td>
#       <td id="T_16e36_row1_col3" class="data row1 col3" >0.548</td>
#       <td id="T_16e36_row1_col4" class="data row1 col4" >0.000</td>
#       <td id="T_16e36_row1_col5" class="data row1 col5" >0.000</td>
#       <td id="T_16e36_row1_col6" class="data row1 col6" >0.000</td>
#       <td id="T_16e36_row1_col7" class="data row1 col7" >0.000</td>
#       <td id="T_16e36_row1_col8" class="data row1 col8" >0.219</td>
#       <td id="T_16e36_row1_col9" class="data row1 col9" >0.000</td>
#     </tr>
#     <tr>
#       <th id="T_16e36_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_16e36_row2_col0" class="data row2 col0" >0.000</td>
#       <td id="T_16e36_row2_col1" class="data row2 col1" >0.000</td>
#       <td id="T_16e36_row2_col2" class="data row2 col2" >0.000</td>
#       <td id="T_16e36_row2_col3" class="data row2 col3" >0.000</td>
#       <td id="T_16e36_row2_col4" class="data row2 col4" >0.205</td>
#       <td id="T_16e36_row2_col5" class="data row2 col5" >0.000</td>
#       <td id="T_16e36_row2_col6" class="data row2 col6" >0.000</td>
#       <td id="T_16e36_row2_col7" class="data row2 col7" >0.000</td>
#       <td id="T_16e36_row2_col8" class="data row2 col8" >0.000</td>
#       <td id="T_16e36_row2_col9" class="data row2 col9" >0.794</td>
#     </tr>
#     <tr>
#       <th id="T_16e36_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_16e36_row3_col0" class="data row3 col0" >0.000</td>
#       <td id="T_16e36_row3_col1" class="data row3 col1" >0.000</td>
#       <td id="T_16e36_row3_col2" class="data row3 col2" >0.000</td>
#       <td id="T_16e36_row3_col3" class="data row3 col3" >0.000</td>
#       <td id="T_16e36_row3_col4" class="data row3 col4" >0.454</td>
#       <td id="T_16e36_row3_col5" class="data row3 col5" >0.000</td>
#       <td id="T_16e36_row3_col6" class="data row3 col6" >0.000</td>
#       <td id="T_16e36_row3_col7" class="data row3 col7" >0.428</td>
#       <td id="T_16e36_row3_col8" class="data row3 col8" >0.000</td>
#       <td id="T_16e36_row3_col9" class="data row3 col9" >0.117</td>
#     </tr>
#     <tr>
#       <th id="T_16e36_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_16e36_row4_col0" class="data row4 col0" >0.125</td>
#       <td id="T_16e36_row4_col1" class="data row4 col1" >0.000</td>
#       <td id="T_16e36_row4_col2" class="data row4 col2" >0.000</td>
#       <td id="T_16e36_row4_col3" class="data row4 col3" >0.000</td>
#       <td id="T_16e36_row4_col4" class="data row4 col4" >0.000</td>
#       <td id="T_16e36_row4_col5" class="data row4 col5" >0.423</td>
#       <td id="T_16e36_row4_col6" class="data row4 col6" >0.452</td>
#       <td id="T_16e36_row4_col7" class="data row4 col7" >0.000</td>
#       <td id="T_16e36_row4_col8" class="data row4 col8" >0.000</td>
#       <td id="T_16e36_row4_col9" class="data row4 col9" >0.000</td>
#     </tr>
#     <tr>
#       <th id="T_16e36_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_16e36_row5_col0" class="data row5 col0" >0.058</td>
#       <td id="T_16e36_row5_col1" class="data row5 col1" >0.000</td>
#       <td id="T_16e36_row5_col2" class="data row5 col2" >0.000</td>
#       <td id="T_16e36_row5_col3" class="data

# %%
pd.DataFrame(np.array(models_torch['top_sparse_attention_CC'].model.blocks[1].series.layers[0].self_attn.last_attn_weights.mean(0).mean(0).to('cpu'))).style.background_gradient(axis=0).format(precision=3)
# Out:
# /var/folders/vm/1x4t9m015pxd573nk50nfnkh0000gn/T/ipykernel_54236/838903454.py:1: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   pd.DataFrame(np.array(models_torch['top_sparse_attention_CC'].model.blocks[1].series.layers[0].self_attn.last_attn_weights.mean(0).mean(0).to('cpu'))).style.background_gradient(axis=0).format(precision=3)
# <style type="text/css">
# #T_9735d_row0_col0, #T_9735d_row2_col6, #T_9735d_row3_col3, #T_9735d_row5_col1, #T_9735d_row6_col4, #T_9735d_row7_col8, #T_9735d_row8_col5, #T_9735d_row9_col7 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_9735d_row0_col1 {
#   background-color: #023c5f;
#   color: #f1f1f1;
# }
# #T_9735d_row0_col2, #T_9735d_row0_col3, #T_9735d_row0_col4, #T_9735d_row0_col6, #T_9735d_row0_col7, #T_9735d_row0_col8, #T_9735d_row0_col9, #T_9735d_row1_col0, #T_9735d_row1_col1, #T_9735d_row1_col2, #T_9735d_row1_col3, #T_9735d_row1_col4, #T_9735d_row1_col8, #T_9735d_row1_col9, #T_9735d_row2_col0, #T_9735d_row2_col1, #T_9735d_row2_col2, #T_9735d_row2_col4, #T_9735d_row2_col5, #T_9735d_row2_col7, #T_9735d_row2_col9, #T_9735d_row3_col1, #T_9735d_row3_col2, #T_9735d_row3_col4, #T_9735d_row3_col5, #T_9735d_row3_col7, #T_9735d_row3_col8, #T_9735d_row3_col9, #T_9735d_row4_col0, #T_9735d_row4_col2, #T_9735d_row4_col3, #T_9735d_row4_col4, #T_9735d_row4_col5, #T_9735d_row4_col8, #T_9735d_row4_col9, #T_9735d_row5_col0, #T_9735d_row5_col2, #T_9735d_row5_col3, #T_9735d_row5_col4, #T_9735d_row5_col6, #T_9735d_row5_col8, #T_9735d_row5_col9, #T_9735d_row6_col0, #T_9735d_row6_col2, #T_9735d_row6_col5, #T_9735d_row6_col6, #T_9735d_row6_col7, #T_9735d_row6_col8, #T_9735d_row6_col9, #T_9735d_row7_col0, #T_9735d_row7_col1, #T_9735d_row7_col2, #T_9735d_row7_col3, #T_9735d_row7_col5, #T_9735d_row7_col7, #T_9735d_row7_col9, #T_9735d_row8_col0, #T_9735d_row8_col1, #T_9735d_row8_col2, #T_9735d_row8_col6, #T_9735d_row8_col7, #T_9735d_row8_col8, #T_9735d_row8_col9, #T_9735d_row9_col0, #T_9735d_row9_col1, #T_9735d_row9_col2, #T_9735d_row9_col3, #T_9735d_row9_col5, #T_9735d_row9_col8, #T_9735d_row9_col9 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_9735d_row0_col5 {
#   background-color: #b9c6e0;
#   color: #000000;
# }
# #T_9735d_row1_col5 {
#   background-color: #1c7fb8;
#   color: #f1f1f1;
# }
# #T_9735d_row1_col6, #T_9735d_row5_col5 {
#   background-color: #91b5d6;
#   color: #000000;
# }
# #T_9735d_row1_col7 {
#   background-color: #6da6cd;
#   color: #f1f1f1;
# }
# #T_9735d_row2_col3 {
#   background-color: #f1ebf5;
#   color: #000000;
# }
# #T_9735d_row2_col8 {
#   background-color: #034267;
#   color: #f1f1f1;
# }
# #T_9735d_row3_col0 {
#   background-color: #2a88bc;
#   color: #f1f1f1;
# }
# #T_9735d_row3_col6 {
#   background-color: #d5d5e8;
#   color: #000000;
# }
# #T_9735d_row4_col1 {
#   background-color: #046299;
#   color: #f1f1f1;
# }
# #T_9735d_row4_col6 {
#   background-color: #7dacd1;
#   color: #f1f1f1;
# }
# #T_9735d_row4_col7 {
#   background-color: #a9bfdc;
#   color: #000000;
# }
# #T_9735d_row5_col7 {
#   background-color: #d6d6e9;
#   color: #000000;
# }
# #T_9735d_row6_col1 {
#   background-color: #358fc0;
#   color: #f1f1f1;
# }
# #T_9735d_row6_col3 {
#   background-color: #5ea0ca;
#   color: #f1f1f1;
# }
# #T_9735d_row7_col4, #T_9735d_row7_col6 {
#   background-color: #056dab;
#   color: #f1f1f1;
# }
# #T_9735d_row8_col3 {
#   background-color: #c6cce3;
#   color: #000000;
# }
# #T_9735d_row8_col4 {
#   background-color: #0567a2;
#   color: #f1f1f1;
# }
# #T_9735d_row9_col4 {
#   background-color: #75a9cf;
#   color: #f1f1f1;
# }
# #T_9735d_row9_col6 {
#   background-color: #a2bcda;
#   color: #000000;
# }
# </style>
# <table id="T_9735d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9735d_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_9735d_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_9735d_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_9735d_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_9735d_level0_col4" class="col_heading level0 col4" >4</th>
#       <th id="T_9735d_level0_col5" class="col_heading level0 col5" >5</th>
#       <th id="T_9735d_level0_col6" class="col_heading level0 col6" >6</th>
#       <th id="T_9735d_level0_col7" class="col_heading level0 col7" >7</th>
#       <th id="T_9735d_level0_col8" class="col_heading level0 col8" >8</th>
#       <th id="T_9735d_level0_col9" class="col_heading level0 col9" >9</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9735d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9735d_row0_col0" class="data row0 col0" >0.229</td>
#       <td id="T_9735d_row0_col1" class="data row0 col1" >0.577</td>
#       <td id="T_9735d_row0_col2" class="data row0 col2" >0.000</td>
#       <td id="T_9735d_row0_col3" class="data row0 col3" >0.000</td>
#       <td id="T_9735d_row0_col4" class="data row0 col4" >0.000</td>
#       <td id="T_9735d_row0_col5" class="data row0 col5" >0.194</td>
#       <td id="T_9735d_row0_col6" class="data row0 col6" >0.000</td>
#       <td id="T_9735d_row0_col7" class="data row0 col7" >0.000</td>
#       <td id="T_9735d_row0_col8" class="data row0 col8" >0.000</td>
#       <td id="T_9735d_row0_col9" class="data row0 col9" >0.000</td>
#     </tr>
#     <tr>
#       <th id="T_9735d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9735d_row1_col0" class="data row1 col0" >0.000</td>
#       <td id="T_9735d_row1_col1" class="data row1 col1" >0.000</td>
#       <td id="T_9735d_row1_col2" class="data row1 col2" >0.000</td>
#       <td id="T_9735d_row1_col3" class="data row1 col3" >0.000</td>
#       <td id="T_9735d_row1_col4" class="data row1 col4" >0.000</td>
#       <td id="T_9735d_row1_col5" class="data row1 col5" >0.420</td>
#       <td id="T_9735d_row1_col6" class="data row1 col6" >0.238</td>
#       <td id="T_9735d_row1_col7" class="data row1 col7" >0.342</td>
#       <td id="T_9735d_row1_col8" class="data row1 col8" >0.000</td>
#       <td id="T_9735d_row1_col9" class="data row1 col9" >0.000</td>
#     </tr>
#     <tr>
#       <th id="T_9735d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9735d_row2_col0" class="data row2 col0" >0.000</td>
#       <td id="T_9735d_row2_col1" class="data row2 col1" >0.000</td>
#       <td id="T_9735d_row2_col2" class="data row2 col2" >0.000</td>
#       <td id="T_9735d_row2_col3" class="data row2 col3" >0.067</td>
#       <td id="T_9735d_row2_col4" class="data row2 col4" >0.000</td>
#       <td id="T_9735d_row2_col5" class="data row2 col5" >0.000</td>
#       <td id="T_9735d_row2_col6" class="data row2 col6" >0.558</td>
#       <td id="T_9735d_row2_col7" class="data row2 col7" >0.000</td>
#       <td id="T_9735d_row2_col8" class="data row2 col8" >0.374</td>
#       <td id="T_9735d_row2_col9" class="data row2 col9" >0.000</td>
#     </tr>
#     <tr>
#       <th id="T_9735d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9735d_row3_col0" class="data row3 col0" >0.150</td>
#       <td id="T_9735d_row3_col1" class="data row3 col1" >0.000</td>
#       <td id="T_9735d_row3_col2" class="data row3 col2" >0.000</td>
#       <td id="T_9735d_row3_col3" class="data row3 col3" >0.722</td>
#       <td id="T_9735d_row3_col4" class="data row3 col4" >0.000</td>
#       <td id="T_9735d_row3_col5" class="data row3 col5" >0.000</td>
#       <td id="T_9735d_row3_col6" class="data row3 col6" >0.127</td>
#       <td id="T_9735d_row3_col7" class="data row3 col7" >0.000</td>
#       <td id="T_9735d_row3_col8" class="data row3 col8" >0.000</td>
#       <td id="T_9735d_row3_col9" class="data row3 col9" >0.000</td>
#     </tr>
#     <tr>
#       <th id="T_9735d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_9735d_row4_col0" class="data row4 col0" >0.000</td>
#       <td id="T_9735d_row4_col1" class="data row4 col1" >0.489</td>
#       <td id="T_9735d_row4_col2" class="data row4 col2" >0.000</td>
#       <td id="T_9735d_row4_col3" class="data row4 col3" >0.000</td>
#       <td id="T_9735d_row4_col4" class="data row4 col4" >0.000</td>
#       <td id="T_9735d_row4_col5" class="data row4 col5" >0.000</td>
#       <td id="T_9735d_row4_col6" class="data row4 col6" >0.266</td>
#       <td id="T_9735d_row4_col7" class="data row4 col7" >0.244</td>
#       <td id="T_9735d_row4_col8" class="data row4 col8" >0.000</td>
#       <td id="T_9735d_row4_col9" class="data row4 col9" >0.000</td>
#     </tr>
#     <tr>
#       <th id="T_9735d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_9735d_row5_col0" class="data row

# %%
pd.DataFrame(np.array(models_torch['max_sparse_attention_CC'].model.blocks[0].series.layers[0].self_attn.last_attn_weights.mean(0).mean(0).to('cpu'))).style.background_gradient(axis=0).format(precision=3)
# Out:
# /var/folders/vm/1x4t9m015pxd573nk50nfnkh0000gn/T/ipykernel_54236/3075308818.py:1: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   pd.DataFrame(np.array(models_torch['max_sparse_attention_CC'].model.blocks[0].series.layers[0].self_attn.last_attn_weights.mean(0).mean(0).to('cpu'))).style.background_gradient(axis=0).format(precision=3)
# <style type="text/css">
# #T_a0441_row0_col0, #T_a0441_row0_col1, #T_a0441_row0_col2, #T_a0441_row0_col4, #T_a0441_row0_col5, #T_a0441_row0_col6, #T_a0441_row0_col7, #T_a0441_row0_col8, #T_a0441_row0_col9, #T_a0441_row1_col0, #T_a0441_row1_col2, #T_a0441_row1_col3, #T_a0441_row1_col4, #T_a0441_row1_col5, #T_a0441_row1_col6, #T_a0441_row1_col7, #T_a0441_row1_col8, #T_a0441_row1_col9, #T_a0441_row2_col0, #T_a0441_row2_col1, #T_a0441_row2_col2, #T_a0441_row2_col3, #T_a0441_row2_col4, #T_a0441_row2_col7, #T_a0441_row2_col8, #T_a0441_row3_col0, #T_a0441_row3_col1, #T_a0441_row3_col3, #T_a0441_row3_col4, #T_a0441_row3_col5, #T_a0441_row3_col6, #T_a0441_row3_col7, #T_a0441_row3_col8, #T_a0441_row3_col9, #T_a0441_row4_col0, #T_a0441_row4_col1, #T_a0441_row4_col2, #T_a0441_row4_col3, #T_a0441_row4_col4, #T_a0441_row4_col6, #T_a0441_row4_col7, #T_a0441_row4_col8, #T_a0441_row4_col9, #T_a0441_row5_col0, #T_a0441_row5_col1, #T_a0441_row5_col2, #T_a0441_row5_col3, #T_a0441_row5_col4, #T_a0441_row5_col6, #T_a0441_row5_col7, #T_a0441_row5_col8, #T_a0441_row5_col9, #T_a0441_row6_col0, #T_a0441_row6_col1, #T_a0441_row6_col3, #T_a0441_row6_col4, #T_a0441_row6_col5, #T_a0441_row6_col6, #T_a0441_row6_col7, #T_a0441_row6_col8, #T_a0441_row6_col9, #T_a0441_row7_col0, #T_a0441_row7_col1, #T_a0441_row7_col2, #T_a0441_row7_col3, #T_a0441_row7_col4, #T_a0441_row7_col6, #T_a0441_row7_col7, #T_a0441_row7_col8, #T_a0441_row7_col9, #T_a0441_row8_col0, #T_a0441_row8_col1, #T_a0441_row8_col2, #T_a0441_row8_col3, #T_a0441_row8_col5, #T_a0441_row8_col6, #T_a0441_row8_col7, #T_a0441_row8_col8, #T_a0441_row8_col9, #T_a0441_row9_col0, #T_a0441_row9_col1, #T_a0441_row9_col3, #T_a0441_row9_col4, #T_a0441_row9_col5, #T_a0441_row9_col6, #T_a0441_row9_col7, #T_a0441_row9_col8, #T_a0441_row9_col9 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_a0441_row0_col3, #T_a0441_row1_col1, #T_a0441_row2_col6, #T_a0441_row2_col9, #T_a0441_row3_col2, #T_a0441_row4_col5, #T_a0441_row5_col5, #T_a0441_row6_col2, #T_a0441_row7_col5, #T_a0441_row8_col4, #T_a0441_row9_col2 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_a0441_row2_col5 {
#   background-color: #cccfe5;
#   color: #000000;
# }
# </style>
# <table id="T_a0441">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a0441_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_a0441_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_a0441_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_a0441_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_a0441_level0_col4" class="col_heading level0 col4" >4</th>
#       <th id="T_a0441_level0_col5" class="col_heading level0 col5" >5</th>
#       <th id="T_a0441_level0_col6" class="col_heading level0 col6" >6</th>
#       <th id="T_a0441_level0_col7" class="col_heading level0 col7" >7</th>
#       <th id="T_a0441_level0_col8" class="col_heading level0 col8" >8</th>
#       <th id="T_a0441_level0_col9" class="col_heading level0 col9" >9</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a0441_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a0441_row0_col0" class="data row0 col0" >0.000</td>
#       <td id="T_a0441_row0_col1" class="data row0 col1" >0.000</td>
#       <td id="T_a0441_row0_col2" class="data row0 col2" >0.000</td>
#       <td id="T_a0441_row0_col3" class="data row0 col3" >1.000</td>
#       <td id="T_a0441_row0_col4" class="data row0 col4" >0.000</td>
#       <td id="T_a0441_row0_col5" class="data row0 col5" >0.000</td>
#       <td id="T_a0441_row0_col6" class="data row0 col6" >0.000</td>
#       <td id="T_a0441_row0_col7" class="data row0 col7" >0.000</td>
#       <td id="T_a0441_row0_col8" class="data row0 col8" >0.000</td>
#       <td id="T_a0441_row0_col9" class="data row0 col9" >0.000</td>
#     </tr>
#     <tr>
#       <th id="T_a0441_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a0441_row1_col0" class="data row1 col0" >0.000</td>
#       <td id="T_a0441_row1_col1" class="data row1 col1" >1.000</td>
#       <td id="T_a0441_row1_col2" class="data row1 col2" >0.000</td>
#       <td id="T_a0441_row1_col3" class="data row1 col3" >0.000</td>
#       <td id="T_a0441_row1_col4" class="data row1 col4" >0.000</td>
#       <td id="T_a0441_row1_col5" class="data row1 col5" >0.000</td>
#       <td id="T_a0441_row1_col6" class="data row1 col6" >0.000</td>
#       <td id="T_a0441_row1_col7" class="data row1 col7" >0.000</td>
#       <td id="T_a0441_row1_col8" class="data row1 col8" >0.000</td>
#       <td id="T_a0441_row1_col9" class="data row1 col9" >0.000</td>
#     </tr>
#     <tr>
#       <th id="T_a0441_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a0441_row2_col0" class="data row2 col0" >0.000</td>
#       <td id="T_a0441_row2_col1" class="data row2 col1" >0.000</td>
#       <td id="T_a0441_row2_col2" class="data row2 col2" >0.000</td>
#       <td id="T_a0441_row2_col3" class="data row2 col3" >0.000</td>
#       <td id="T_a0441_row2_col4" class="data row2 col4" >0.000</td>
#       <td id="T_a0441_row2_col5" class="data row2 col5" >0.264</td>
#       <td id="T_a0441_row2_col6" class="data row2 col6" >0.408</td>
#       <td id="T_a0441_row2_col7" class="data row2 col7" >0.000</td>
#       <td id="T_a0441_row2_col8" class="data row2 col8" >0.000</td>
#       <td id="T_a0441_row2_col9" class="data row2 col9" >0.328</td>
#     </tr>
#     <tr>
#       <th id="T_a0441_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a0441_row3_col0" class="data row3 col0" >0.000</td>
#       <td id="T_a0441_row3_col1" class="data row3 col1" >0.000</td>
#       <td id="T_a0441_row3_col2" class="data row3 col2" >1.000</td>
#       <td id="T_a0441_row3_col3" class="data row3 col3" >0.000</td>
#       <td id="T_a0441_row3_col4" class="data row3 col4" >0.000</td>
#       <td id="T_a0441_row3_col5" class="data row3 col5" >0.000</td>
#       <td id="T_a0441_row3_col6" class="data row3 col6" >0.000</td>
#       <td id="T_a0441_row3_col7" class="data row3 col7" >0.000</td>
#       <td id="T_a0441_row3_col8" class="data row3 col8" >0.000</td>
#       <td id="T_a0441_row3_col9" class="data row3 col9" >0.000</td>
#     </tr>
#     <tr>
#       <th id="T_a0441_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a0441_row4_col0" class="data row4 col0" >0.000</td>
#       <td id="T_a0441_row4_col1" class="data row4 col1" >0.000</td>
#       <td id="T_a0441_row4_col2" class="data row4 col2" >0.000</td>
#       <td id="T_a0441_row4_col3" class="data row4 col3" >0.000</td>
#       <td id="T_a0441_row4_col4" class="data row4 col4" >0.000</td>
#       <td id="T_a0441_row4_col5" class="data row4 col5" >1.000</td>
#       <td id="T_a0441_row4_col6" class="data row4 col6" >0.000</td>
#       <td id="T_a0441_row4_col7" class="data row4 col7" >0.000</td>
#       <td id="T_a0441_row4_col8" class="data row4 col8" >0.000</td>
#       <td id="T_a0441_row4_col9" class="data row4 col9" >0.000</td>
#     </tr>
#     <tr>
#       <th id="T_a0441_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a0441_row5_col0" class="data row5 col0" >0.000</td>
#       <td id="T_a0441_row5_col1" class="data row5 col1" >0.000</td>
#       <td id="T_a0441_row5_col2" class="data row5 col2" >0.000</td>
#       <td id="T_a0441_row5_col3" class="data row5 col3" >0.000</td>
#       <td id="T_a0441_row5_col4" class="data row5 col4" >0.000</td>
#       <td id="T_a0441_row5_col5" class="data row5 col5" >1.000</td>
#       <td id="T_a0441_row5_col6" class="data row5 col6" >0.000</td>
#       <td id="T_a0441_row5_col7" class="data row5 col7" >0.000</td>
#       <td id="T_a0441_row5_col8" class="data row5 col8" >0.000</td>
#       <td id="T_a0441_row5_col9" class="data row5 col9" >0.000</td>
#     </tr>
#     <tr>
#       <th id="T_a0441_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a0441_row6_col0" class="data row6 col0" >0.000</td>
#       <td id="T_a0441_row6_col1" class="data row6 col1" >0.000</td>
#       <td id="T_a0441_row6_col2" class="data row6 col2" >1.000</td>
#       <td id="T_a044

# %%
pd.DataFrame(np.array(models_torch['max_sparse_attention_CC'].model.blocks[1].series.layers[0].self_attn.last_attn_weights.mean(0).mean(0).to('cpu'))).style.background_gradient(axis=0).format(precision=3)
# Out:
# /var/folders/vm/1x4t9m015pxd573nk50nfnkh0000gn/T/ipykernel_54236/2746487211.py:1: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   pd.DataFrame(np.array(models_torch['max_sparse_attention_CC'].model.blocks[1].series.layers[0].self_attn.last_attn_weights.mean(0).mean(0).to('cpu'))).style.background_gradient(axis=0).format(precision=3)
# <style type="text/css">
# #T_fdead_row0_col0, #T_fdead_row0_col1, #T_fdead_row0_col3, #T_fdead_row0_col4, #T_fdead_row0_col5, #T_fdead_row0_col7, #T_fdead_row0_col8, #T_fdead_row0_col9, #T_fdead_row1_col0, #T_fdead_row1_col1, #T_fdead_row1_col2, #T_fdead_row1_col4, #T_fdead_row1_col5, #T_fdead_row1_col6, #T_fdead_row1_col7, #T_fdead_row1_col8, #T_fdead_row1_col9, #T_fdead_row2_col1, #T_fdead_row2_col2, #T_fdead_row2_col3, #T_fdead_row2_col4, #T_fdead_row2_col5, #T_fdead_row2_col8, #T_fdead_row2_col9, #T_fdead_row3_col1, #T_fdead_row3_col2, #T_fdead_row3_col3, #T_fdead_row3_col5, #T_fdead_row3_col6, #T_fdead_row3_col8, #T_fdead_row3_col9, #T_fdead_row4_col0, #T_fdead_row4_col1, #T_fdead_row4_col5, #T_fdead_row4_col6, #T_fdead_row4_col7, #T_fdead_row4_col8, #T_fdead_row4_col9, #T_fdead_row5_col0, #T_fdead_row5_col1, #T_fdead_row5_col3, #T_fdead_row5_col4, #T_fdead_row5_col5, #T_fdead_row5_col6, #T_fdead_row5_col7, #T_fdead_row5_col8, #T_fdead_row6_col0, #T_fdead_row6_col1, #T_fdead_row6_col2, #T_fdead_row6_col3, #T_fdead_row6_col4, #T_fdead_row6_col5, #T_fdead_row6_col6, #T_fdead_row6_col7, #T_fdead_row6_col8, #T_fdead_row7_col0, #T_fdead_row7_col1, #T_fdead_row7_col3, #T_fdead_row7_col4, #T_fdead_row7_col5, #T_fdead_row7_col6, #T_fdead_row7_col8, #T_fdead_row8_col0, #T_fdead_row8_col1, #T_fdead_row8_col2, #T_fdead_row8_col3, #T_fdead_row8_col5, #T_fdead_row8_col6, #T_fdead_row8_col7, #T_fdead_row8_col8, #T_fdead_row8_col9, #T_fdead_row9_col0, #T_fdead_row9_col1, #T_fdead_row9_col2, #T_fdead_row9_col3, #T_fdead_row9_col4, #T_fdead_row9_col5, #T_fdead_row9_col6, #T_fdead_row9_col8, #T_fdead_row9_col9 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_fdead_row0_col2, #T_fdead_row0_col6, #T_fdead_row1_col3, #T_fdead_row3_col0, #T_fdead_row6_col9, #T_fdead_row8_col4, #T_fdead_row9_col7 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_fdead_row2_col0 {
#   background-color: #034f7d;
#   color: #f1f1f1;
# }
# #T_fdead_row2_col6 {
#   background-color: #7dacd1;
#   color: #f1f1f1;
# }
# #T_fdead_row2_col7 {
#   background-color: #9ab8d8;
#   color: #000000;
# }
# #T_fdead_row3_col4, #T_fdead_row4_col2 {
#   background-color: #8eb3d5;
#   color: #000000;
# }
# #T_fdead_row3_col7 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_fdead_row4_col3 {
#   background-color: #b8c6e0;
#   color: #000000;
# }
# #T_fdead_row4_col4 {
#   background-color: #79abd0;
#   color: #f1f1f1;
# }
# #T_fdead_row5_col2 {
#   background-color: #04598c;
#   color: #f1f1f1;
# }
# #T_fdead_row5_col9 {
#   background-color: #3991c1;
#   color: #f1f1f1;
# }
# #T_fdead_row7_col2 {
#   background-color: #6fa7ce;
#   color: #f1f1f1;
# }
# #T_fdead_row7_col7 {
#   background-color: #7eadd1;
#   color: #f1f1f1;
# }
# #T_fdead_row7_col9 {
#   background-color: #bfc9e1;
#   color: #000000;
# }
# </style>
# <table id="T_fdead">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fdead_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_fdead_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_fdead_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_fdead_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_fdead_level0_col4" class="col_heading level0 col4" >4</th>
#       <th id="T_fdead_level0_col5" class="col_heading level0 col5" >5</th>
#       <th id="T_fdead_level0_col6" class="col_heading level0 col6" >6</th>
#       <th id="T_fdead_level0_col7" class="col_heading level0 col7" >7</th>
#       <th id="T_fdead_level0_col8" class="col_heading level0 col8" >8</th>
#       <th id="T_fdead_level0_col9" class="col_heading level0 col9" >9</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fdead_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fdead_row0_col0" class="data row0 col0" >0.000</td>
#       <td id="T_fdead_row0_col1" class="data row0 col1" >0.000</td>
#       <td id="T_fdead_row0_col2" class="data row0 col2" >0.436</td>
#       <td id="T_fdead_row0_col3" class="data row0 col3" >0.000</td>
#       <td id="T_fdead_row0_col4" class="data row0 col4" >0.000</td>
#       <td id="T_fdead_row0_col5" class="data row0 col5" >0.000</td>
#       <td id="T_fdead_row0_col6" class="data row0 col6" >0.564</td>
#       <td id="T_fdead_row0_col7" class="data row0 col7" >0.000</td>
#       <td id="T_fdead_row0_col8" class="data row0 col8" >0.000</td>
#       <td id="T_fdead_row0_col9" class="data row0 col9" >0.000</td>
#     </tr>
#     <tr>
#       <th id="T_fdead_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fdead_row1_col0" class="data row1 col0" >0.000</td>
#       <td id="T_fdead_row1_col1" class="data row1 col1" >0.000</td>
#       <td id="T_fdead_row1_col2" class="data row1 col2" >0.000</td>
#       <td id="T_fdead_row1_col3" class="data row1 col3" >1.000</td>
#       <td id="T_fdead_row1_col4" class="data row1 col4" >0.000</td>
#       <td id="T_fdead_row1_col5" class="data row1 col5" >0.000</td>
#       <td id="T_fdead_row1_col6" class="data row1 col6" >0.000</td>
#       <td id="T_fdead_row1_col7" class="data row1 col7" >0.000</td>
#       <td id="T_fdead_row1_col8" class="data row1 col8" >0.000</td>
#       <td id="T_fdead_row1_col9" class="data row1 col9" >0.000</td>
#     </tr>
#     <tr>
#       <th id="T_fdead_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_fdead_row2_col0" class="data row2 col0" >0.323</td>
#       <td id="T_fdead_row2_col1" class="data row2 col1" >0.000</td>
#       <td id="T_fdead_row2_col2" class="data row2 col2" >0.000</td>
#       <td id="T_fdead_row2_col3" class="data row2 col3" >0.000</td>
#       <td id="T_fdead_row2_col4" class="data row2 col4" >0.000</td>
#       <td id="T_fdead_row2_col5" class="data row2 col5" >0.000</td>
#       <td id="T_fdead_row2_col6" class="data row2 col6" >0.271</td>
#       <td id="T_fdead_row2_col7" class="data row2 col7" >0.406</td>
#       <td id="T_fdead_row2_col8" class="data row2 col8" >0.000</td>
#       <td id="T_fdead_row2_col9" class="data row2 col9" >0.000</td>
#     </tr>
#     <tr>
#       <th id="T_fdead_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_fdead_row3_col0" class="data row3 col0" >0.354</td>
#       <td id="T_fdead_row3_col1" class="data row3 col1" >0.000</td>
#       <td id="T_fdead_row3_col2" class="data row3 col2" >0.000</td>
#       <td id="T_fdead_row3_col3" class="data row3 col3" >0.000</td>
#       <td id="T_fdead_row3_col4" class="data row3 col4" >0.434</td>
#       <td id="T_fdead_row3_col5" class="data row3 col5" >0.000</td>
#       <td id="T_fdead_row3_col6" class="data row3 col6" >0.000</td>
#       <td id="T_fdead_row3_col7" class="data row3 col7" >0.212</td>
#       <td id="T_fdead_row3_col8" class="data row3 col8" >0.000</td>
#       <td id="T_fdead_row3_col9" class="data row3 col9" >0.000</td>
#     </tr>
#     <tr>
#       <th id="T_fdead_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_fdead_row4_col0" class="data row4 col0" >0.000</td>
#       <td id="T_fdead_row4_col1" class="data row4 col1" >0.000</td>
#       <td id="T_fdead_row4_col2" class="data row4 col2" >0.190</td>
#       <td id="T_fdead_row4_col3" class="data row4 col3" >0.323</td>
#       <td id="T_fdead_row4_col4" class="data row4 col4" >0.487</td>
#       <td id="T_fdead_row4_col5" class="data row4 col5" >0.000</td>
#       <td id="T_fdead_row4_col6" class="data row4 col6" >0.000</td>
#       <td id="T_fdead_row4_col7" class="data row4 col7" >0.000</td>
#       <td id="T_fdead_row4_col8" class="data row4 col8" >0.000</td>
#       <td id="T_fdead_row4_col9" class="data row4 col9" >0.000</td>
#     </tr>
#     <tr>
#       <th id="T_fdead_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_fdead_row5_col0" class="data row5 col0" >0.000</td>
#       <td id="T_fdead_row5_col1" class="data row5 col1" >0.000</td>
#       <td id="T_fdead_row5_col2" class="data row5 col2" >0.382</td>
#       <td id="T_fdead_row5_col3" class="data row5 col3" >0.000</td>
#       <td id="T_fdead_row5_col4" class="data row5 col4" >0.000</td>
#       <td id="T_fdead_row5_col5" class="data row5 col5" >0.000</td>
#       <td id="T_fdead_row5_col6" class="
